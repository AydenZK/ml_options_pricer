# %%
import requests
import pandas as pd

pd.set_option('display.max_rows', None)

# %% [markdown]
# Given a ticker, we will query the
# - stock price
# - available exercise prices
# - available times to expiration
# - risk-free interest rate
# - volatility
#
# and use black scholes formula to return the option price

# %% [markdown]
# Choosing Options:
#
# - Choose Ticker
# > see all expiries
# - Choose Expiry
# > See options chain for that Expiry
# - Choose option by code
# - Plug it into formula
#
# or
#
# - Choose Ticker, OptType, Expiry and Strike
# - Plug into formula

# %%
API_KEY = "OeAFFmMliFG5orCUuwAKQ8l4WWFQ67YX"

MEMORY = {}

OPTIONS = {}

RENAME_MAP = {
    'CALL': {
        'strike': 'Strike', 
        'contractName': 'cName',
        'lastPrice': 'lastPrice', 
        'bid': 'cBidP', 
        'ask': 'cAskP',
        'volume': 'cVolume', 
        'impliedVolatility': 'impliedVolatility', 
        'delta': 'cDelta', 
        'gamma': 'Gamma', 
        'theta': 'Theta', 
        'vega': 'Vega', 
        'rho': 'Rho'
    },
    'PUT': {
        'strike': 'Strike', 
        'contractName': 'pName',
        'lastPrice': 'lastPrice', 
        'bid': 'pBidP', 
        'ask': 'pAskP',
        'volume': 'pVolume', 
        'impliedVolatility': 'impliedVolatility', 
        'delta': 'pDelta', 
        'gamma': 'Gamma', 
        'theta': 'Theta', 
        'vega': 'Vega', 
        'rho': 'Rho'
    }
}

# %%
def query_data(ticker):
    global OPTIONS
    global MEMORY
    global API_KEY
    global RENAME_MAP

    if ticker not in OPTIONS:
        url = f"https://eodhistoricaldata.com/api/options/{ticker}.US?api_token={API_KEY}"
        response = requests.request("GET", url)

        OPTIONS[ticker] = response.json()
        OPTIONS[ticker]['expiries'] = [i['expirationDate'] for i in OPTIONS[ticker]['data']]
        OPTIONS[ticker]['options_chain'] = {}

        for sample in OPTIONS[ticker]['data']:
            opt_chain = {opt['strike']:{} for opt in sample['options']["CALL"]} if len(sample['options']["CALL"]) > len(sample['options']["PUT"]) else {opt['strike']:{} for opt in sample['options']["PUT"]}
            opt_types = ['CALL', 'PUT']
            for opt_type in opt_types:
                for opt in sample['options'][opt_type]: 
                    opt_chain[opt['strike']].update({RENAME_MAP[opt_type][k]:v for k, v in opt.items() if k in ['strike', 'bid', 'ask', 'volume', 'delta', 'gamma', 'theta', 'vega', 'rho', 'contractName']})
                    MEMORY[opt['contractName']] = opt
            
            OPTIONS[ticker]['options_chain'][sample['expirationDate']] = pd.DataFrame(list(opt_chain.values()), columns = ["Theta", "Gamma", "Rho", "Vega", "cName", "cDelta", "cVolume", "cBidP", "cTheo", "cAskP", "Strike", "pBidP", "pTheo", "pAskP", "pVolume", "pDelta", 'pName'])
    
    return OPTIONS[ticker]['data']

class OptionFromId:
    def __init__(self, contract_name, memory={}):
        self.contract_name = contract_name
        self.ticker = ""
        self.generate_ticker()

        query_data(self.ticker)

        if memory:
            self.memory = {contract_name: memory}
        else:
            self.memory = MEMORY
        
        self.stock_price = OPTIONS[self.ticker]['lastTradePrice']

        self.opt_type = self.memory[contract_name]['type']
        self.exercise_price =  self.memory[contract_name]['strike']
        self.time_to_expiration =  self.memory[contract_name]['daysBeforeExpiration']

        self.volatility = 0
        self.interest_rate = 0

    def generate_ticker(self):
        for i in self.contract_name:
            if i.isalpha():
                self.ticker += i
            else: break

class OptionByChoice:
    def __init__(self, ticker, opt_type, strike, expiration):
        self.data = query_data(ticker)
        self.strike = strike
        self.expiration = expiration

        opts_date = self.find_opt_date()
        self.opt_data = self.find_opt(opts_date['options'][opt_type])
        self.option = OptionFromId(self.opt_data['contractName'], memory=self.opt_data)

    def find_opt_date(self):
        for opt in self.data:
            if opt["expirationDate"] == self.expiration:
                return opt
        raise KeyError(f"No option with date: {self.expiration}")

    def find_opt(self, opts_datetype):
        for opt in opts_datetype:
            if opt['strike'] == self.strike:
                return opt
        raise KeyError(f"No option with date: {self.expiration}, strike: {self.strike}")

# %%
config = {
    'ticker': "AAPL"
}

# or 

# config = {
#     'ticker': "AAPL",
#     'opt_type': 'CALL',
#     'strike': 170,
#     'expiration': '2022-02-25'
# }

# or

# config = {
#     'id': "AAPL220218C00070000"
# }

class OptionsPricer:
    def __init__(self, config):
        self.config = config
        if {'opt_type', 'strike', 'expiration'}.issubset(set(config.keys())):
            self.option = OptionByChoice(**config).option
        elif 'id' in config.keys():
            self.option = OptionFromId(config['id'])
        else:
            query_data(config['ticker'])
            print("See below expiries, and then `OPTIONS[<ticker>]['options_chain'][<expiry>]` to see options chains")
            print(OPTIONS[config['ticker']]['expiries'])

aapl = OptionsPricer(config)
# aapl.option
# Out:
# See below expiries, and then `OPTIONS[option_chain][<expiry>]` to see options chains
# ['2022-02-18', '2022-02-25', '2022-03-04', '2022-03-11', '2022-03-18', '2022-03-25', '2022-04-01', '2022-04-14', '2022-05-20', '2022-06-17', '2022-07-15', '2022-08-19', '2022-09-16', '2022-10-21', '2022-11-18', '2023-01-20', '2023-03-17', '2023-06-16', '2023-09-15', '2024-01-19']

# %%
OPTIONS["AAPL"]["options_chain"]['2022-03-25']
# Out:
#      Theta   Gamma  Rho    Vega                cName  cDelta  cVolume  cBidP  \
# 0  -0.0106  0.0006    0  0.0112  AAPL220325C00105000  0.9845      NaN  63.75
# 1  -0.0130  0.0009    0  0.0146  AAPL220325C00110000  0.9804     64.0  58.80
# 2  -0.0160  0.0012    0  0.0190  AAPL220325C00115000  0.9848      NaN  53.70
# 3  -0.0176  0.0015    0  0.0226  AAPL220325C00120000  0.9720      NaN  48.90
# 4  -0.0232  0.0022    0  0.0313  AAPL220325C00125000  0.9507      NaN  42.90
# 5  -0.0297  0.0031    0  0.0421  AAPL220325C00130000  0.9655      2.0  38.85
# 6  -0.0379  0.0044    0  0.0566  AAPL220325C00135000  0.9401      NaN  33.30
# 7  -0.0456  0.0061    0  0.0728  AAPL220325C00140000  0.9369      1.0  28.70
# 8  -0.0558  0.0084    0  0.0946  AAPL220325C00145000  0.8883      1.0  24.80
# 9  -0.0676  0.0114    0  0.1212  AAPL220325C00150000  0.8455     40.0  20.30
# 10 -0.0786  0.0150    0  0.1500  AAPL220325C00155000  0.7876      1.0  16.00
# 11 -0.0868  0.0192    0  0.1780  AAPL220325C00160000  0.7093     53.0  12.05
# 12 -0.0916  0.0232    0  0.2004  AAPL220325C00165000  0.6094     41.0   8.55
# 13 -0.0895  0.0257    0  0.2084  AAPL220325C00170000  0.4874    284.0   5.55
# 14 -0.0801  0.0252    0  0.1948  AAPL220325C00175000  0.3531    271.0   3.20
# 15 -0.0541  0.0225    0  0.1499  AAPL220325C00180000  0.2241    264.0   1.69
# 16 -0.0374  0.0156    0  0.1026  AAPL220325C00185000  0.1322    528.0   0.83
# 17 -0.0214  0.0090    0  0.0576  AAPL220325C00190000  0.0761     54.0   0.40
# 18 -0.0075  0.0031    0  0.0174  AAPL220325C00195000  0.0422    316.0   0.20
# 19 -0.0218  0.0054    0  0.0449  AAPL220325C00200000  0.0248     45.0   0.08
# 20 -0.0225  0.0045    0  0.0417  AAPL220325C00205000  0.0140      1.0   0.05
# 21 -0.0197  0.0035    0  0.0340  AAPL220325C00210000  0.0098     25.0   0.02
# 22 -0.0782  0.0059    0  0.0928  AAPL220325C00215000  0.0091     12.0   0.01
# 23 -0.0206  0.0026    0  0.0304  AAPL220325C00220000  0.0085     50.0   0.01
# 24 -0.0209  0.0023    0  0.0289  AAPL220325C00225000  0.0066      1.0   0.01
# 25 -0.0083  0.0010    0  0.0105  AAPL220325C00230000  0.0063      2.0   0.01
# 26 -0.0084  0.0009    0  0.0100  AAPL220325C00235000  0.0019    417.0   0.01
# 27 -0.0257  0.0020    0  0.0297  AAPL220325C00240000  0.0000      2.0   0.01
# 28 -0.0221  0.0016    0  0.0248  AAPL220325C00245000  0.0000      1.0   0.01
# 29 -0.0301  0.0018    0  0.0313  AAPL220325C00250000  0.0000      2.0   0.01
#
#     cTheo  cAskP  Strike  pBidP  pTheo  pAskP  pVolume  pDelta  \
# 0     NaN  64.40     105   0.06    NaN   0.13      4.0 -0.0078
# 1     NaN  59.45     110   0.10    NaN   0.15      4.0 -0.0105
# 2     NaN  54.35     115   0.14    NaN   0.19      1.0 -0.0143
# 3     NaN  49.50     120   0.19    NaN   0.24      3.0 -0.0175
# 4     NaN  46.20     125   0.27    NaN   0.33     13.0 -0.0257
# 5     NaN  39.55     130   0.37    NaN   0.44     16.0 -0.0368
# 6     NaN  35.75     135   0.52    NaN   0.59     16.0 -0.0531
# 7     NaN  30.20     140   0.73    NaN   0.80    190.0 -0.0734
# 8     NaN  25.40     145   1.06    NaN   1.16     50.0 -0.1042
# 9     NaN  20.90     150   1.54    NaN   1.66    225.0 -0.1487
# 10    NaN  16.60     155   2.23    NaN   2.39    381.0 -0.2083
# 11    NaN  12.60     160   3.20    NaN   3.45    133.0 -0.2866
# 12    NaN   8.90     165   4.60    NaN   4.85    403.0 -0.3891
# 13    NaN   5.80     170   6.50    NaN   6.85    217.0 -0.5123
# 14    NaN   3.45     175   9.10    NaN   9.60    120.0 -0.6436
# 15    NaN   1.85     180  12.50    NaN  13.05     21.0 -0.7914
# 16    NaN   0.90     185  16.60    NaN  17.20      7.0 -0.8828
# 17    NaN   0.46     190  21.00    NaN  21.95     50.0 -0.9452
# 18    NaN   0.24     195  25.75    NaN  26.75      1.0 -0.9866
# 19    NaN   0.14     200  30.80    NaN  31.45     11.0 -0.9597
# 20    NaN   0.09     205  35.80    NaN  36.45      5.0 -0.9632
# 21    NaN   0.08     210  40.75    NaN  41.40      NaN -0.9711
# 22    NaN   0.08     215  44.35    NaN  47.55      NaN -0.8980
# 23    NaN   0.07     220  50.75    NaN  51.40      2.0 -0.9747
# 24    NaN   0.07     225  55.75    NaN  56.40      NaN -0.9761
# 25    NaN   0.06     230  60.95    NaN  61.55      NaN -0.9923
# 26    NaN   0.05     235  65.95    NaN  66.55      NaN -0.9926
# 27    NaN   0.06     240  69.85    NaN  71.45      NaN -0.9754
# 28    NaN   0.05     245  75.75    NaN  76.40      NaN -0.9800
# 29    NaN   0.05     250  80.60    NaN  81.50      NaN -0.9738
#
#                   pName
# 0   AAPL220325P00105000
# 1   AAPL220325P00110000
# 2   AAPL220325P00115000
# 3   AAPL220325P00120000
# 4   AAPL220325P00125000
# 5   AAPL220325P00130000
# 6   AAPL220325P00135000
# 7   AAPL220325P00140000
# 8   AAPL220325P00145000
# 9   AAPL220325P00150000
# 10  AAPL220325P00155000
# 11  AAPL220325P00160000
# 12  AAPL220325P00165000
# 13  AAPL220325P00170000
# 14  AAPL220325P00175000
# 15  AAPL220325P00180000
# 16  AAPL220325P00185000
# 17  AAPL220325P00190000
# 18  AAPL220325P00195000
# 19  AAPL220325P00200000
# 20  AAPL220325P00205000
# 21  AAPL220325P00210000
# 22  AAPL220325P00215000
# 23  AAPL220325P00220000
# 24  AAPL220325P00225000
# 25  AAPL220325P00230000
# 26  AAPL220325P00235000
# 27  AAPL220325P00240000
# 28  AAPL220325P00245000
# 29  AAPL220325P00250000

# %%
MEMORY
# Out:
# {'AAPL220218C00070000': {'contractName': 'AAPL220218C00070000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'TRUE',
#   'lastTradeDateTime': '2022-02-14 15:55:06',
#   'expirationDate': '2022-02-18',
#   'strike': 70,
#   'lastPrice': 98.2,
#   'bid': 102.3,
#   'ask': 102.75,
#   'change': -4.23,
#   'changePercent': -0.0413,
#   'volume': 1,
#   'openInterest': 16,
#   'impliedVolatility': 549.0118,
#   'delta': 0.9923,
#   'gamma': 0.0003,
#   'theta': -0.3696,
#   'vega': 0.0027,
#   'rho': 0,
#   'theoretical': 102.75,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00075000': {'contractName': 'AAPL220218C00075000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'TRUE',
#   'lastTradeDateTime': '2022-02-09 14:51:22',
#   'expirationDate': '2022-02-18',
#   'strike': 75,
#   'lastPrice': 100.85,
#   'bid': 97.3,
#   'ask': 97.75,
#   'change': 4.77,
#   'changePercent': 0.0496,
#   'volume': 12,
#   'openInterest': 11,
#   'impliedVolatility': 510.0037,
#   'delta': 0.9917,
#   'gamma': 0.0003,
#   'theta': -0.3668,
#   'vega': 0.0029,
#   'rho': 0,
#   'theoretical': 97.75,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00080000': {'contractName': 'AAPL220218C00080000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'TRUE',
#   'lastTradeDateTime': '2022-02-16 14:44:13',
#   'expirationDate': '2022-02-18',
#   'strike': 80,
#   'lastPrice': 92.1,
#   'bid': 92.3,
#   'ask': 92.75,
#   'change': 0.49,
#   'changePercent': 0.0053,
#   'volume': 1,
#   'openInterest': 4,
#   'impliedVolatility': 473.5204,
#   'delta': 0.9911,
#   'gamma': 0.0004,
#   'theta': -0.3636,
#   'vega': 0.0031,
#   'rho': 0,
#   'theoretical': 92.75,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00085000': {'contractName': 'AAPL220218C00085000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'TRUE',
#   'lastTradeDateTime': '2022-02-15 12:03:51',
#   'expirationDate': '2022-02-18',
#   'strike': 85,
#   'lastPrice': 86.52,
#   'bid': 87.25,
#   'ask': 87.75,
#   'change': -0.49,
#   'changePercent': -0.0056,
#   'volume': 3,
#   'openInterest': 741,
#   'impliedVolatility': 439.23,
#   'delta': 0.9904,
#   'gamma': 0.0005,
#   'theta': -0.3602,
#   'vega': 0.0033,
#   'rho': 0,
#   'theoretical': 87.75,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00090000': {'contractName': 'AAPL220218C00090000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'TRUE',
#   'lastTradeDateTime': '2022-02-16 14:13:44',
#   'expirationDate': '2022-02-18',
#   'strike': 90,
#   'lastPrice': 81.45,
#   'bid': 82.3,
#   'ask': 82.75,
#   'change': -0.79,
#   'changePercent': -0.0096,
#   'volume': 1,
#   'openInterest': 37,
#   'impliedVolatility': 406.8576,
#   'delta': 0.9896,
#   'gamma': 0.0005,
#   'theta': -0.3565,
#   'vega': 0.0035,
#   'rho': 0,
#   'theoretical': 82.75,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00095000': {'contractName': 'AAPL220218C00095000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'TRUE',
#   'lastTradeDateTime': '2022-02-15 12:01:03',
#   'expirationDate': '2022-02-18',
#   'strike': 95,
#   'lastPrice': 76.55,
#   'bid': 77.3,
#   'ask': 77.75,
#   'change': -0.48,
#   'changePercent': -0.0062,
#   'volume': 5,
#   'openInterest': 18,
#   'impliedVolatility': 376.173,
#   'delta': 0.9888,
#   'gamma': 0.0006,
#   'theta': -0.3525,
#   'vega': 0.0038,
#   'rho': 0,
#   'theoretical': 77.75,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00100000': {'contractName': 'AAPL220218C00100000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'TRUE',
#   'lastTradeDateTime': '2022-02-15 15:08:20',
#   'expirationDate': '2022-02-18',
#   'strike': 100,
#   'lastPrice': 71.15,
#   'bid': 72.25,
#   'ask': 72.75,
#   'change': -1.08,
#   'changePercent': -0.015,
#   'volume': 1,
#   'openInterest': 580,
#   'impliedVolatility': 346.9811,
#   'delta': 0.9878,
#   'gamma': 0.0007,
#   'theta': -0.3481,
#   'vega': 0.004,
#   'rho': 0,
#   'theoretical': 72.75,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00105000': {'contractName': 'AAPL220218C00105000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'TRUE',
#   'lastTradeDateTime': '2022-02-15 12:07:58',
#   'expirationDate': '2022-02-18',
#   'strike': 105,
#   'lastPrice': 66.35,
#   'bid': 67.3,
#   'ask': 67.75,
#   'change': -1.07,
#   'changePercent': -0.0159,
#   'volume': 23,
#   'openInterest': 47,
#   'impliedVolatility': 319.1133,
#   'delta': 0.9868,
#   'gamma': 0.0008,
#   'theta': -0.3434,
#   'vega': 0.0043,
#   'rho': 0,
#   'theoretical': 67.75,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00110000': {'contractName': 'AAPL220218C00110000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'TRUE',
#   'lastTradeDateTime': '2022-02-16 14:56:55',
#   'expirationDate': '2022-02-18',
#   'strike': 110,
#   'lastPrice': 62.58,
#   'bid': 62.3,
#   'ask': 62.75,
#   'change': 1.66,
#   'changePercent': 0.0272,
#   'volume': 6,
#   'openInterest': 96,
#   'impliedVolatility': 232.2514,
#   'delta': 0.9966,
#   'gamma': 0.0003,
#   'theta': -0.0744,
#   'vega': 0.0013,
#   'rho': 0,
#   'theoretical': 62.58,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00115000': {'contractName': 'AAPL220218C00115000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'TRUE',
#   'lastTradeDateTime': '2022-02-16 12:35:39',
#   'expirationDate': '2022-02-18',
#   'strike': 115,
#   'lastPrice': 55.29,
#   'bid': 57.3,
#   'ask': 57.75,
#   'change': -1.19,
#   'changePercent': -0.0211,
#   'volume': 2,
#   'openInterest': 225,
#   'impliedVolatility': 266.7818,
#   'delta': 0.9844,
#   'gamma': 0.0012,
#   'theta': -0.3327,
#   'vega': 0.005,
#   'rho': 0,
#   'theoretical': 57.75,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00120000': {'contractName': 'AAPL220218C00120000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'TRUE',
#   'lastTradeDateTime': '2022-02-16 12:01:14',
#   'expirationDate': '2022-02-18',
#   'strike': 120,
#   'lastPrice': 51.2,
#   'bid': 52.3,
#   'ask': 52.75,
#   'change': -0.02,
#   'changePercent': -0.0004,
#   'volume': 7,
#   'openInterest': 598,
#   'impliedVolatility': 242.0721,
#   'delta': 0.9828,
#   'gamma': 0.0014,
#   'theta': -0.3266,
#   'vega': 0.0054,
#   'rho': 0,
#   'theoretical': 52.75,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00125000': {'contractName': 'AAPL220218C00125000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'TRUE',
#   'lastTradeDateTime': '2022-02-16 10:06:48',
#   'expirationDate': '2022-02-18',
#   'strike': 125,
#   'lastPrice': 46.89,
#   'bid': 47.3,
#   'ask': 47.75,
#   'change': 2.56,
#   'changePercent': 0.0577,
#   'volume': 2,
#   'openInterest': 269,
#   'impliedVolatility': 218.1875,
#   'delta': 0.9811,
#   'gamma': 0.0017,
#   'theta': -0.3199,
#   'vega': 0.0059,
#   'rho': 0,
#   'theoretical': 47.75,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00130000': {'contractName': 'AAPL220218C00130000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'TRUE',
#   'lastTradeDateTime': '2022-02-16 11:55:30',
#   'expirationDate': '2022-02-18',
#   'strike': 130,
#   'lastPrice': 40.97,
#   'bid': 42.3,
#   'ask': 42.75,
#   'change': -1.31,
#   'changePercent': -0.031,
#   'volume': 2,
#   'openInterest': 631,
#   'impliedVolatility': 195.028,
#   'delta': 0.979,
#   'gamma': 0.0021,
#   'theta': -0.3125,
#   'vega': 0.0064,
#   'rho': 0,
#   'theoretical': 42.75,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00135000': {'contractName': 'AAPL220218C00135000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'TRUE',
#   'lastTradeDateTime': '2022-02-16 14:11:38',
#   'expirationDate': '2022-02-18',
#   'strike': 135,
#   'lastPrice': 36.7,
#   'bid': 37.3,
#   'ask': 37.75,
#   'change': -0.51,
#   'changePercent': -0.0137,
#   'volume': 8,
#   'openInterest': 208,
#   'impliedVolatility': 172.4961,
#   'delta': 0.9765,
#   'gamma': 0.0025,
#   'theta': -0.3041,
#   'vega': 0.0071,
#   'rho': 0,
#   'theoretical': 37.75,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00140000': {'contractName': 'AAPL220218C00140000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'TRUE',
#   'lastTradeDateTime': '2022-02-16 12:20:44',
#   'expirationDate': '2022-02-18',
#   'strike': 140,
#   'lastPrice': 32.45,
#   'bid': 32.3,
#   'ask': 32.8,
#   'change': -0.05,
#   'changePercent': -0.0015,
#   'volume': 10,
#   'openInterest': 898,
#   'impliedVolatility': 156.4286,
#   'delta': 0.9688,
#   'gamma': 0.0035,
#   'theta': -0.3494,
#   'vega': 0.009,
#   'rho': 0,
#   'theoretical': 32.8,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00141000': {'contractName': 'AAPL220218C00141000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'TRUE',
#   'lastTradeDateTime': '0000-00-00 00:00:00',
#   'expirationDate': '2022-02-18',
#   'strike': 141,
#   'lastPrice': 0,
#   'bid': 31.3,
#   'ask': 31.7,
#   'change': 0,
#   'changePercent': None,
#   'volume': None,
#   'openInterest': None,
#   'impliedVolatility': 139.3986,
#   'delta': 0.9777,
#   'gamma': 0.003,
#   'theta': -0.2344,
#   'vega': 0.0068,
#   'rho': 0,
#   'theoretical': 31.7,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:18:45',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00142000': {'contractName': 'AAPL220218C00142000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'TRUE',
#   'lastTradeDateTime': '0000-00-00 00:00:00',
#   'expirationDate': '2022-02-18',
#   'strike': 142,
#   'lastPrice': 0,
#   'bid': 30.3,
#   'ask': 30.65,
#   'change': 0,
#   'changePercent': None,
#   'volume': None,
#   'openInterest': None,
#   'impliedVolatility': 127.1012,
#   'delta': 0.9829,
#   'gamma': 0.0026,
#   'theta': -0.17,
#   'vega': 0.0054,
#   'rho': 0,
#   'theoretical': 30.65,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:18:45',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00143000': {'contractName': 'AAPL220218C00143000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'TRUE',
#   'lastTradeDateTime': '0000-00-00 00:00:00',
#   'expirationDate': '2022-02-18',
#   'strike': 143,
#   'lastPrice': 0,
#   'bid': 29.3,
#   'ask': 29.65,
#   'change': 0,
#   'changePercent': None,
#   'volume': None,
#   'openInterest': None,
#   'impliedVolatility': 123.1371,
#   'delta': 0.9824,
#   'gamma': 0.0028,
#   'theta': -0.1688,
#   'vega': 0.0055,
#   'rho': 0,
#   'theoretical': 29.65,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:18:45',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00144000': {'contractName': 'AAPL220218C00144000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'TRUE',
#   'lastTradeDateTime': '2022-02-14 00:03:15',
#   'expirationDate': '2022-02-18',
#   'strike': 144,
#   'lastPrice': 30.4,
#   'bid': 28.3,
#   'ask': 28.65,
#   'change': 30.4,
#   'changePercent': None,
#   'volume': 1,
#   'openInterest': 1,
#   'impliedVolatility': 119.1874,
#   'delta': 0.9819,
#   'gamma': 0.0029,
#   'theta': -0.1676,
#   'vega': 0.0057,
#   'rho': 0,
#   'theoretical': 28.65,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00145000': {'contractName': 'AAPL220218C00145000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'TRUE',
#   'lastTradeDateTime': '2022-02-16 15:57:40',
#   'expirationDate': '2022-02-18',
#   'strike': 145,
#   'lastPrice': 27.62,
#   'bid': 27.3,
#   'ask': 27.75,
#   'change': 0.57,
#   'changePercent': 0.0211,
#   'volume': 49,
#   'openInterest': 4077,
#   'impliedVolatility': 109.519,
#   'delta': 0.9857,
#   'gamma': 0.0026,
#   'theta': -0.1259,
#   'vega': 0.0046,
#   'rho': 0,
#   'theoretical': 27.62,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00146000': {'contractName': 'AAPL220218C00146000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'TRUE',
#   'lastTradeDateTime': '2022-02-14 00:03:15',
#   'expirationDate': '2022-02-18',
#   'strike': 146,
#   'lastPrice': 26.8,
#   'bid': 26.3,
#   'ask': 26.75,
#   'change': 26.8,
#   'changePercent': None,
#   'volume': 3,
#   'openInterest': 5,
#   'impliedVolatility': 124.6387,
#   'delta': 0.9684,
#   'gamma': 0.0045,
#   'theta': -0.2813,
#   'vega': 0.0091,
#   'rho': 0,
#   'theoretical': 26.75,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00147000': {'contractName': 'AAPL220218C00147000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'TRUE',
#   'lastTradeDateTime': '2022-02-15 13:18:31',
#   'expirationDate': '2022-02-18',
#   'strike': 147,
#   'lastPrice': 24.18,
#   'bid': 25.3,
#   'ask': 25.75,
#   'change': -0.32,
#   'changePercent': -0.0131,
#   'volume': 7,
#   'openInterest': 5,
#   'impliedVolatility': 120.3744,
#   'delta': 0.9673,
#   'gamma': 0.0047,
#   'theta': -0.2788,
#   'vega': 0.0093,
#   'rho': 0,
#   'theoretical': 25.75,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00148000': {'contractName': 'AAPL220218C00148000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'TRUE',
#   'lastTradeDateTime': '2022-02-16 11:29:27',
#   'expirationDate': '2022-02-18',
#   'strike': 148,
#   'lastPrice': 22.7,
#   'bid': 24.3,
#   'ask': 24.75,
#   'change': -0.68,
#   'changePercent': -0.0291,
#   'volume': 4,
#   'openInterest': 8,
#   'impliedVolatility': 116.1198,
#   'delta': 0.9663,
#   'gamma': 0.0051,
#   'theta': -0.2762,
#   'vega': 0.0096,
#   'rho': 0,
#   'theoretical': 24.75,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00149000': {'contractName': 'AAPL220218C00149000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'TRUE',
#   'lastTradeDateTime': '2022-02-16 09:36:56',
#   'expirationDate': '2022-02-18',
#   'strike': 149,
#   'lastPrice': 22.25,
#   'bid': 23.3,
#   'ask': 23.75,
#   'change': -0.29,
#   'changePercent': -0.0129,
#   'volume': 1,
#   'openInterest': 22,
#   'impliedVolatility': 111.8737,
#   'delta': 0.9651,
#   'gamma': 0.0054,
#   'theta': -0.2735,
#   'vega': 0.0098,
#   'rho': 0,
#   'theoretical': 23.75,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00150000': {'contractName': 'AAPL220218C00150000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'TRUE',
#   'lastTradeDateTime': '2022-02-16 15:52:00',
#   'expirationDate': '2022-02-18',
#   'strike': 150,
#   'lastPrice': 22.8,
#   'bid': 22.35,
#   'ask': 22.7,
#   'change': 0.03,
#   'changePercent': 0.0013,
#   'volume': 218,
#   'openInterest': 14165,
#   'impliedVolatility': 102.2843,
#   'delta': 0.9705,
#   'gamma': 0.0052,
#   'theta': -0.2176,
#   'vega': 0.0086,
#   'rho': 0,
#   'theoretical': 22.7,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00152500': {'contractName': 'AAPL220218C00152500',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'TRUE',
#   'lastTradeDateTime': '2022-02-16 10:02:16',
#   'expirationDate': '2022-02-18',
#   'strike': 152.5,
#   'lastPrice': 19.11,
#   'bid': 19.85,
#   'ask': 20.25,
#   'change': 4.37,
#   'changePercent': 0.2965,
#   'volume': 25,
#   'openInterest': 378,
#   'impliedVolatility': 97.0606,
#   'delta': 0.9604,
#   'gamma': 0.0069,
#   'theta': -0.2632,
#   'vega': 0.0109,
#   'rho': 0,
#   'theoretical': 20.25,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00155000': {'contractName': 'AAPL220218C00155000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'TRUE',
#   'lastTradeDateTime': '2022-02-16 15:59:33',
#   'expirationDate': '2022-02-18',
#   'strike': 155,
#   'lastPrice': 17.8,
#   'bid': 17.35,
#   'ask': 17.75,
#   'change': 0.05,
#   'changePercent': 0.0028,
#   'volume': 280,
#   'openInterest': 8211,
#   'impliedVolatility': 86.4969,
#   'delta': 0.9561,
#   'gamma': 0.0084,
#   'theta': -0.2548,
#   'vega': 0.0119,
#   'rho': 0,
#   'theoretical': 17.75,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00157500': {'contractName': 'AAPL220218C00157500',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'TRUE',
#   'lastTradeDateTime': '2022-02-16 15:50:32',
#   'expirationDate': '2022-02-18',
#   'strike': 157.5,
#   'lastPrice': 15.42,
#   'bid': 14.85,
#   'ask': 15.25,
#   'change': 0.4,
#   'changePercent': 0.0266,
#   'volume': 16,
#   'openInterest': 1459,
#   'impliedVolatility': 75.9111,
#   'delta': 0.9508,
#   'gamma': 0.0105,
#   'theta': -0.2452,
#   'vega': 0.013,
#   'rho': 0,
#   'theoretical': 15.25,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00160000': {'contractName': 'AAPL220218C00160000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'TRUE',
#   'lastTradeDateTime': '2022-02-16 15:57:34',
#   'expirationDate': '2022-02-18',
#   'strike': 160,
#   'lastPrice': 12.51,
#   'bid': 12.35,
#   'ask': 12.7,
#   'change': -0.34,
#   'changePercent': -0.0265,
#   'volume': 690,
#   'openInterest': 28133,
#   'impliedVolatility': 61.5371,
#   'delta': 0.9536,
#   'gamma': 0.0124,
#   'theta': -0.1892,
#   'vega': 0.0124,
#   'rho': 0,
#   'theoretical': 12.7,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00162500': {'contractName': 'AAPL220218C00162500',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'TRUE',
#   'lastTradeDateTime': '2022-02-16 15:55:57',
#   'expirationDate': '2022-02-18',
#   'strike': 162.5,
#   'lastPrice': 10.1,
#   'bid': 9.9,
#   'ask': 10.3,
#   'change': 0.09,
#   'changePercent': 0.009,
#   'volume': 450,
#   'openInterest': 5195,
#   'impliedVolatility': 41.9874,
#   'delta': 0.9743,
#   'gamma': 0.0114,
#   'theta': -0.0786,
#   'vega': 0.0076,
#   'rho': 0,
#   'theoretical': 10.1,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00165000': {'contractName': 'AAPL220218C00165000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'TRUE',
#   'lastTradeDateTime': '2022-02-16 15:59:31',
#   'expirationDate': '2022-02-18',
#   'strike': 165,
#   'lastPrice': 7.6,
#   'bid': 7.45,
#   'ask': 7.8,
#   'change': -0.15,
#   'changePercent': -0.0194,
#   'volume': 3293,
#   'openInterest': 39377,
#   'impliedVolatility': 32.8717,
#   'delta': 0.9681,
#   'gamma': 0.0171,
#   'theta': -0.0736,
#   'vega': 0.0091,
#   'rho': 0,
#   'theoretical': 7.6,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00167500': {'contractName': 'AAPL220218C00167500',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'TRUE',
#   'lastTradeDateTime': '2022-02-16 15:59:33',
#   'expirationDate': '2022-02-18',
#   'strike': 167.5,
#   'lastPrice': 5.4,
#   'bid': 5.15,
#   'ask': 5.45,
#   'change': -0.43,
#   'changePercent': -0.0738,
#   'volume': 2497,
#   'openInterest': 7460,
#   'impliedVolatility': 37.8476,
#   'delta': 0.8586,
#   'gamma': 0.0464,
#   'theta': -0.2692,
#   'vega': 0.0286,
#   'rho': 0,
#   'theoretical': 5.4,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00170000': {'contractName': 'AAPL220218C00170000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'TRUE',
#   'lastTradeDateTime': '2022-02-16 15:59:38',
#   'expirationDate': '2022-02-18',
#   'strike': 170,
#   'lastPrice': 3.15,
#   'bid': 3,
#   'ask': 3.25,
#   'change': -0.5,
#   'changePercent': -0.137,
#   'volume': 34092,
#   'openInterest': 48235,
#   'impliedVolatility': 30.7864,
#   'delta': 0.7466,
#   'gamma': 0.0814,
#   'theta': -0.3131,
#   'vega': 0.0409,
#   'rho': 0,
#   'theoretical': 3.15,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00172500': {'contractName': 'AAPL220218C00172500',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'TRUE',
#   'lastTradeDateTime': '2022-02-16 15:59:59',
#   'expirationDate': '2022-02-18',
#   'strike': 172.5,
#   'lastPrice': 1.38,
#   'bid': 1.33,
#   'ask': 1.38,
#   'change': -0.44,
#   'changePercent': -0.2418,
#   'volume': 89659,
#   'openInterest': 36180,
#   'impliedVolatility': 26.637,
#   'delta': 0.5093,
#   'gamma': 0.1173,
#   'theta': -0.3381,
#   'vega': 0.0509,
#   'rho': 0,
#   'theoretical': 1.38,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00175000': {'contractName': 'AAPL220218C00175000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'FALSE',
#   'lastTradeDateTime': '2022-02-16 15:59:58',
#   'expirationDate': '2022-02-18',
#   'strike': 175,
#   'lastPrice': 0.34,
#   'bid': 0.34,
#   'ask': 0.35,
#   'change': -0.32,
#   'changePercent': -0.4848,
#   'volume': 79843,
#   'openInterest': 87684,
#   'impliedVolatility': 23.0707,
#   'delta': 0.2065,
#   'gamma': 0.0968,
#   'theta': -0.2098,
#   'vega': 0.0364,
#   'rho': 0,
#   'theoretical': 0.34,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00177500': {'contractName': 'AAPL220218C00177500',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'FALSE',
#   'lastTradeDateTime': '2022-02-16 15:59:59',
#   'expirationDate': '2022-02-18',
#   'strike': 177.5,
#   'lastPrice': 0.07,
#   'bid': 0.06,
#   'ask': 0.07,
#   'change': -0.09,
#   'changePercent': -0.5625,
#   'volume': 26249,
#   'openInterest': 43273,
#   'impliedVolatility': 23.7621,
#   'delta': 0.0547,
#   'gamma': 0.0365,
#   'theta': -0.084,
#   'vega': 0.0142,
#   'rho': 0,
#   'theoretical': 0.07,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00180000': {'contractName': 'AAPL220218C00180000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'FALSE',
#   'lastTradeDateTime': '2022-02-16 15:59:35',
#   'expirationDate': '2022-02-18',
#   'strike': 180,
#   'lastPrice': 0.02,
#   'bid': 0.01,
#   'ask': 0.02,
#   'change': -0.03,
#   'changePercent': -0.6,
#   'volume': 16098,
#   'openInterest': 78248,
#   'impliedVolatility': 26.6638,
#   'delta': 0.0165,
#   'gamma': 0.012,
#   'theta': -0.0349,
#   'vega': 0.0052,
#   'rho': 0,
#   'theoretical': 0.02,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00182500': {'contractName': 'AAPL220218C00182500',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'FALSE',
#   'lastTradeDateTime': '2022-02-16 15:57:52',
#   'expirationDate': '2022-02-18',
#   'strike': 182.5,
#   'lastPrice': 0.01,
#   'bid': 0.01,
#   'ask': 0.01,
#   'change': -0.02,
#   'changePercent': -0.6667,
#   'volume': 2469,
#   'openInterest': 13351,
#   'impliedVolatility': 31.1078,
#   'delta': 0.0077,
#   'gamma': 0.0053,
#   'theta': -0.021,
#   'vega': 0.0027,
#   'rho': 0,
#   'theoretical': 0.01,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00185000': {'contractName': 'AAPL220218C00185000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'FALSE',
#   'lastTradeDateTime': '2022-02-16 15:59:55',
#   'expirationDate': '2022-02-18',
#   'strike': 185,
#   'lastPrice': 0.01,
#   'bid': 0.01,
#   'ask': 0.01,
#   'change': -0.02,
#   'changePercent': -0.6667,
#   'volume': 2575,
#   'openInterest': 61758,
#   'impliedVolatility': 37.6564,
#   'delta': 0.0065,
#   'gamma': 0.0038,
#   'theta': -0.0218,
#   'vega': 0.0023,
#   'rho': 0,
#   'theoretical': 0.01,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00187500': {'contractName': 'AAPL220218C00187500',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'FALSE',
#   'lastTradeDateTime': '2022-02-16 15:57:52',
#   'expirationDate': '2022-02-18',
#   'strike': 187.5,
#   'lastPrice': 0.01,
#   'bid': 0.01,
#   'ask': 0.01,
#   'change': 0,
#   'changePercent': 0,
#   'volume': 117,
#   'openInterest': 8817,
#   'impliedVolatility': 43.993,
#   'delta': 0.0056,
#   'gamma': 0.0028,
#   'theta': -0.0225,
#   'vega': 0.002,
#   'rho': 0,
#   'theoretical': 0.01,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00190000': {'contractName': 'AAPL220218C00190000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'FALSE',
#   'lastTradeDateTime': '2022-02-16 15:54:34',
#   'expirationDate': '2022-02-18',
#   'strike': 190,
#   'lastPrice': 0.01,
#   'bid': 0.01,
#   'ask': 0.01,
#   'change': 0,
#   'changePercent': 0,
#   'volume': 350,
#   'openInterest': 33846,
#   'impliedVolatility': 50.1476,
#   'delta': 0.005,
#   'gamma': 0.0022,
#   'theta': -0.0231,
#   'vega': 0.0018,
#   'rho': 0,
#   'theoretical': 0.01,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00192500': {'contractName': 'AAPL220218C00192500',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'FALSE',
#   'lastTradeDateTime': '2022-02-15 15:54:21',
#   'expirationDate': '2022-02-18',
#   'strike': 192.5,
#   'lastPrice': 0.01,
#   'bid': 0.01,
#   'ask': 0.01,
#   'change': 0,
#   'changePercent': 0,
#   'volume': 19,
#   'openInterest': 1158,
#   'impliedVolatility': 0,
#   'delta': 0,
#   'gamma': 0,
#   'theta': 0,
#   'vega': 0,
#   'rho': 0,
#   'theoretical': 0,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00195000': {'contractName': 'AAPL220218C00195000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'FALSE',
#   'lastTradeDateTime': '2022-02-16 15:50:01',
#   'expirationDate': '2022-02-18',
#   'strike': 195,
#   'lastPrice': 0.01,
#   'bid': 0.01,
#   'ask': 0.01,
#   'change': 0,
#   'changePercent': 0,
#   'volume': 6,
#   'openInterest': 13667,
#   'impliedVolatility': 61.9899,
#   'delta': 0.0041,
#   'gamma': 0.0015,
#   'theta': -0.0241,
#   'vega': 0.0016,
#   'rho': 0,
#   'theoretical': 0.01,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00197500': {'contractName': 'AAPL220218C00197500',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'FALSE',
#   'lastTradeDateTime': '2022-02-14 12:04:25',
#   'expirationDate': '2022-02-18',
#   'strike': 197.5,
#   'lastPrice': 0.01,
#   'bid': 0.01,
#   'ask': 0.01,
#   'change': 0,
#   'changePercent': 0,
#   'volume': 1,
#   'openInterest': 762,
#   'impliedVolatility': 0,
#   'delta': 0,
#   'gamma': 0,
#   'theta': 0,
#   'vega': 0,
#   'rho': 0,
#   'theoretical': 0,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00200000': {'contractName': 'AAPL220218C00200000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'FALSE',
#   'lastTradeDateTime': '2022-02-16 15:50:01',
#   'expirationDate': '2022-02-18',
#   'strike': 200,
#   'lastPrice': 0.01,
#   'bid': 0.01,
#   'ask': 0.01,
#   'change': 0,
#   'changePercent': 0,
#   'volume': 126,
#   'openInterest': 24784,
#   'impliedVolatility': 73.299,
#   'delta': 0.0035,
#   'gamma': 0.0011,
#   'theta': -0.0248,
#   'vega': 0.0014,
#   'rho': 0,
#   'theoretical': 0.01,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00202500': {'contractName': 'AAPL220218C00202500',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'FALSE',
#   'lastTradeDateTime': '2022-02-14 09:44:48',
#   'expirationDate': '2022-02-18',
#   'strike': 202.5,
#   'lastPrice': 0.01,
#   'bid': 0.01,
#   'ask': 0.01,
#   'change': 0,
#   'changePercent': 0,
#   'volume': 6,
#   'openInterest': 73,
#   'impliedVolatility': 0,
#   'delta': 0,
#   'gamma': 0,
#   'theta': 0,
#   'vega': 0,
#   'rho': 0,
#   'theoretical': 0,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00205000': {'contractName': 'AAPL220218C00205000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'FALSE',
#   'lastTradeDateTime': '2022-02-16 09:40:48',
#   'expirationDate': '2022-02-18',
#   'strike': 205,
#   'lastPrice': 0.01,
#   'bid': 0.01,
#   'ask': 0.01,
#   'change': 0,
#   'changePercent': 0,
#   'volume': 4,
#   'openInterest': 10247,
#   'impliedVolatility': 84.1497,
#   'delta': 0.0031,
#   'gamma': 0.0009,
#   'theta': -0.0255,
#   'vega': 0.0012,
#   'rho': 0,
#   'theoretical': 0.01,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00207500': {'contractName': 'AAPL220218C00207500',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'FALSE',
#   'lastTradeDateTime': '2022-02-14 00:03:18',
#   'expirationDate': '2022-02-18',
#   'strike': 207.5,
#   'lastPrice': 0.01,
#   'bid': 0.01,
#   'ask': 0.01,
#   'change': 0.01,
#   'changePercent': None,
#   'volume': 15,
#   'openInterest': 13,
#   'impliedVolatility': 0,
#   'delta': 0,
#   'gamma': 0,
#   'theta': 0,
#   'vega': 0,
#   'rho': 0,
#   'theoretical': 0,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00210000': {'contractName': 'AAPL220218C00210000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'FALSE',
#   'lastTradeDateTime': '2022-02-16 10:37:59',
#   'expirationDate': '2022-02-18',
#   'strike': 210,
#   'lastPrice': 0.01,
#   'bid': 0.01,
#   'ask': 0.01,
#   'change': 0,
#   'changePercent': 0,
#   'volume': 10,
#   'openInterest': 15961,
#   'impliedVolatility': 94.5951,
#   'delta': 0.0028,
#   'gamma': 0.0007,
#   'theta': -0.026,
#   'vega': 0.0011,
#   'rho': 0,
#   'theoretical': 0.01,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00215000': {'contractName': 'AAPL220218C00215000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'FALSE',
#   'lastTradeDateTime': '2022-02-16 11:18:00',
#   'expirationDate': '2022-02-18',
#   'strike': 215,
#   'lastPrice': 0.01,
#   'bid': 0.01,
#   'ask': 0.01,
#   'change': 0,
#   'changePercent': 0,
#   'volume': 4,
#   'openInterest': 3017,
#   'impliedVolatility': 104.6758,
#   'delta': 0.0026,
#   'gamma': 0.0006,
#   'theta': -0.0265,
#   'vega': 0.001,
#   'rho': 0,
#   'theoretical': 0.01,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00220000': {'contractName': 'AAPL220218C00220000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'FALSE',
#   'lastTradeDateTime': '2022-02-15 15:33:30',
#   'expirationDate': '2022-02-18',
#   'strike': 220,
#   'lastPrice': 0.01,
#   'bid': 0.01,
#   'ask': 0.01,
#   'change': 0,
#   'changePercent': 0,
#   'volume': 6,
#   'openInterest': 3707,
#   'impliedVolatility': 0,
#   'delta': 0,
#   'gamma': 0,
#   'theta': 0,
#   'vega': 0,
#   'rho': 0,
#   'theoretical': 0,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00225000': {'contractName': 'AAPL220218C00225000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'FALSE',
#   'lastTradeDateTime': '2022-02-11 09:55:33',
#   'expirationDate': '2022-02-18',
#   'strike': 225,
#   'lastPrice': 0.01,
#   'bid': 0.01,
#   'ask': 0.01,
#   'change': 0,
#   'changePercent': 0,
#   'volume': 3,
#   'openInterest': 3013,
#   'impliedVolatility': 0,
#   'delta': 0,
#   'gamma': 0,
#   'theta': 0,
#   'vega': 0,
#   'rho': 0,
#   'theoretical': 0,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00230000': {'contractName': 'AAPL220218C00230000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'FALSE',
#   'lastTradeDateTime': '2022-02-09 15:03:17',
#   'expirationDate': '2022-02-18',
#   'strike': 230,
#   'lastPrice': 0.01,
#   'bid': 0.01,
#   'ask': 0.01,
#   'change': 0,
#   'changePercent': 0,
#   'volume': 1,
#   'openInterest': 2809,
#   'impliedVolatility': 0,
#   'delta': 0,
#   'gamma': 0,
#   'theta': 0,
#   'vega': 0,
#   'rho': 0,
#   'theoretical': 0,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00235000': {'contractName': 'AAPL220218C00235000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'FALSE',
#   'lastTradeDateTime': '2022-02-10 09:54:18',
#   'expirationDate': '2022-02-18',
#   'strike': 235,
#   'lastPrice': 0.01,
#   'bid': 0.01,
#   'ask': 0.01,
#   'change': 0,
#   'changePercent': 0,
#   'volume': 1,
#   'openInterest': 1314,
#   'impliedVolatility': 0,
#   'delta': 0,
#   'gamma': 0,
#   'theta': 0,
#   'vega': 0,
#   'rho': 0,
#   'theoretical': 0,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00240000': {'contractName': 'AAPL220218C00240000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'FALSE',
#   'lastTradeDateTime': '2022-02-07 13:36:36',
#   'expirationDate': '2022-02-18',
#   'strike': 240,
#   'lastPrice': 0.01,
#   'bid': 0.01,
#   'ask': 0.01,
#   'change': 0,
#   'changePercent': 0,
#   'volume': 115,
#   'openInterest': 994,
#   'impliedVolatility': 0,
#   'delta': 0,
#   'gamma': 0,
#   'theta': 0,
#   'vega': 0,
#   'rho': 0,
#   'theoretical': 0,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00245000': {'contractName': 'AAPL220218C00245000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'FALSE',
#   'lastTradeDateTime': '2022-02-08 11:37:36',
#   'expirationDate': '2022-02-18',
#   'strike': 245,
#   'lastPrice': 0.01,
#   'bid': 0.01,
#   'ask': 0.01,
#   'change': 0,
#   'changePercent': 0,
#   'volume': 15,
#   'openInterest': 1792,
#   'impliedVolatility': 0,
#   'delta': 0,
#   'gamma': 0,
#   'theta': 0,
#   'vega': 0,
#   'rho': 0,
#   'theoretical': 0,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00250000': {'contractName': 'AAPL220218C00250000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'FALSE',
#   'lastTradeDateTime': '2022-02-09 15:54:03',
#   'expirationDate': '2022-02-18',
#   'strike': 250,
#   'lastPrice': 0.01,
#   'bid': 0.01,
#   'ask': 0.01,
#   'change': 0,
#   'changePercent': 0,
#   'volume': 1,
#   'openInterest': 2073,
#   'impliedVolatility': 0,
#   'delta': 0,
#   'gamma': 0,
#   'theta': 0,
#   'vega': 0,
#   'rho': 0,
#   'theoretical': 0,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00255000': {'contractName': 'AAPL220218C00255000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'FALSE',
#   'lastTradeDateTime': '2022-01-31 15:56:16',
#   'expirationDate': '2022-02-18',
#   'strike': 255,
#   'lastPrice': 0.01,
#   'bid': 0.01,
#   'ask': 0.01,
#   'change': -0.02,
#   'changePercent': -0.6667,
#   'volume': 234,
#   'openInterest': 1865,
#   'impliedVolatility': 0,
#   'delta': 0,
#   'gamma': 0,
#   'theta': 0,
#   'vega': 0,
#   'rho': 0,
#   'theoretical': 0,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00260000': {'contractName': 'AAPL220218C00260000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'FALSE',
#   'lastTradeDateTime': '2022-02-09 14:58:48',
#   'expirationDate': '2022-02-18',
#   'strike': 260,
#   'lastPrice': 0.01,
#   'bid': 0.01,
#   'ask': 0.01,
#   'change': 0,
#   'changePercent': 0,
#   'volume': 1,
#   'openInterest': 4924,
#   'impliedVolatility': 0,
#   'delta': 0,
#   'gamma': 0,
#   'theta': 0,
#   'vega': 0,
#   'rho': 0,
#   'theoretical': 0,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00265000': {'contractName': 'AAPL220218C00265000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'FALSE',
#   'lastTradeDateTime': '2022-01-31 15:54:13',
#   'expirationDate': '2022-02-18',
#   'strike': 265,
#   'lastPrice': 0.01,
#   'bid': 0.01,
#   'ask': 0.01,
#   'change': 0,
#   'changePercent': 0,
#   'volume': 503,
#   'openInterest': 1115,
#   'impliedVolatility': 0,
#   'delta': 0,
#   'gamma': 0,
#   'theta': 0,
#   'vega': 0,
#   'rho': 0,
#   'theoretical': 0,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00270000': {'contractName': 'AAPL220218C00270000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'FALSE',
#   'lastTradeDateTime': '2022-02-14 09:32:06',
#   'expirationDate': '2022-02-18',
#   'strike': 270,
#   'lastPrice': 0.01,
#   'bid': 0.01,
#   'ask': 0.01,
#   'change': 0,
#   'changePercent': 0,
#   'volume': 5,
#   'openInterest': 803,
#   'impliedVolatility': 0,
#   'delta': 0,
#   'gamma': 0,
#   'theta': 0,
#   'vega': 0,
#   'rho': 0,
#   'theoretical': 0,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00275000': {'contractName': 'AAPL220218C00275000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'FALSE',
#   'lastTradeDateTime': '2022-02-15 09:30:05',
#   'expirationDate': '2022-02-18',
#   'strike': 275,
#   'lastPrice': 0.01,
#   'bid': 0.01,
#   'ask': 0.01,
#   'change': 0,
#   'changePercent': 0,
#   'volume': 1,
#   'openInterest': 4106,
#   'impliedVolatility': 0,
#   'delta': 0,
#   'gamma': 0,
#   'theta': 0,
#   'vega': 0,
#   'rho': 0,
#   'theoretical': 0,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218P00070000': {'contractName': 'AAPL220218P00070000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'PUT',
#   'inTheMoney': 'FALSE',
#   'lastTradeDateTime': '2022-02-14 14:48:34',
#   'expirationDate': '2022-02-18',
#   'strike': 70,
#   'lastPrice': 0.01,
#   'bid': 0.01,
#   'ask': 0.01,
#   'change': 0,
#   'changePercent': 0,
#   'volume': 17,
#   'openInterest': 1430,
#   'impliedVolatility': 0,
#   'delta': 0,
#   'gamma': 0,
#   'theta': 0,
#   'vega': 0,
#   'rho': 0,
#   'theoretical': 0,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218P00075000': {'contractName': 'AAPL220218P00075000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'PUT',
#   'inTheMoney': 'FALSE',
#   'lastTradeDateTime': '2022-01-31 10:03:01',
#   'expirationDate': '2022-02-18',
#   'strike': 75,
#   'lastPrice': 0.01,
#   'bid': 0.01,
#   'ask': 0.01,
#   'change': 0,
#   'changePercent': 0,
#   'volume': 722,
#   'openInterest': 5662,
#   'impliedVolatility': 0,
#   'delta': 0,
#   'gamma': 0,
#   'theta': 0,
#   'vega': 0,
#   'rho': 0,
#   'theoretical': 0,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218P00080000': {'contractName': 'AAPL220218P00080000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'PUT',
#   'inTheMoney': 'FALSE',
#   'lastTradeDateTime': '2022-02-09 12:02:11',
#   'expirationDate': '2022-02-18',
#   'strike': 80,
#   'lastPrice': 0.01,
#   'bid': 0.01,
#   'ask': 0.01,
#   'change': 0,
#   'changePercent': 0,
#   'volume': 1,
#   'openInterest': 1946,
#   'impliedVolatility': 0,
#   'delta': 0,
#   'gamma': 0,
#   'theta': 0,
#   'vega': 0,
#   'rho': 0,
#   'theoretical': 0,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218P00085000': {'contractName': 'AAPL220218P00085000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'PUT',
#   'inTheMoney': 'FALSE',
#   'lastTradeDateTime': '2022-02-14 09:56:15',
#   'expirationDate': '2022-02-18',
#   'strike': 85,
#   'lastPrice': 0.01,
#   'bid': 0.01,
#   'ask': 0.01,
#   'change': 0,
#   'changePercent': 0,
#   'volume': 1,
#   'openInterest': 1204,
#   'impliedVolatility': 0,
#   'delta': 0,
#   'gamma': 0,
#   'theta': 0,
#   'vega': 0,
#   'rho': 0,
#   'theoretical': 0,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218P00090000': {'contractName': 'AAPL220218P00090000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'PUT',
#   'inTheMoney': 'FALSE',
#   'lastTradeDateTime': '2022-02-11 14:36:29',
#   'expirationDate': '2022-02-18',
#   'strike': 90,
#   'lastPrice': 0.01,
#   'bid': 0.01,
#   'ask': 0.01,
#   'change': 0,
#   'changePercent': 0,
#   'volume': 1,
#   'openInterest': 2286,
#   'impliedVolatility': 0,
#   'delta': 0,
#   'gamma': 0,
#   'theta': 0,
#   'vega': 0,
#   'rho': 0,
#   'theoretical': 0,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218P00095000': {'contractName': 'AAPL220218P00095000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'PUT',
#   'inTheMoney': 'FALSE',
#   'lastTradeDateTime': '2022-02-04 13:51:27',
#   'expirationDate': '2022-02-18',
#   'strike': 95,
#   'lastPrice': 0.01,
#   'bid': 0.01,
#   'ask': 0.01,
#   'change': 0,
#   'changePercent': 0,
#   'volume': 45,
#   'openInterest': 996,
#   'impliedVolatility': 0,
#   'delta': 0,
#   'gamma': 0,
#   'theta': 0,
#   'vega': 0,
#   'rho': 0,
#   'theoretical': 0,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218P00100000': {'contractName': 'AAPL220218P00100000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'PUT',
#   'inTheMoney': 'FALSE',
#   'lastTradeDateTime': '2022-02-15 11:05:51',
#   'expirationDate': '2022-02-18',
#   'strike': 100,
#   'lastPrice': 0.01,
#   'bid': 0.01,
#   'ask': 0.01,
#   'change': 0,
#   'changePercent': 0,
#   'volume': 100,
#   'openInterest': 4305,
#   'impliedVolatility': 0,
#   'delta': 0,
#   'gamma': 0,
#   'theta': 0,
#   'vega': 0,
#   'rho': 0,
#   'theoretical': 0,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218P00105000': {'contractName': 'AAPL220218P00105000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'PUT',
#   'inTheMoney': 'FALSE',
#   'lastTradeDateTime': '2022-02-15 10:14:34',
#   'expirationDate': '2022-02-18',
#   'strike': 105,
#   'lastPrice': 0.01,
#   'bid': 0.01,
#   'ask': 0.01,
#   'change': 0,
#   'changePercent': 0,
#   'volume': 1,
#   'openInterest': 4975,
#   'impliedVolatility': 0,
#   'delta': 0,
#   'gamma': 0,
#   'theta': 0,
#   'vega': 0,
#   'rho': 0,
#   'theoretical': 0,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218P00110000': {'contractName': 'AAPL220218P00110000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'PUT',
#   'inTheMoney': 'FALSE',
#   'lastTradeDateTime': '2022-02-14 11:10:33',
#   'expirationDate': '2022-02-18',
#   'strike': 110,
#   'lastPrice': 0.01,
#   'bid': 0.01,
#   'ask': 0.01,
#   'change': 0,
#   'changePercent': 0,
#   'volume': 12,
#   'openInterest': 6376,
#   'impliedVolatility': 0,
#   'delta': 0,
#   'gamma': 0,
#   'theta': 0,
#   'vega': 0,
#   'rho': 0,
#   'theoretical': 0,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218P00115000': {'contractName': 'AAPL220218P00115000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'PUT',
#   'inTheMoney': 'FALSE',
#   'lastTradeDateTime': '2022-02-15 11:23:47',
#   'expirationDate': '2022-02-18',
#   'strike': 115,
#   'lastPrice': 0.01,
#   'bid': 0.01,
#   'ask': 0.01,
#   'change': 0,
#   'changePercent': 0,
#   'volume': 2,
#   'openInterest': 9435,
#   'impliedVolatility': 0,
#   'delta': 0,
#   'gamma': 0,
#   'theta': 0,
#   'vega': 0,
#   'rho': 0,
#   'theoretical': 0,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218P00120000': {'contractName': 'AAPL220218P00120000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'PUT',
#   'inTheMoney': 'FALSE',
#   'lastTradeDateTime': '2022-02-16 15:25:27',
#   'expirationDate': '2022-02-18',
#   'strike': 120,
#   'lastPrice': 0.01,
#   'bid': 0.01,
#   'ask': 0.01,
#   'change': 0,
#   'changePercent': 0,
#   'volume': 3,
#   'openInterest': 12590,
#   'impliedVolatility': 169.4963,
#   'delta': -0.0016,
#   'gamma': 0.0002,
#   'theta': -0.0273,
#   'vega': 0.0006,
#   'rho': 0,
# ...
#   'lastTradeDateTime': '2022-01-11 11:35:00',
#   'expirationDate': '2022-07-15',
#   'strike': 70,
#   'lastPrice': 104.1,
#   'bid': 102.4,
#   'ask': 103.05,
#   'change': 4.45,
#   'changePercent': 0.0447,
#   'volume': 3,
#   'openInterest': 135,
#   'impliedVolatility': 68.5658,
#   'delta': 0.9898,
#   'gamma': 0.0004,
#   'theta': -0.0056,
#   'vega': 0.0278,
#   'rho': 0,
#   'theoretical': 102.725,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:19',
#   'daysBeforeExpiration': 148},
#  'AAPL220715C00075000': {'contractName': 'AAPL220715C00075000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'TRUE',
#   'lastTradeDateTime': '2022-02-03 12:10:49',
#   'expirationDate': '2022-07-15',
#   'strike': 75,
#   'lastPrice': 99.75,
#   'bid': 97.55,
#   'ask': 98.1,
#   'change': 0.8,
#   'changePercent': 0.0081,
#   'volume': 200,
#   'openInterest': 81,
#   'impliedVolatility': 66.7579,
#   'delta': 0.9859,
#   'gamma': 0.0005,
#   'theta': -0.0075,
#   'vega': 0.0373,
#   'rho': 0,
#   'theoretical': 97.825,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:19',
#   'daysBeforeExpiration': 148},
#  'AAPL220715C00080000': {'contractName': 'AAPL220715C00080000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'TRUE',
#   'lastTradeDateTime': '2022-02-02 15:26:42',
#   'expirationDate': '2022-07-15',
#   'strike': 80,
#   'lastPrice': 95.6,
#   'bid': 92.6,
#   'ask': 93.2,
#   'change': 5.4,
#   'changePercent': 0.0599,
#   'volume': 276,
#   'openInterest': 282,
#   'impliedVolatility': 63.8418,
#   'delta': 0.9824,
#   'gamma': 0.0006,
#   'theta': -0.0088,
#   'vega': 0.0455,
#   'rho': 0,
#   'theoretical': 92.9,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:19',
#   'daysBeforeExpiration': 148},
#  'AAPL220715C00085000': {'contractName': 'AAPL220715C00085000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'TRUE',
#   'lastTradeDateTime': '2022-02-03 15:17:23',
#   'expirationDate': '2022-07-15',
#   'strike': 85,
#   'lastPrice': 90.1,
#   'bid': 87.7,
#   'ask': 88.45,
#   'change': 0.1,
#   'changePercent': 0.0011,
#   'volume': 27,
#   'openInterest': 62,
#   'impliedVolatility': 62.5903,
#   'delta': 0.9764,
#   'gamma': 0.0008,
#   'theta': -0.0113,
#   'vega': 0.059,
#   'rho': 0,
#   'theoretical': 88.075,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:19',
#   'daysBeforeExpiration': 148},
#  'AAPL220715C00090000': {'contractName': 'AAPL220715C00090000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'TRUE',
#   'lastTradeDateTime': '2022-01-31 11:02:59',
#   'expirationDate': '2022-07-15',
#   'strike': 90,
#   'lastPrice': 83.59,
#   'bid': 82.45,
#   'ask': 83.55,
#   'change': 16.68,
#   'changePercent': 0.2493,
#   'volume': 2,
#   'openInterest': 14,
#   'impliedVolatility': 56.8894,
#   'delta': 0.9767,
#   'gamma': 0.0009,
#   'theta': -0.0101,
#   'vega': 0.0582,
#   'rho': 0,
#   'theoretical': 83,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:19',
#   'daysBeforeExpiration': 148},
#  'AAPL220715C00095000': {'contractName': 'AAPL220715C00095000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'TRUE',
#   'lastTradeDateTime': '2022-02-16 10:13:15',
#   'expirationDate': '2022-07-15',
#   'strike': 95,
#   'lastPrice': 76.34,
#   'bid': 77.85,
#   'ask': 78.5,
#   'change': 1.83,
#   'changePercent': 0.0246,
#   'volume': 8,
#   'openInterest': 210,
#   'impliedVolatility': 55.324,
#   'delta': 0.9698,
#   'gamma': 0.0011,
#   'theta': -0.0125,
#   'vega': 0.073,
#   'rho': 0,
#   'theoretical': 78.175,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:19',
#   'daysBeforeExpiration': 148},
#  'AAPL220715C00100000': {'contractName': 'AAPL220715C00100000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'TRUE',
#   'lastTradeDateTime': '2022-02-10 13:19:06',
#   'expirationDate': '2022-07-15',
#   'strike': 100,
#   'lastPrice': 74.15,
#   'bid': 73,
#   'ask': 73.6,
#   'change': -2.26,
#   'changePercent': -0.0296,
#   'volume': 1,
#   'openInterest': 151,
#   'impliedVolatility': 52.7415,
#   'delta': 0.9638,
#   'gamma': 0.0014,
#   'theta': -0.0139,
#   'vega': 0.0849,
#   'rho': 0,
#   'theoretical': 73.3,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:19',
#   'daysBeforeExpiration': 148},
#  'AAPL220715C00105000': {'contractName': 'AAPL220715C00105000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'TRUE',
#   'lastTradeDateTime': '2022-02-11 15:53:11',
#   'expirationDate': '2022-07-15',
#   'strike': 105,
#   'lastPrice': 69.78,
#   'bid': 68.05,
#   'ask': 68.7,
#   'change': 2.62,
#   'changePercent': 0.039,
#   'volume': 3,
#   'openInterest': 64,
#   'impliedVolatility': 49.5259,
#   'delta': 0.9589,
#   'gamma': 0.0016,
#   'theta': -0.0146,
#   'vega': 0.0944,
#   'rho': 0,
#   'theoretical': 68.375,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:19',
#   'daysBeforeExpiration': 148},
#  'AAPL220715C00110000': {'contractName': 'AAPL220715C00110000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'TRUE',
#   'lastTradeDateTime': '2022-02-14 15:46:24',
#   'expirationDate': '2022-07-15',
#   'strike': 110,
#   'lastPrice': 60,
#   'bid': 63.05,
#   'ask': 64.25,
#   'change': -6.26,
#   'changePercent': -0.0945,
#   'volume': 2,
#   'openInterest': 158,
#   'impliedVolatility': 48.1637,
#   'delta': 0.9474,
#   'gamma': 0.002,
#   'theta': -0.0175,
#   'vega': 0.1158,
#   'rho': 0,
#   'theoretical': 63.65,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:19',
#   'daysBeforeExpiration': 148},
#  'AAPL220715C00115000': {'contractName': 'AAPL220715C00115000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'TRUE',
#   'lastTradeDateTime': '2022-02-15 15:30:28',
#   'expirationDate': '2022-07-15',
#   'strike': 115,
#   'lastPrice': 58.5,
#   'bid': 58.2,
#   'ask': 59.15,
#   'change': 0.3,
#   'changePercent': 0.0052,
#   'volume': 4,
#   'openInterest': 67,
#   'impliedVolatility': 44.4419,
#   'delta': 0.9423,
#   'gamma': 0.0024,
#   'theta': -0.0173,
#   'vega': 0.1247,
#   'rho': 0,
#   'theoretical': 58.675,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:19',
#   'daysBeforeExpiration': 148},
#  'AAPL220715C00120000': {'contractName': 'AAPL220715C00120000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'TRUE',
#   'lastTradeDateTime': '2022-02-15 14:41:54',
#   'expirationDate': '2022-07-15',
#   'strike': 120,
#   'lastPrice': 53.65,
#   'bid': 53.9,
#   'ask': 54.4,
#   'change': 2.95,
#   'changePercent': 0.0582,
#   'volume': 18,
#   'openInterest': 93,
#   'impliedVolatility': 43.939,
#   'delta': 0.9244,
#   'gamma': 0.003,
#   'theta': -0.0215,
#   'vega': 0.1543,
#   'rho': 0,
#   'theoretical': 54.15,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:19',
#   'daysBeforeExpiration': 148},
#  'AAPL220715C00125000': {'contractName': 'AAPL220715C00125000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'TRUE',
#   'lastTradeDateTime': '2022-02-11 13:41:22',
#   'expirationDate': '2022-07-15',
#   'strike': 125,
#   'lastPrice': 47.3,
#   'bid': 49.25,
#   'ask': 49.7,
#   'change': -3.99,
#   'changePercent': -0.0778,
#   'volume': 1,
#   'openInterest': 170,
#   'impliedVolatility': 41.9443,
#   'delta': 0.9095,
#   'gamma': 0.0035,
#   'theta': -0.0236,
#   'vega': 0.177,
#   'rho': 0,
#   'theoretical': 49.475,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:19',
#   'daysBeforeExpiration': 148},
#  'AAPL220715C00130000': {'contractName': 'AAPL220715C00130000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'TRUE',
#   'lastTradeDateTime': '2022-02-16 11:19:07',
#   'expirationDate': '2022-07-15',
#   'strike': 130,
#   'lastPrice': 43.24,
#   'bid': 44.7,
#   'ask': 45.15,
#   'change': -1.06,
#   'changePercent': -0.0239,
#   'volume': 2,
#   'openInterest': 193,
#   'impliedVolatility': 40.3138,
#   'delta': 0.8899,
#   'gamma': 0.0043,
#   'theta': -0.0264,
#   'vega': 0.2047,
#   'rho': 0,
#   'theoretical': 44.925,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:19',
#   'daysBeforeExpiration': 148},
#  'AAPL220715C00135000': {'contractName': 'AAPL220715C00135000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'TRUE',
#   'lastTradeDateTime': '2022-02-15 14:58:04',
#   'expirationDate': '2022-07-15',
#   'strike': 135,
#   'lastPrice': 40,
#   'bid': 40.25,
#   'ask': 40.65,
#   'change': 3.97,
#   'changePercent': 0.1102,
#   'volume': 1,
#   'openInterest': 358,
#   'impliedVolatility': 38.6588,
#   'delta': 0.8672,
#   'gamma': 0.0051,
#   'theta': -0.029,
#   'vega': 0.2339,
#   'rho': 0,
#   'theoretical': 40.45,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:19',
#   'daysBeforeExpiration': 148},
#  'AAPL220715C00140000': {'contractName': 'AAPL220715C00140000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'TRUE',
#   'lastTradeDateTime': '2022-02-15 14:48:39',
#   'expirationDate': '2022-07-15',
#   'strike': 140,
#   'lastPrice': 35.75,
#   'bid': 35.9,
#   'ask': 36.3,
#   'change': 2.3,
#   'changePercent': 0.0688,
#   'volume': 1,
#   'openInterest': 1185,
#   'impliedVolatility': 37.1275,
#   'delta': 0.8402,
#   'gamma': 0.006,
#   'theta': -0.0318,
#   'vega': 0.2652,
#   'rho': 0,
#   'theoretical': 36.1,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:19',
#   'daysBeforeExpiration': 148},
#  'AAPL220715C00145000': {'contractName': 'AAPL220715C00145000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'TRUE',
#   'lastTradeDateTime': '2022-02-16 15:14:37',
#   'expirationDate': '2022-07-15',
#   'strike': 145,
#   'lastPrice': 32.39,
#   'bid': 31.75,
#   'ask': 32.05,
#   'change': 0.54,
#   'changePercent': 0.017,
#   'volume': 24,
#   'openInterest': 787,
#   'impliedVolatility': 35.7075,
#   'delta': 0.8081,
#   'gamma': 0.007,
#   'theta': -0.0345,
#   'vega': 0.2983,
#   'rho': 0,
#   'theoretical': 31.9,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:19',
#   'daysBeforeExpiration': 148},
#  'AAPL220715C00150000': {'contractName': 'AAPL220715C00150000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'TRUE',
#   'lastTradeDateTime': '2022-02-16 15:04:32',
#   'expirationDate': '2022-07-15',
#   'strike': 150,
#   'lastPrice': 26.22,
#   'bid': 27.7,
#   'ask': 28.05,
#   'change': -1.33,
#   'changePercent': -0.0483,
#   'volume': 2,
#   'openInterest': 3354,
#   'impliedVolatility': 34.3811,
#   'delta': 0.7706,
#   'gamma': 0.008,
#   'theta': -0.0371,
#   'vega': 0.3315,
#   'rho': 0,
#   'theoretical': 27.875,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:19',
#   'daysBeforeExpiration': 148},
#  'AAPL220715C00155000': {'contractName': 'AAPL220715C00155000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'TRUE',
#   'lastTradeDateTime': '2022-02-16 10:09:46',
#   'expirationDate': '2022-07-15',
#   'strike': 155,
#   'lastPrice': 22.72,
#   'bid': 23.9,
#   'ask': 24.2,
#   'change': -0.93,
#   'changePercent': -0.0393,
#   'volume': 2,
#   'openInterest': 1066,
#   'impliedVolatility': 33.1287,
#   'delta': 0.7273,
#   'gamma': 0.0091,
#   'theta': -0.0393,
#   'vega': 0.3637,
#   'rho': 0,
#   'theoretical': 24.05,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:19',
#   'daysBeforeExpiration': 148},
#  'AAPL220715C00160000': {'contractName': 'AAPL220715C00160000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'TRUE',
#   'lastTradeDateTime': '2022-02-16 15:50:07',
#   'expirationDate': '2022-07-15',
#   'strike': 160,
#   'lastPrice': 20.84,
#   'bid': 20.3,
#   'ask': 20.6,
#   'change': 0.74,
#   'changePercent': 0.0368,
#   'volume': 26,
#   'openInterest': 2181,
#   'impliedVolatility': 31.9325,
#   'delta': 0.6784,
#   'gamma': 0.0102,
#   'theta': -0.041,
#   'vega': 0.3925,
#   'rho': 0,
#   'theoretical': 20.45,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:19',
#   'daysBeforeExpiration': 148},
#  'AAPL220715C00165000': {'contractName': 'AAPL220715C00165000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'TRUE',
#   'lastTradeDateTime': '2022-02-16 15:43:30',
#   'expirationDate': '2022-07-15',
#   'strike': 165,
#   'lastPrice': 17.45,
#   'bid': 17,
#   'ask': 17.3,
#   'change': 0.45,
#   'changePercent': 0.0265,
#   'volume': 20,
#   'openInterest': 2122,
#   'impliedVolatility': 30.8993,
#   'delta': 0.6238,
#   'gamma': 0.0112,
#   'theta': -0.0422,
#   'vega': 0.4159,
#   'rho': 0,
#   'theoretical': 17.15,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:19',
#   'daysBeforeExpiration': 148},
#  'AAPL220715C00170000': {'contractName': 'AAPL220715C00170000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'TRUE',
#   'lastTradeDateTime': '2022-02-16 15:03:29',
#   'expirationDate': '2022-07-15',
#   'strike': 170,
#   'lastPrice': 14.53,
#   'bid': 14,
#   'ask': 14.25,
#   'change': 0.23,
#   'changePercent': 0.0161,
#   'volume': 45,
#   'openInterest': 2606,
#   'impliedVolatility': 29.891,
#   'delta': 0.5646,
#   'gamma': 0.012,
#   'theta': -0.0424,
#   'vega': 0.4316,
#   'rho': 0,
#   'theoretical': 14.125,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:19',
#   'daysBeforeExpiration': 148},
#  'AAPL220715C00175000': {'contractName': 'AAPL220715C00175000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'FALSE',
#   'lastTradeDateTime': '2022-02-16 15:42:36',
#   'expirationDate': '2022-07-15',
#   'strike': 175,
#   'lastPrice': 11.75,
#   'bid': 11.35,
#   'ask': 11.6,
#   'change': 0.95,
#   'changePercent': 0.088,
#   'volume': 45,
#   'openInterest': 3731,
#   'impliedVolatility': 29.0849,
#   'delta': 0.5021,
#   'gamma': 0.0125,
#   'theta': -0.0419,
#   'vega': 0.4375,
#   'rho': 0,
#   'theoretical': 11.475,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:19',
#   'daysBeforeExpiration': 148},
#  'AAPL220715C00180000': {'contractName': 'AAPL220715C00180000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'FALSE',
#   'lastTradeDateTime': '2022-02-16 15:54:44',
#   'expirationDate': '2022-07-15',
#   'strike': 180,
#   'lastPrice': 9.1,
#   'bid': 8.95,
#   'ask': 9.2,
#   'change': -0.1,
#   'changePercent': -0.0109,
#   'volume': 13,
#   'openInterest': 3837,
#   'impliedVolatility': 28.2154,
#   'delta': 0.4376,
#   'gamma': 0.0127,
#   'theta': -0.0403,
#   'vega': 0.4323,
#   'rho': 0,
#   'theoretical': 9.1,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:19',
#   'daysBeforeExpiration': 148},
#  'AAPL220715C00185000': {'contractName': 'AAPL220715C00185000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'FALSE',
#   'lastTradeDateTime': '2022-02-16 14:30:01',
#   'expirationDate': '2022-07-15',
#   'strike': 185,
#   'lastPrice': 7.2,
#   'bid': 7,
#   'ask': 7.2,
#   'change': 0.13,
#   'changePercent': 0.0184,
#   'volume': 88,
#   'openInterest': 2880,
#   'impliedVolatility': 27.7421,
#   'delta': 0.3753,
#   'gamma': 0.0124,
#   'theta': -0.0382,
#   'vega': 0.4162,
#   'rho': 0,
#   'theoretical': 7.2,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:19',
#   'daysBeforeExpiration': 148},
#  ...}

# %%
aapl.option.exercise_price
# Out:
# 70

# %%
OPTIONS["AAPL"]["options_chain"]['2022-02-18']
# Out:
#      Theta   Gamma  Rho    Vega                cName  cDelta  cVolume  cBidP  \
# 0   0.0000  0.0000    0  0.0000  AAPL220218C00070000  0.9930      1.0  98.70
# 1   0.0000  0.0000    0  0.0000  AAPL220218C00075000  0.9962     12.0  93.70
# 2   0.0000  0.0000    0  0.0000  AAPL220218C00080000  0.9959      1.0  88.70
# 3   0.0000  0.0000    0  0.0000  AAPL220218C00085000  0.9955      3.0  83.70
# 4   0.0000  0.0000    0  0.0000  AAPL220218C00090000  0.9952      1.0  78.70
# 5   0.0000  0.0000    0  0.0000  AAPL220218C00095000  0.9947      5.0  73.60
# 6   0.0000  0.0000    0  0.0000  AAPL220218C00100000  0.9943      9.0  68.60
# 7   0.0000  0.0000    0  0.0000  AAPL220218C00105000  0.9938     23.0  63.70
# 8   0.0000  0.0000    0  0.0000  AAPL220218C00110000  0.9974      1.0  58.60
# 9   0.0000  0.0000    0  0.0000  AAPL220218C00115000  0.9853      8.0  53.60
# 10  0.0000  0.0000    0  0.0000  AAPL220218C00120000  0.9875      3.0  48.60
# 11 -0.0533  0.0003    0  0.0005  AAPL220218C00125000  0.9965      2.0  43.60
# 12  0.0000  0.0000    0  0.0000  AAPL220218C00130000  0.9897      2.0  38.70
# 13 -0.0513  0.0006    0  0.0007  AAPL220218C00135000  0.9883     28.0  33.60
# 14 -0.0501  0.0007    0  0.0008  AAPL220218C00140000  0.9594     22.0  28.70
# 15 -0.0498  0.0008    0  0.0008  AAPL220218C00141000  0.9860      NaN  27.70
# 16 -0.0495  0.0009    0  0.0008  AAPL220218C00142000  0.9856      NaN  26.70
# 17 -0.0492  0.0009    0  0.0008  AAPL220218C00143000  0.9851      NaN  25.70
# 18 -0.0489  0.0010    0  0.0009  AAPL220218C00144000  0.9846      1.0  24.70
# 19 -0.0486  0.0011    0  0.0009  AAPL220218C00145000  0.9840    151.0  23.70
# 20 -0.0483  0.0011    0  0.0009  AAPL220218C00146000  0.9834      3.0  22.70
# 21 -0.0479  0.0012    0  0.0010  AAPL220218C00147000  0.9745      7.0  21.60
# 22 -0.0476  0.0013    0  0.0010  AAPL220218C00148000  0.9871      4.0  20.60
# 23 -0.0472  0.0015    0  0.0010  AAPL220218C00149000  0.9866      1.0  19.60
# 24 -0.0833  0.0024    0  0.0018  AAPL220218C00150000  0.9805    419.0  18.70
# 25 -0.0812  0.0031    0  0.0020  AAPL220218C00152500  0.9782     52.0  16.20
# 26 -0.0944  0.0046    0  0.0026  AAPL220218C00155000  0.9819    233.0  13.60
# 27 -0.0759  0.0056    0  0.0026  AAPL220218C00157500  0.9045     13.0  11.15
# 28 -0.1495  0.0131    0  0.0055  AAPL220218C00160000  0.9566   1214.0   8.75
# 29 -0.2341  0.0274    0  0.0100  AAPL220218C00162500  0.8638    475.0   6.20
# 30 -0.4147  0.0607    0  0.0198  AAPL220218C00165000  0.8579   2889.0   4.00
# 31 -0.5591  0.1159    0  0.0318  AAPL220218C00167500  0.6691   4231.0   2.00
# 32 -0.5130  0.1331    0  0.0326  AAPL220218C00170000  0.3496  44168.0   0.61
# 33 -0.2419  0.0629    0  0.0153  AAPL220218C00172500  0.0949  83724.0   0.10
# 34 -0.4231  0.0381    0  0.0158  AAPL220218C00175000  0.0191  73097.0   0.01
# 35 -0.3891  0.0240    0  0.0121  AAPL220218C00177500  0.0086  16627.0   0.01
# 36 -0.4158  0.0175    0  0.0106  AAPL220218C00180000  0.0071   4158.0   0.01
# 37 -0.6085  0.0156    0  0.0122  AAPL220218C00182500  0.0060    586.0   0.01
# 38 -0.4561  0.0110    0  0.0088  AAPL220218C00185000  0.0053    424.0   0.01
# 39 -0.3671  0.0080    0  0.0067  AAPL220218C00187500  0.0048    137.0   0.01
# 40 -0.3190  0.0061    0  0.0055  AAPL220218C00190000  0.0043    140.0   0.01
# 41 -0.3268  0.0053    0  0.0052  AAPL220218C00192500  0.0000     19.0   0.01
# 42 -0.3338  0.0046    0  0.0049  AAPL220218C00195000  0.0037    112.0   0.01
# 43 -0.4637  0.0049    0  0.0059  AAPL220218C00197500  0.0000      1.0   0.01
# 44 -1.2107  0.0071    0  0.0116  AAPL220218C00200000  0.0032     36.0   0.01
# 45 -0.5982  0.0045    0  0.0065  AAPL220218C00202500  0.0000      6.0   0.01
# 46 -1.3450  0.0062    0  0.0114  AAPL220218C00205000  0.0029      4.0   0.01
# 47  0.0000  0.0000    0  0.0000  AAPL220218C00207500  0.0000     15.0   0.01
# 48 -1.5647  0.0056    0  0.0117  AAPL220218C00210000  0.0026      4.0   0.01
# 49 -2.2661  0.0056    0  0.0141  AAPL220218C00215000  0.0000      4.0   0.01
# 50 -1.1150  0.0036    0  0.0079  AAPL220218C00220000  0.0000      6.0   0.01
# 51 -0.3883  0.0017    0  0.0032  AAPL220218C00225000  0.0000      3.0   0.01
# 52 -0.2293  0.0010    0  0.0019  AAPL220218C00230000  0.0000      1.0   0.01
# 53 -0.2323  0.0009    0  0.0018  AAPL220218C00235000  0.0000      1.0   0.01
# 54 -0.2351  0.0008    0  0.0017  AAPL220218C00240000  0.0000    115.0   0.01
# 55 -0.2378  0.0008    0  0.0017  AAPL220218C00245000  0.0000     15.0   0.01
# 56 -0.2403  0.0007    0  0.0016  AAPL220218C00250000  0.0000      1.0   0.01
# 57 -0.2426  0.0007    0  0.0016  AAPL220218C00255000  0.0000    234.0   0.01
# 58 -0.2448  0.0006    0  0.0015  AAPL220218C00260000  0.0000      1.0   0.01
# 59 -0.2469  0.0006    0  0.0015  AAPL220218C00265000  0.0000    503.0   0.01
# 60 -0.2489  0.0005    0  0.0014  AAPL220218C00270000  0.0014      5.0   0.01
# 61 -0.2507  0.0005    0  0.0014  AAPL220218C00275000  0.0000      1.0   0.01
#
#     cTheo  cAskP  Strike   pBidP  pTheo   pAskP  pVolume  pDelta  \
# 0     NaN  99.05    70.0    0.01    NaN    0.01     17.0  0.0000
# 1     NaN  93.95    75.0    0.01    NaN    0.01    722.0  0.0000
# 2     NaN  89.20    80.0    0.01    NaN    0.01      1.0  0.0000
# 3     NaN  84.20    85.0    0.01    NaN    0.01      1.0  0.0000
# 4     NaN  79.20    90.0    0.01    NaN    0.01      1.0  0.0000
# 5     NaN  73.95    95.0    0.01    NaN    0.01     45.0  0.0000
# 6     NaN  68.95   100.0    0.01    NaN    0.01    100.0  0.0000
# 7     NaN  63.95   105.0    0.01    NaN    0.01      1.0  0.0000
# 8     NaN  59.20   110.0    0.01    NaN    0.01     12.0  0.0000
# 9     NaN  54.05   115.0    0.01    NaN    0.01      2.0  0.0000
# 10    NaN  49.00   120.0    0.01    NaN    0.01      3.0  0.0000
# 11    NaN  44.20   125.0    0.01    NaN    0.01     17.0 -0.0019
# 12    NaN  38.95   130.0    0.01    NaN    0.01     14.0  0.0000
# 13    NaN  33.95   135.0    0.01    NaN    0.01     17.0 -0.0024
# 14    NaN  29.20   140.0    0.01    NaN    0.01    208.0 -0.0028
# 15    NaN  28.20   141.0    0.01    NaN    0.01     16.0 -0.0029
# 16    NaN  27.20   142.0    0.01    NaN    0.01     28.0 -0.0030
# 17    NaN  26.20   143.0    0.01    NaN    0.04    218.0 -0.0031
# 18    NaN  25.20   144.0    0.01    NaN    0.04    298.0 -0.0032
# 19    NaN  24.20   145.0    0.01    NaN    0.01   1886.0 -0.0034
# 20    NaN  23.20   146.0    0.01    NaN    0.02    426.0 -0.0035
# 21    NaN  22.00   147.0    0.01    NaN    0.03    112.0 -0.0036
# 22    NaN  21.25   148.0    0.01    NaN    0.02     20.0 -0.0038
# 23    NaN  20.25   149.0    0.01    NaN    0.02      7.0 -0.0040
# 24    NaN  19.20   150.0    0.01    NaN    0.02    606.0 -0.0073
# 25    NaN  16.70   152.5    0.01    NaN    0.02    479.0 -0.0082
# 26    NaN  14.25   155.0    0.02    NaN    0.03    788.0 -0.0112
# 27    NaN  11.80   157.5    0.02    NaN    0.04    416.0 -0.0111
# 28    NaN   9.20   160.0    0.04    NaN    0.05   9617.0 -0.0271
# 29    NaN   6.80   162.5    0.08    NaN    0.11  11273.0 -0.0563
# 30    NaN   4.30   165.0    0.24    NaN    0.27  33153.0 -0.1416
# 31    NaN   2.24   167.5    0.65    NaN    0.68  40054.0 -0.3246
# 32    NaN   0.68   170.0    1.61    NaN    1.85  75561.0 -0.6537
# 33    NaN   0.13   172.5    3.60    NaN    3.90  23587.0 -0.9014
# 34    NaN   0.03   175.0    5.85    NaN    6.35  16098.0 -0.8971
# 35    NaN   0.02   177.5    8.55    NaN    8.80    843.0 -0.9286
# 36    NaN   0.01   180.0   10.85    NaN   11.30   2697.0 -0.9392
# 37    NaN   0.01   182.5   13.25    NaN   13.90     33.0 -0.9278
# 38    NaN   0.01   185.0   15.90    NaN   16.30     62.0 -0.9520
# 39    NaN   0.01   187.5   18.40    NaN   19.10      2.0 -0.9655
# 40    NaN   0.01   190.0   20.75    NaN   21.70    173.0 -0.9730
# 41    NaN   0.01   192.5   23.45    NaN   24.00      1.0 -0.9750
# 42    NaN   0.01   195.0   25.95    NaN   26.50     10.0 -0.9766
# 43    NaN   0.01   197.5   27.95    NaN   29.60      NaN -0.9704
# 44    NaN   0.01   200.0   29.90    NaN   31.65      1.0 -0.9322
# 45    NaN   0.01   202.5   33.00    NaN   34.65      1.0 -0.9671
# 46    NaN   0.01   205.0   35.00    NaN   36.70      5.0 -0.9338
# 47    NaN   0.01   207.5     NaN    NaN     NaN      NaN     NaN
# 48    NaN   0.01   210.0   40.35    NaN   41.80      6.0 -0.9314
# 49    NaN   0.01   215.0   44.80    NaN   47.20      7.0 -0.9121
# 50    NaN   0.01   220.0   50.95    NaN   52.10     40.0 -0.9579
# 51    NaN   0.01   225.0   56.00    NaN   56.45     14.0 -0.9859
# 52    NaN   0.01   230.0   61.05    NaN   61.30      2.0 -0.9921
# 53    NaN   0.01   235.0   66.05    NaN   66.30      7.0 -0.9925
# 54    NaN   0.01   240.0   71.05    NaN   71.30      6.0 -0.9929
# 55    NaN   0.01   245.0   76.05    NaN   76.30      NaN -0.9932
# 56    NaN   0.01   250.0   81.05    NaN   81.30      2.0 -0.9934
# 57    NaN   0.01   255.0   86.05    NaN   86.30      NaN -0.9937
# 58    NaN   0.01   260.0   91.05    NaN   91.30      1.0 -0.9939
# 59    NaN   0.01   265.0   96.05    NaN   96.30      3.0 -0.9941
# 60    NaN   0.01   270.0  101.05    NaN  101.30      1.0 -0.9943
# 61    NaN   0.01   275.0  106.05    NaN  106.30      1.0 -0.9944
#
#                   pName
# 0   AAPL220218P00070000
# 1   AAPL220218P00075000
# 2   AAPL220218P00080000
# 3   AAPL220218P00085000
# 4   AAPL220218P00090000
# 5   AAPL220218P00095000
# 6   AAPL220218P00100000
# 7   AAPL220218P00105000
# 8   AAPL220218P00110000
# 9   AAPL220218P00115000
# 10  AAPL220218P00120000
# 11  AAPL220218P00125000
# 12  AAPL220218P00130000
# 13  AAPL220218P00135000
# 14  AAPL220218P00140000
# 15  AAPL220218P00141000
# 16  AAPL220218P00142000
# 17  AAPL220218P00143000
# 18  AAPL220218P00144000
# 19  AAPL220218P00145000
# 20  AAPL220218P00146000
# 21  AAPL220218P00147000
# 22  AAPL220218P00148000
# 23  AAPL220218P00149000
# 24  AAPL220218P00150000
# 25  AAPL220218P00152500
# 26  AAPL220218P00155000
# 27  AAPL220218P00157500
# 28  AAPL220218P00160000
# 29  AAPL220218P00162500
# 30  AAPL220218P00165000
# 31  AAPL220218P00167500
# 32  AAPL220218P00170000
# 33  AAPL220218P00172500
# 34  AAPL220218P00175000
# 35  AAPL220218P00177500
# 36  AAPL220218P00180000
# 37  AAPL220218P00182500
# 38  AAPL220218P00185000
# 39  AAPL220218P00187500
# 40  AAPL220218P00190000
# 41  AAPL220218P00192500
# 42  AAPL220218P00195000
# 43  AAPL220218P00197500
# 44  AAPL220218P00200000
# 45  AAPL220218P00202500
# 46  AAPL220218P00205000
# 47                  NaN
# 48  AAPL220218P00210000
# 49  AAPL220218P00215000
# 50  AAPL220218P00220000
# 51  AAPL220218P00225000
# 52  AAPL220218P00230000
# 53  AAPL220218P00235000
# 54  AAPL220218P00240000
# 55  AAPL220218P00245000
# 56  AAPL220218P00250000
# 57  AAPL220218P00255000
# 58  AAPL220218P00260000
# 59  AAPL220218P00265000
# 60  AAPL220218P00270000
# 61  AAPL220218P00275000

# %%
OPTIONS
# Out:
# {'AAPL': {'code': 'AAPL',
#   'exchange': 'US',
#   'lastTradeDate': '2022-02-17',
#   'lastTradePrice': 168.88,
#   'data': [{'expirationDate': '2022-02-18',
#     'impliedVolatility': 36.4222,
#     'putVolume': 219722,
#     'callVolume': 233962,
#     'putCallVolumeRatio': 0.9391354151528881,
#     'putOpenInterest': 572337,
#     'callOpenInterest': 617262,
#     'putCallOpenInterestRatio': 0.9272189119045073,
#     'optionsCount': 123,
#     'options': {'CALL': [{'contractName': 'AAPL220218C00070000',
#        'contractSize': 'REGULAR',
#        'contractPeriod': 'MONTHLY',
#        'currency': 'USD',
#        'type': 'CALL',
#        'inTheMoney': 'TRUE',
#        'lastTradeDateTime': '2022-02-14 15:55:06',
#        'expirationDate': '2022-02-18',
#        'strike': 70,
#        'lastPrice': 98.2,
#        'bid': 98.7,
#        'ask': 99.05,
#        'change': -4.23,
#        'changePercent': -0.0413,
#        'volume': 1,
#        'openInterest': 16,
#        'impliedVolatility': 744.2521,
#        'delta': 0.993,
#        'gamma': 0.0003,
#        'theta': -0.6425,
#        'vega': 0.0017,
#        'rho': 0,
#        'theoretical': 99.05,
#        'intrinsicValue': 0,
#        'timeValue': 0,
#        'updatedAt': '2022-02-17 19:08:34',
#        'daysBeforeExpiration': 0},
#       {'contractName': 'AAPL220218C00075000',
#        'contractSize': 'REGULAR',
#        'contractPeriod': 'MONTHLY',
#        'currency': 'USD',
#        'type': 'CALL',
#        'inTheMoney': 'TRUE',
#        'lastTradeDateTime': '2022-02-09 14:51:22',
#        'expirationDate': '2022-02-18',
#        'strike': 75,
#        'lastPrice': 100.85,
#        'bid': 93.7,
#        'ask': 93.95,
#        'change': 4.77,
#        'changePercent': 0.0496,
#        'volume': 12,
#        'openInterest': 11,
#        'impliedVolatility': 619.1258,
#        'delta': 0.9962,
#        'gamma': 0.0002,
#        'theta': -0.3103,
#        'vega': 0.001,
#        'rho': 0,
#        'theoretical': 93.95,
#        'intrinsicValue': 0,
#        'timeValue': 0,
#        'updatedAt': '2022-02-17 19:08:34',
#        'daysBeforeExpiration': 0},
#       {'contractName': 'AAPL220218C00080000',
#        'contractSize': 'REGULAR',
#        'contractPeriod': 'MONTHLY',
#        'currency': 'USD',
#        'type': 'CALL',
#        'inTheMoney': 'TRUE',
#        'lastTradeDateTime': '2022-02-16 14:44:13',
#        'expirationDate': '2022-02-18',
#        'strike': 80,
#        'lastPrice': 92.1,
#        'bid': 88.7,
#        'ask': 89.2,
#        'change': 0.49,
#        'changePercent': 0.0053,
#        'volume': 1,
#        'openInterest': 4,
#        'impliedVolatility': 573.1157,
#        'delta': 0.9959,
#        'gamma': 0.0002,
#        'theta': -0.3078,
#        'vega': 0.0011,
#        'rho': 0,
#        'theoretical': 88.95,
#        'intrinsicValue': 0,
#        'timeValue': 0,
#        'updatedAt': '2022-02-17 19:08:34',
#        'daysBeforeExpiration': 0},
#       {'contractName': 'AAPL220218C00085000',
#        'contractSize': 'REGULAR',
#        'contractPeriod': 'MONTHLY',
#        'currency': 'USD',
#        'type': 'CALL',
#        'inTheMoney': 'TRUE',
#        'lastTradeDateTime': '2022-02-15 12:03:51',
#        'expirationDate': '2022-02-18',
#        'strike': 85,
#        'lastPrice': 86.52,
#        'bid': 83.7,
#        'ask': 84.2,
#        'change': -0.49,
#        'changePercent': -0.0056,
#        'volume': 3,
#        'openInterest': 741,
#        'impliedVolatility': 529.8529,
#        'delta': 0.9955,
#        'gamma': 0.0003,
#        'theta': -0.3051,
#        'vega': 0.0012,
#        'rho': 0,
#        'theoretical': 83.95,
#        'intrinsicValue': 0,
#        'timeValue': 0,
#        'updatedAt': '2022-02-17 19:08:34',
#        'daysBeforeExpiration': 0},
#       {'contractName': 'AAPL220218C00090000',
#        'contractSize': 'REGULAR',
#        'contractPeriod': 'MONTHLY',
#        'currency': 'USD',
#        'type': 'CALL',
#        'inTheMoney': 'TRUE',
#        'lastTradeDateTime': '2022-02-16 14:13:44',
#        'expirationDate': '2022-02-18',
#        'strike': 90,
#        'lastPrice': 81.45,
#        'bid': 78.7,
#        'ask': 79.2,
#        'change': -0.79,
#        'changePercent': -0.0096,
#        'volume': 1,
#        'openInterest': 34,
#        'impliedVolatility': 488.9972,
#        'delta': 0.9952,
#        'gamma': 0.0003,
#        'theta': -0.3021,
#        'vega': 0.0012,
#        'rho': 0,
#        'theoretical': 78.95,
#        'intrinsicValue': 0,
#        'timeValue': 0,
#        'updatedAt': '2022-02-17 19:08:34',
#        'daysBeforeExpiration': 0},
#       {'contractName': 'AAPL220218C00095000',
#        'contractSize': 'REGULAR',
#        'contractPeriod': 'MONTHLY',
#        'currency': 'USD',
#        'type': 'CALL',
#        'inTheMoney': 'TRUE',
#        'lastTradeDateTime': '2022-02-15 12:01:03',
#        'expirationDate': '2022-02-18',
#        'strike': 95,
#        'lastPrice': 76.55,
#        'bid': 73.6,
#        'ask': 73.95,
#        'change': -0.48,
#        'changePercent': -0.0062,
#        'volume': 5,
#        'openInterest': 11,
#        'impliedVolatility': 450.2627,
#        'delta': 0.9947,
#        'gamma': 0.0004,
#        'theta': -0.299,
#        'vega': 0.0013,
#        'rho': 0,
#        'theoretical': 73.95,
#        'intrinsicValue': 0,
#        'timeValue': 0,
#        'updatedAt': '2022-02-17 19:08:34',
#        'daysBeforeExpiration': 0},
#       {'contractName': 'AAPL220218C00100000',
#        'contractSize': 'REGULAR',
#        'contractPeriod': 'MONTHLY',
#        'currency': 'USD',
#        'type': 'CALL',
#        'inTheMoney': 'TRUE',
#        'lastTradeDateTime': '2022-02-17 14:55:17',
#        'expirationDate': '2022-02-18',
#        'strike': 100,
#        'lastPrice': 69.58,
#        'bid': 68.6,
#        'ask': 68.95,
#        'change': -1.57,
#        'changePercent': -0.0221,
#        'volume': 9,
#        'openInterest': 568,
#        'impliedVolatility': 413.4066,
#        'delta': 0.9943,
#        'gamma': 0.0004,
#        'theta': -0.2955,
#        'vega': 0.0014,
#        'rho': 0,
#        'theoretical': 68.95,
#        'intrinsicValue': 0,
#        'timeValue': 0,
#        'updatedAt': '2022-02-17 19:08:34',
#        'daysBeforeExpiration': 0},
#       {'contractName': 'AAPL220218C00105000',
#        'contractSize': 'REGULAR',
#        'contractPeriod': 'MONTHLY',
#        'currency': 'USD',
#        'type': 'CALL',
#        'inTheMoney': 'TRUE',
#        'lastTradeDateTime': '2022-02-15 12:07:58',
#        'expirationDate': '2022-02-18',
#        'strike': 105,
#        'lastPrice': 66.35,
#        'bid': 63.7,
#        'ask': 63.95,
#        'change': -1.07,
#        'changePercent': -0.0159,
#        'volume': 23,
#        'openInterest': 41,
#        'impliedVolatility': 378.2198,
#        'delta': 0.9938,
#        'gamma': 0.0005,
#        'theta': -0.2918,
#        'vega': 0.0016,
#        'rho': 0,
#        'theoretical': 63.95,
#        'intrinsicValue': 0,
#        'timeValue': 0,
#        'updatedAt': '2022-02-17 19:08:34',
#        'daysBeforeExpiration': 0},
#       {'contractName': 'AAPL220218C00110000',
#        'contractSize': 'REGULAR',
#        'contractPeriod': 'MONTHLY',
#        'currency': 'USD',
#        'type': 'CALL',
#        'inTheMoney': 'TRUE',
#        'lastTradeDateTime': '2022-02-17 10:47:27',
#        'expirationDate': '2022-02-18',
#        'strike': 110,
#        'lastPrice': 61.34,
#        'bid': 58.6,
#        'ask': 59.2,
#        'change': -1.24,
#        'changePercent': -0.0198,
#        'volume': 1,
#        'openInterest': 96,
#        'impliedVolatility': 301.06,
#        'delta': 0.9974,
#        'gamma': 0.0003,
#        'theta': -0.1037,
#        'vega': 0.0007,
#        'rho': 0,
#        'theoretical': 58.9,
#        'intrinsicValue': 0,
#        'timeValue': 0,
#        'updatedAt': '2022-02-17 19:08:34',
#        'daysBeforeExpiration': 0},
#       {'contractName': 'AAPL220218C00115000',
#        'contractSize': 'REGULAR',
#        'contractPeriod': 'MONTHLY',
#        'currency': 'USD',
#        'type': 'CALL',
#        'inTheMoney': 'TRUE',
#        'lastTradeDateTime': '2022-02-17 13:41:11',
#        'expirationDate': '2022-02-18',
#        'strike': 115,
#        'lastPrice': 55.39,
#        'bid': 53.6,
#        'ask': 54.05,
#        'change': 0.1,
#        'changePercent': 0.0018,
#        'volume': 8,
#        'openInterest': 203,
#        'impliedVolatility': 351.735,
#        'delta': 0.9853,
#        'gamma': 0.0012,
#        'theta': -0.5756,
#        'vega': 0.0033,
#        'rho': 0,
#        'theoretical': 54.05,
#        'intrinsicValue': 0,
#        'timeValue': 0,
#        'updatedAt': '2022-02-17 19:08:35',
#        'daysBeforeExpiration': 0},
#       {'contractName': 'AAPL220218C00120000',
#        'contractSize': 'REGULAR',
#        'contractPeriod': 'MONTHLY',
#        'currency': 'USD',
#        'type': 'CALL',
#        'inTheMoney': 'TRUE',
#        'lastTradeDateTime': '2022-02-17 13:56:25',
#        'expirationDate': '2022-02-18',
#        'strike': 120,
#        'lastPrice': 50.34,
#        'bid': 48.6,
#        'ask': 49,
#        'change': -0.86,
#        'changePercent': -0.0168,
#        'volume': 3,
#        'openInterest': 598,
#        'impliedVolatility': 301.6887,
#        'delta': 0.9875,
#        'gamma': 0.0012,
#        'theta': -0.4285,
#        'vega': 0.0029,
#        'rho': 0,
#        'theoretical': 49,
#        'intrinsicValue': 0,
#        'timeValue': 0,
#        'updatedAt': '2022-02-17 19:08:35',
#        'daysBeforeExpiration': 0},
#       {'contractName': 'AAPL220218C00125000',
#        'contractSize': 'REGULAR',
#        'contractPeriod': 'MONTHLY',
#        'currency': 'USD',
#        'type': 'CALL',
#        'inTheMoney': 'TRUE',
#        'lastTradeDateTime': '2022-02-16 10:06:48',
#        'expirationDate': '2022-02-18',
#        'strike': 125,
#        'lastPrice': 46.89,
#        'bid': 43.6,
#        'ask': 44.2,
#        'change': 2.56,
#        'changePercent': 0.0577,
#        'volume': 2,
#        'openInterest': 269,
#        'impliedVolatility': 217.7006,
#        'delta': 0.9965,
#        'gamma': 0.0005,
#        'theta': -0.0991,
#        'vega': 0.0009,
#        'rho': 0,
#        'theoretical': 43.9,
#        'intrinsicValue': 0,
#        'timeValue': 0,
#        'updatedAt': '2022-02-17 19:08:35',
#        'daysBeforeExpiration': 0},
#       {'contractName': 'AAPL220218C00130000',
#        'contractSize': 'REGULAR',
#        'contractPeriod': 'MONTHLY',
#        'currency': 'USD',
#        'type': 'CALL',
#        'inTheMoney': 'TRUE',
#        'lastTradeDateTime': '2022-02-17 11:55:28',
#        'expirationDate': '2022-02-18',
#        'strike': 130,
#        'lastPrice': 41.51,
#        'bid': 38.7,
#        'ask': 38.95,
#        'change': 0.54,
#        'changePercent': 0.0132,
#        'volume': 2,
#        'openInterest': 629,
#        'impliedVolatility': 221.5726,
#        'delta': 0.9897,
#        'gamma': 0.0014,
#        'theta': -0.2668,
#        'vega': 0.0024,
#        'rho': 0,
#        'theoretical': 38.95,
#        'intrinsicValue': 0,
#        'timeValue': 0,
#        'updatedAt': '2022-02-17 19:08:35',
#        'daysBeforeExpiration': 0},
#       {'contractName': 'AAPL220218C00135000',
#        'contractSize': 'REGULAR',
#        'contractPeriod': 'MONTHLY',
#        'currency': 'USD',
#        'type': 'CALL',
#        'inTheMoney': 'TRUE',
#        'lastTradeDateTime': '2022-02-17 15:52:45',
#        'expirationDate': '2022-02-18',
#        'strike': 135,
#        'lastPrice': 33.6,
#        'bid': 33.6,
#        'ask': 33.95,
#        'change': -3.1,
#        'changePercent': -0.0845,
#        'volume': 28,
#        'openInterest': 207,
#        'impliedVolatility': 193.1401,
#        'delta': 0.9883,
#        'gamma': 0.0018,
#        'theta': -0.2599,
#        'vega': 0.0027,
#        'rho': 0,
#        'theoretical': 33.95,
#        'intrinsicValue': 0,
#        'timeValue': 0,
#        'updatedAt': '2022-02-17 19:08:35',
#        'daysBeforeExpiration': 0},
#       {'contractName': 'AAPL220218C00140000',
#        'contractSize': 'REGULAR',
#        'contractPeriod': 'MONTHLY',
#        'currency': 'USD',
#        'type': 'CALL',
#        'inTheMoney': 'TRUE',
#        'lastTradeDateTime': '2022-02-17 15:58:26',
#        'expirationDate': '2022-02-18',
#        'strike': 140,
#        'lastPrice': 28.87,
#        'bid': 28.7,
#        'ask': 29.2,
#        'change': -3.58,
#        'changePercent': -0.1103,
#        'volume': 22,
#        'openInterest': 895,
#        'impliedVolatility': 212.2912,
#        'delta': 0.9594,
#        'gamma': 0.0047,
#        'theta': -0.8173,
#        'vega': 0.0077,
#        'rho': 0,
#        'theoretical': 29.2,
#        'intrinsicValue': 0,
#        'timeValue': 0,
#        'updatedAt': '2022-02-17 19:08:35',
#        'daysBeforeExpiration': 0},
#       {'contractName': 'AAPL220218C00141000',
#        'contractSize': 'REGULAR',
#        'contractPeriod': 'MONTHLY',
#        'currency': 'USD',
#        'type': 'CALL',
#        'inTheMoney': 'TRUE',
#        'lastTradeDateTime': '0000-00-00 00:00:00',
#        'expirationDate': '2022-02-18',
#        'strike': 141,
#        'lastPrice': 0,
#        'bid': 27.7,
#        'ask': 28.2,
#        'change': 0,
#        'changePercent': None,
#        'volume': None,
#        'openInterest': None,
#        'impliedVolatility': 159.8931,
#        'delta': 0.986,
#        'gamma': 0.0025,
#        'theta': -0.2502,
#        'vega': 0.0031,
#        'rho': 0,
#        'theoretical': 27.95,
#        'intrinsicValue': 0,
#        'timeValue': 0,
#        'updatedAt': '2022-02-17 19:06:46',
#        'daysBeforeExpiration': 0},
#       {'contractName': 'AAPL220218C00142000',
#        'contractSize': 'REGULAR',
#        'contractPeriod': 'MONTHLY',
#        'currency': 'USD',
#        'type': 'CALL',
#        'inTheMoney': 'TRUE',
#        'lastTradeDateTime': '0000-00-00 00:00:00',
#        'expirationDate': '2022-02-18',
#        'strike': 142,
#        'lastPrice': 0,
#        'bid': 26.7,
#        'ask': 27.2,
#        'change': 0,
#        'changePercent': None,
#        'volume': None,
#        'openInterest': None,
#        'impliedVolatility': 154.429,
#        'delta': 0.9856,
#        'gamma': 0.0027,
#        'theta': -0.2484,
#        'vega': 0.0032,
#        'rho': 0,
#        'theoretical': 26.95,
#        'intrinsicValue': 0,
#        'timeValue': 0,
#        'updatedAt': '2022-02-17 19:06:46',
#        'daysBeforeExpiration': 0},
#       {'contractName': 'AAPL220218C00143000',
#        'contractSize': 'REGULAR',
#        'contractPeriod': 'MONTHLY',
#        'currency': 'USD',
#        'type': 'CALL',
#        'inTheMoney': 'TRUE',
#        'lastTradeDateTime': '0000-00-00 00:00:00',
#        'expirationDate': '2022-02-18',
#        'strike': 143,
#        'lastPrice': 0,
#        'bid': 25.7,
#        'ask': 26.2,
#        'change': 0,
#        'changePercent': None,
#        'volume': None,
#        'openInterest': None,
#        'impliedVolatility': 148.9837,
#        'delta': 0.9851,
#        'gamma': 0.0029,
#        'theta': -0.2465,
#        'vega': 0.0033,
#        'rho': 0,
#        'theoretical': 25.95,
#        'intrinsicValue': 0,
#        'timeValue': 0,
#        'updatedAt': '2022-02-17 19:06:46',
#        'daysBeforeExpiration': 0},
#       {'contractName': 'AAPL220218C00144000',
#        'contractSize': 'REGULAR',
#        'contractPeriod': 'MONTHLY',
#        'currency': 'USD',
#        'type': 'CALL',
#        'inTheMoney': 'TRUE',
#        'lastTradeDateTime': '2022-02-14 00:03:15',
#        'expirationDate': '2022-02-18',
#        'strike': 144,
#        'lastPrice': 30.4,
#        'bid': 24.7,
#        'ask': 25.2,
#        'change': 30.4,
#        'changePercent': None,
#        'volume': 1,
#        'openInterest': 1,
#        'impliedVolatility': 143.5559,
#        'delta': 0.9846,
#        'gamma': 0.0031,
#        'theta': -0.2445,
#        'vega': 0.0034,
#        'rho': 0,
#        'theoretical': 24.95,
#        'intrinsicValue': 0,
#        'timeValue': 0,
#        'updatedAt': '2022-02-17 19:08:35',
#        'daysBeforeExpiration': 0},
#       {'contractName': 'AAPL220218C00145000',
#        'contractSize': 'REGULAR',
#        'contractPeriod': 'MONTHLY',
#        'currency': 'USD',
#        'type': 'CALL',
#        'inTheMoney': 'TRUE',
#        'lastTradeDateTime': '2022-02-17 15:58:55',
#        'expirationDate': '2022-02-18',
#        'strike': 145,
#        'lastPrice': 23.95,
#        'bid': 23.7,
#        'ask': 24.2,
#        'change': -3.67,
#        'changePercent': -0.1329,
#        'volume': 151,
#        'openInterest': 4036,
#        'impliedVolatility': 138.1441,
#        'delta': 0.984,
#        'gamma': 0.0033,
#        'theta': -0.2425,
#        'vega': 0.0035,
#        'rho': 0,
#        'theoretical': 23.95,
#        'intrinsicValue': 0,
#        'timeValue': 0,
#        'updatedAt': '2022-02-17 19:08:35',
#        'daysBeforeExpiration': 0},
#       {'contractName': 'AAPL220218C00146000',
#        'contractSize': 'REGULAR',
#        'contractPeriod': 'MONTHLY',
#        'currency': 'USD',
#        'type': 'CALL',
#        'inTheMoney': 'TRUE',
#        'lastTradeDateTime': '2022-02-14 00:03:15',
#        'expirationDate': '2022-02-18',
#        'strike': 146,
#        'lastPrice': 26.8,
#        'bid': 22.7,
#        'ask': 23.2,
#        'change': 26.8,
#        'changePercent': None,
#        'volume': 3,
#        'openInterest': 5,
#        'impliedVolatility': 132.7471,
#        'delta': 0.9834,
#        'gamma': 0.0035,
#        'theta': -0.2404,
#        'vega': 0.0036,
#        'rho': 0,
#        'theoretical': 22.95,
#        'intrinsicValue': 0,
#        'timeValue': 0,
#        'updatedAt': '2022-02-17 19:08:35',
#        'daysBeforeExpiration': 0},
#       {'contractName': 'AAPL220218C00147000',
#        'contractSize': 'REGULAR',
#        'contractPeriod': 'MONTHLY',
#        'currency': 'USD',
#        'type': 'CALL',
#        'inTheMoney': 'TRUE',
#        'lastTradeDateTime': '2022-02-17 09:30:01',
#        'expirationDate': '2022-02-18',
#        'strike': 147,
#        'lastPrice': 24.18,
#        'bid': 21.6,
#        'ask': 22,
#        'change': -0.32,
#        'changePercent': -0.0131,
#        'volume': 7,
#        'openInterest': 5,
#        'impliedVolatility': 138.4699,
#        'delta': 0.9745,
#        'gamma': 0.0049,
#        'theta': -0.3625,
#        'vega': 0.0053,
#        'rho': 0,
#        'theoretical': 22,
#        'intrinsicValue': 0,
#        'timeValue': 0,
#        'updatedAt': '2022-02-17 19:08:35',
#        'daysBeforeExpiration': 0},
#       {'contractName': 'AAPL220218C00148000',
#        'contractSize': 'REGULAR',
#        'contractPeriod': 'MONTHLY',
#        'currency': 'USD',
#        'type': 'CALL',
#        'inTheMoney': 'TRUE',
#        'lastTradeDateTime': '2022-02-16 11:29:27',
#        'expirationDate': '2022-02-18',
#        'strike': 148,
#        'lastPrice': 22.7,
#        'bid': 20.6,
#        'ask': 21.25,
#        'change': -0.68,
#        'changePercent': -0.0291,
#        'volume': 4,
#        'openInterest': 7,
#        'impliedVolatility': 114.6494,
#        'delta': 0.9871,
#        'gamma': 0.0033,
#        'theta': -0.1667,
#        'vega': 0.0029,
#        'rho': 0,
#        'theoretical': 20.925,
#        'intrinsicValue': 0,
#        'timeValue': 0,
#        'updatedAt': '2022-02-17 19:08:35',
#        'daysBeforeExpiration': 0},
#       {'contractName': 'AAPL220218C00149000',
#        'contractSize': 'REGULAR',
#        'contractPeriod': 'MONTHLY',
#        'currency': 'USD',
#        'type': 'CALL',
#        'inTheMoney': 'TRUE',
#        'lastTradeDateTime': '2022-02-16 09:36:56',
#        'expirationDate': '2022-02-18',
#        'strike': 149,
#        'lastPrice': 22.25,
#        'bid': 19.6,
#        'ask': 20.25,
#        'change': -0.29,
#        'changePercent': -0.0129,
#        'volume': 1,
#        'openInterest': 22,
#        'impliedVolatility': 109.5418,
#        'delta': 0.9866,
#        'gamma': 0.0036,
#        'theta': -0.1651,
#        'vega': 0.003,
#        'rho': 0,
#        'theoretical': 19.925,
#        'intrinsicValue': 0,
#        'timeValue': 0,
#        'updatedAt': '2022-02-17 19:08:35',
#        'daysBeforeExpiration': 0},
#       {'contractName': 'AAPL220218C00150000',
#        'contractSize': 'REGULAR',
#        'contractPeriod': 'MONTHLY',
#        'currency': 'USD',
#        'type': 'CALL',
#        'inTheMoney': 'TRUE',
#        'lastTradeDateTime': '2022-02-17 15:50:11',
#        'expirationDate': '2022-02-18',
#        'strike': 150,
#        'lastPrice': 19.86,
#        'bid': 18.7,
#        'ask': 19.2,
#        'change': -2.94,
#        'changePercent': -0.1289,
#        'volume': 419,
#        'openInterest': 14155,
#        'impliedVolatility': 111.2714,
#        'delta': 0.9805,
#        'gamma': 0.0048,
#        'theta': -0.231,
#        'vega': 0.0042,
#        'rho': 0,
#        'theoretical': 18.95,
#        'intrinsicValue': 0,
#        'timeValue': 0,
#        'updatedAt': '2022-02-17 19:08:35',
#        'daysBeforeExpiration': 0},
#       {'contractName': 'AAPL220218C00152500',
#        'contractSize': 'REGULAR',
#        'contractPeriod': 'MONTHLY',
#        'currency': 'USD',
#        'type': 'CALL',
#        'inTheMoney': 'TRUE',
#        'lastTradeDateTime': '2022-02-17 11:09:58',
#        'expirationDate': '2022-02-18',
#        'strike': 152.5,
#        'lastPrice': 18.79,
#        'bid': 16.2,
#        'ask': 16.7,
#        'change': -0.32,
#        'changePercent': -0.0167,
#        'volume': 52,
#        'openInterest': 373,
#        'impliedVolatility': 97.9011,
#        'delta': 0.9782,
#        'gamma': 0.006,
#        'theta': -0.2242,
#        'vega': 0.0046,
#        'rho': 0,
#        'theoretical': 16.45,
#        'intrinsicValue': 0,
#        'timeValue': 0,
#        'updatedAt': '2022-02-17 19:08:35',
#        'daysBeforeExpiration': 0},
#       {'contractName': 'AAPL220218C00155000',
#        'contractSize': 'REGULAR',
#        'contractPeriod': 'MONTHLY',
#        'currency': 'USD',
#        'type': 'CALL',
#        'inTheMoney': 'TRUE',
#        'lastTradeDateTime': '2022-02-17 15:50:00',
#        'expirationDate': '2022-02-18',
#        'strike': 155,
#        'lastPrice': 14.33,
#        'bid': 13.6,
#        'ask': 14.25,
#        'change': -3.47,
#        'changePercent': -0.1949,
#        'volume': 233,
#        'openInterest': 8135,
#        'impliedVolatility': 79.0073,
#        'delta': 0.9819,
#        'gamma': 0.0064,
#        'theta': -0.1535,
#        'vega': 0.0039,
#        'rho': 0,
#        'theoretical': 13.925,
#        'intrinsicValue': 0,
#        'timeValue': 0,
#        'updatedAt': '2022-02-17 19:08:35',
#        'daysBeforeExpiration': 0},
#       {'contractName': 'AAPL220218C00157500',
#        'contractSize': 'REGULAR',
#        'contractPeriod': 'MONTHLY',
#        'currency': 'USD',
#        'type': 'CALL',
#        'inTheMoney': 'TRUE',
#        'lastTradeDateTime': '2022-02-17 15:57:08',
#        'expirationDate': '2022-02-18',
#        'strike': 157.5,
#        'lastPrice': 11.2,
#        'bid': 11.15,
#        'ask': 11.8,
#        'change': -4.22,
#        'changePercent': -0.2737,
#        'volume': 13,
#        'openInterest': 1451,
#        'impliedVolatility': 104.0947,
#        'delta': 0.9045,
#        'gamma': 0.0184,
#        'theta': -0.7789,
#        'vega': 0.015,
#        'rho': 0,
#        'theoretical': 11.8,
#        'intrinsicValue': 0,
#        'timeValue': 0,
#        'updatedAt': '2022-02-17 19:08:35',
#        'daysBeforeExpiration': 0},
#       {'contractName': 'AAPL220218C00160000',
#        'contractSize': 'REGULAR',
#        'contractPeriod': 'MONTHLY',
#        'currency': 'USD',
#        'type': 'CALL',
#        'inTheMoney': 'TRUE',
#        'lastTradeDateTime': '2022-02-17 15:54:50',
#        'expirationDate': '2022-02-18',
#        'strike': 160,
#        'lastPrice': 8.65,
#        'bid': 8.75,
#        'ask': 9.2,
#        'change': -3.86,
#        'changePercent': -0.3086,
#        'volume': 1214,
#        'openInterest': 27671,
#        'impliedVolatility': 60.8377,
#        'delta': 0.9566,
#        'gamma': 0.0171,
#        'theta': -0.2459,
#        'vega': 0.0081,
#        'rho': 0,
#        'theoretical': 8.975,
#        'intrinsicValue': 0,
#        'timeValue': 0,
#        'updatedAt': '2022-02-17 19:08:35',
#        'daysBeforeExpiration': 0},
#       {'contractName': 'AAPL220218C00162500',
#        'contractSize': 'REGULAR',
#        'contractPeriod': 'MONTHLY',
#        'currency': 'USD',
#        'type': 'CALL',
#        'inTheMoney': 'TRUE',
#        'lastTradeDateTime': '2022-02-17 15:58:30',
#        'expirationDate': '2022-02-18',
#        'strike': 162.5,
#        'lastPrice': 6.35,
#        'bid': 6.2,
#        'ask': 6.8,
#        'change': -3.75,
#        'changePercent': -0.3713,
#        'volume': 475,
#        'openInterest': 4961,
#        'impliedVolatility': 68.1268,
#        'delta': 0.8638,
#        'gamma': 0.0363,
#        'theta': -0.656,
#        'vega': 0.0193,
#        'rho': 0,
#        'theoretical': 6.8,
#        'intrinsicValue': 0,
#        'timeValue': 0,
#        'updatedAt': '2022-02-17 19:08:35',
#        'daysBeforeExpiration': 0},
#       {'contractName': 'AAPL220218C00165000',
#        'contractSize': 'REGULAR',
#        'contractPeriod': 'MONTHLY',
#        'currency': 'USD',
#        'type': 'CALL',
#        'inTheMoney': 'TRUE',
#        'lastTradeDateTime': '2022-02-17 15:59:56',
#        'expirationDate': '2022-02-18',
#        'strike': 165,
#        'lastPrice': 3.95,
#        'bid': 4,
#        'ask': 4.3,
#        'change': -3.65,
#        'changePercent': -0.4803,
#        'volume': 2889,
#        'openInterest': 38560,
#        'impliedVolatility': 41.8902,
#        'delta': 0.8579,
#        'gamma': 0.0607,
#        'theta': -0.4147,
#        'vega': 0.0199,
#        'rho': 0,
#        'theoretical': 4.15,
#        'intrinsicValue': 0,
#        'timeValue': 0,
#        'updatedAt': '2022-02-17 19:08:35',
#        'daysBeforeExpiration': 0},
#       {'contractName': 'AAPL220218C00167500',
#        'contractSize': 'REGULAR',
#        'contractPeriod': 'MONTHLY',
#        'currency': 'USD',
#        'type': 'CALL',
#        'inTheMoney': 'TRUE',
#        'lastTradeDateTime': '2022-02-17 15:59:58',
#        'expirationDate': '2022-02-18',
#        'strike': 167.5,
#        'lastPrice': 2.09,
#        'bid': 2,
#        'ask': 2.24,
#        'change': -3.31,
#        'changePercent': -0.613,
#        'volume': 4231,
#        'openInterest': 7379,
#        'impliedVolatility': 36.5964,
#        'delta': 0.6691,
#        'gamma': 0.1121,
#        'theta': -0.585,
#        'vega': 0.032,
#        'rho': 0,
#        'theoretical': 2.09,
#        'intrinsicValue': 0,
#        'timeValue': 0,
#        'updatedAt': '2022-02-17 19:08:35',
#        'daysBeforeExpiration': 0},
#       {'contractName': 'AAPL220218C00170000',
#        'contractSize': 'REGULAR',
#        'contractPeriod': 'MONTHLY',
#        'currency': 'USD',
#        'type': 'CALL',
#        'inTheMoney': 'FALSE',
#        'lastTradeDateTime': '2022-02-17 15:59:59',
#        'expirationDate': '2022-02-18',
#        'strike': 170,
#        'lastPrice': 0.66,
#        'bid': 0.61,
#        'ask': 0.68,
#        'change': -2.49,
#        'changePercent': -0.7905,
#        'volume': 44168,
#        'openInterest': 46791,
#        'impliedVolatility': 32.0473,
#        'delta': 0.3496,
#        'gamma': 0.1307,
#        'theta': -0.5236,
#        'vega': 0.0327,
#        'rho': 0,
#        'theoretical': 0.66,
#        'intrinsicValue': 0,
#        'timeValue': 0,
#        'updatedAt': '2022-02-17 19:09:08',
#        'daysBeforeExpiration': 0},
#       {'contractName': 'AAPL220218C00172500',
#        'contractSize': 'REGULAR',
#        'contractPeriod': 'MONTHLY',
#        'currency': 'USD',
#        'type': 'CALL',
#        'inTheMoney': 'FALSE',
#        'lastTradeDateTime': '2022-02-17 15:59:59',
#        'expirationDate': '2022-02-18',
#        'strike': 172.5,
#        'lastPrice': 0.12,
#        'bid': 0.1,
#        'ask': 0.13,
#        'change': -1.26,
#        'changePercent': -0.913,
#        'volume': 83724,
#        'openInterest': 36838,
#        'impliedVolatility': 30.733,
#        'delta': 0.0949,
#        'gamma': 0.0622,
#        'theta': -0.2292,
#        'vega': 0.0149,
#        'rho': 0,
#        'theoretical': 0.12,
#        'intrinsicValue': 0,
#        'timeValue': 0,
#        'updatedAt': '2022-02-17 19:09:08',
#        'daysBeforeExpiration': 0},
#       {'contractName': 'AAPL220218C00175000',
#        'contractSize': 'REGULAR',
#        'contractPeriod': 'MONTHLY',
#        'currency': 'USD',
#        'type': 'CALL',
#        'inTheMoney': 'FALSE',
#        'lastTradeDateTime': '2022-02-17 15:59:56',
#        'expirationDate': '2022-02-18',
#        'strike': 175,
#        'lastPrice': 0.02,
#        'bid': 0.01,
#        'ask': 0.03,
#        'change': -0.32,
#        'changePercent': -0.9412,
#        'volume': 73097,
#        'openInterest': 85960,
#        'impliedVolatility': 32.6737,
#        'delta': 0.0191,
#        'gamma': 0.0161,
#        'theta': -0.0671,
#        'vega': 0.0041,
#        'rho': 0,
#        'theoretical': 0.02,
#        'intrinsicValue': 0,
#        'timeValue': 0,
#        'updatedAt': '2022-02-17 19:08:35',
#        'daysBeforeExpiration': 0},
#       {'contractName': 'AAPL220218C00177500',
#        'contractSize': 'REGULAR',
#        'contractPeriod': 'MONTHLY',
#        'currency': 'USD',
#        'type': 'CALL',
#        'inTheMoney': 'FALSE',
#        'lastTradeDateTime': '2022-02-17 15:59:58',
#        'expirationDate': '2022-02-18',
#        'strike': 177.5,
#        'lastPrice': 0.01,
#        'bid': 0.01,
#        'ask': 0.02,
#        'change': -0.06,
#        'changePercent': -0.8571,
#        'volume': 16627,
#        'openInterest': 48721,
#        'impliedVolatility': 39.7384,
#        'delta': 0.0086,
#        'gamma': 0.0066,
#        'theta': -0.0409,
#        'vega': 0.0021,
#        'rho': 0,
#        'theoretical': 0.01,
#        'intrinsicValue': 0,
#        'timeValue': 0,
#        'updatedAt': '2022-02-17 19:08:35',
#        'daysBeforeExpiration': 0},
#       {'contractName': 'AAPL220218C00180000',
#        'contractSize': 'REGULAR',
#        'contractPeriod': 'MONTHLY',
#        'currency': 'USD',
#        'type': 'CALL',
#        'inTheMoney': 'FALSE',
#        'lastTradeDateTime': '2022-02-17 15:59:00',
#        'expirationDate': '2022-02-18',
#        'strike': 180,
#        'lastPrice': 0.01,
#        'bid': 0.01,
#        'ask': 0.01,
#        'change': -0.01,
#        'changePercent': -0.5,
#        'volume': 4158,
#        'openInterest': 74486,
#        'impliedVolatility': 49.3769,
#        'delta': 0.0071,
#        'gamma': 0.0045,
#        'theta': -0.0428,
#        'vega': 0.0017,
#        'rho': 0,
#        'theoretical': 0.01,
#        'intrinsicValue': 0,
#        'timeValue': 0,
#        'updatedAt': '2022-02-17 19:08:35',
#        'daysBeforeExpiration': 0},
#       {'contractName': 'AAPL220218C00182500',
#        'contractSize': 'REGULAR',
#        'contractPeriod': 'MONTHLY',
#        'currency': 'USD',
#        'type': 'CALL',
#        'inTheMoney': 'FALSE',
#        'lastTradeDateTime': '2022-02-17 15:59:58',
#        'expirationDate': '2022-02-18',
#        'strike': 182.5,
#        'lastPrice': 0.01,
#        'bid': 0.01,
#        'ask': 0.01,
#        'change': 0,
#        'changePercent': 0,
#        'volume': 586,
#        'openInterest': 13127,
#        'impliedVolatility': 58.6752,
#        'delta': 0.006,
#        'gamma': 0.0033,
#        'theta': -0.0443,
#        'vega': 0.0015,
#        'rho': 0,
#        'theoretical': 0.01,
#        'intrinsicValue': 0,
#        'timeValue': 0,
#        'updatedAt': '2022-02-17 19:08:35',
#        'daysBeforeExpiration': 0},
#       {'contractName': 'AAPL220218C00185000',
#        'contractSize': 'REGULAR',
#        'contractPeriod': 'MONTHLY',
#        'currency': 'USD',
#        'type': 'CALL',
#        'inTheMoney': 'FALSE',
#        'lastTradeDateTime': '2022-02-17 15:57:25',
#        'expirationDate': '2022-02-18',
#        'strike': 185,
#        'lastPrice': 0.01,
#        'bid': 0.01,
#        'ask': 0.01,
#        'change': 0,
#        'changePercent': 0,
#        'volume': 424,
#        'openInterest': 59430,
#        'impliedVolatility': 67.6874,
#        'delta': 0.0053,
#        'gamma': 0.0025,
#        'theta': -0.0456,
#        'vega': 0.0013,
#        'rho': 0,
#        'theoretical': 0.01,
#        'intrinsicValue': 0,
#        'timeValue': 0,
#        'updatedAt': '2022-02-17 19:08:35',
#        'daysBeforeExpiration': 0},
#       {'contractName': 'AAPL220218C00187500',
#        'contractSize': 'REGULAR',
#        'contractPeriod': 'MONTHLY',
#        'currency': 'USD',
#        'type': 'CALL',
#        'inTheMoney': 'FALSE',
#        'lastTradeDateTime': '2022-02-17 15:17:33',
#        'expirationDate': '2022-02-18',
#        'strike': 187.5,
#        'lastPrice': 0.01,
#        'bid': 0.01,
#        'ask': 0.01,
#        'change': 0,
#        'changePercent': 0,
#        'volume': 137,
#        'openInterest': 8814,
#        'impliedVolatility': 76.45,
#        'delta': 0.0048,
#        'gamma': 0.002,
#        'theta': -0.0467,
#        'vega': 0.0012,
#        'rho': 0,
#        'theoretical': 0.01,
#        'intrinsicValue': 0,
#        'timeValue': 0,
#        'updatedAt': '2022-02-17 19:08:35',
#        'daysBeforeExpiration': 0},
#       {'contractName': 'AAPL220218C00190000',
#        'contractSize': 'REGULAR',
#        'contractPeriod': 'MONTHLY',
#        'currency': 'USD',
#        'type': 'CALL',
#        'inTheMoney': 'FALSE',
#        'lastTradeDateTime': '2022-02-17 15:52:42',
#        'expirationDate': '2022-02-18',
#        'strike': 190,
#        'lastPrice': 0.01,
#        'bid': 0.01,
#        'ask': 0.01,
#        'change': 0,
#        'changePercent': 0,
#        'volume': 140,
#        'openInterest': 33930,
#        'impliedVolatility': 84.9897,
#        'delta': 0.0043,
#        'gamma': 0.0017,
#        'theta': -0.0477,
#        'vega': 0.0011,
#        'rho': 0,
#        'theoretical': 0.01,
#        'intrinsicValue': 0,
#        'timeValue': 0,
#        'updatedAt': '2022-02-17 19:08:35',
#        'daysBeforeExpiration': 0},
#       {'contractName': 'AAPL220218C00192500',
#        'contractSize': 'REGULAR',
#        'contractPeriod': 'MONTHLY',
#        'currency': 'USD',
#        'type': 'CALL',
#        'inTheMoney': 'FALSE',
#        'lastTradeDateTime': '2022-02-15 15:54:21',
#        'expirationDate': '2022-02-18',
#        'strike': 192.5,
#        'lastPrice': 0.01,
#        'bid': 0.01,
#        'ask': 0.01,
#        'change': 0,
#        'changePercent': 0,
#        'volume': 19,
#        'openInterest': 1158,
#        'impliedVolatility': 0,
#        'delta': 0,
#        'gamma': 0,
#        'theta': 0,
#        'vega': 0,
#        'rho': 0,
#        'theoretical': 0,
#        'intrinsicValue': 0,
#        'timeValue': 0,
#        'updatedAt': '2022-02-17 19:08:35',
#        'daysBeforeExpiration': 0},
#       {'contractName': 'AAPL220218C00195000',
#        'contractSize': 'REGULAR',
#        'contractPeriod': 'MONTHLY',
#        'currency': 'USD',
#        'type': 'CALL',
#        'inTheMoney': 'FALSE',
#        'lastTradeDateTime': '2022-02-17 14:26:52',
#        'expirationDate': '2022-02-18',
#        'strike': 195,
#        'lastPrice': 0.01,
#        'bid': 0.01,
#        'ask': 0.01,
#        'change': 0,
#        'changePercent': 0,
#        'volume': 112,
#        'openInterest': 13662,
#        'impliedVolatility': 101.4782,
#        'delta': 0.0037,
#        'gamma': 0.0012,
#        'theta': -0.0493,
#        'vega': 0.001,
#        'rho': 0,
#        'theoretical': 0.01,
#        'intrinsicValue': 0,
#        'timeValue': 0,
#        'updatedAt': '2022-02-17 19:08:35',
#        'daysBeforeExpiration': 0},
#       {'contractName': 'AAPL220218C00197500',
#        'contractSize': 'REGULAR',
#        'contractPeriod': 'MONTHLY',
#        'currency': 'USD',
#        'type': 'CALL',
#        'inTheMoney': 'FALSE',
#        'lastTradeDateTime': '2022-02-14 12:04:25',
#        'expirationDate': '2022-02-18',
#        'strike': 197.5,
#        'lastPrice': 0.01,
#        'bid': 0.01,
#        'ask': 0.01,
#        'change': 0,
#        'changePercent': 0,
#        'volume': 1,
#        'openInterest': 762,
#        'impliedVolatility': 0,
#        'delta': 0,
#        'gamma': 0,
#        'theta': 0,
#        'vega': 0,
#        'rho': 0,
#        'theoretical': 0,
#        'intrinsicValue': 0,
#        'timeValue': 0,
#        'updatedAt': '2022-02-17 19:08:35',
#        'daysBeforeExpiration': 0},
#       {'contractName': 'AAPL220218C00200000',
#        'contractSize': 'REGULAR',
#        'contractPeriod': 'MONTHLY',
#        'currency': 'USD',
#        'type': 'CALL',
#        'inTheMoney': 'FALSE',
#        'lastTradeDateTime': '2022-02-17 15:50:00',
#        'expirationDate': '2022-02-18',
#        'strike': 200,
#        'lastPrice': 0.01,
#        'bid': 0.01,
#        'ask': 0.01,
#        'change': 0,
#        'changePercent': 0,
#        'volume': 36,
#        'openInterest': 24669,
#        'impliedVolatility': 117.2733,
#        'delta': 0.0032,
#        'gamma': 0.0009,
#        'theta': -0.0506,
#        'vega': 0.0009,
#        'rho': 0,
#        'theoretical': 0.01,
#        'intrinsicValue': 0,
#        'timeValue': 0,
#        'updatedAt': '2022-02-17 19:08:35',
#        'daysBeforeExpiration': 0},
#       {'contractName': 'AAPL220218C00202500',
#        'contractSize': 'REGULAR',
#        'contractPeriod': 'MONTHLY',
#        'currency': 'USD',
#        'type': 'CALL',
#        'inTheMoney': 'FALSE',
#        'lastTradeDateTime': '2022-02-14 09:44:48',
#        'expirationDate': '2022-02-18',
#        'strike': 202.5,
#        'lastPrice': 0.01,
#        'bid': 0.01,
#        'ask': 0.01,
#        'change': 0,
#        'changePercent': 0,
#        'volume': 6,
#        'openInterest': 73,
#        'impliedVolatility': 0,
#        'delta': 0,
#        'gamma': 0,
#        'theta': 0,
#        'vega': 0,
#        'rho': 0,
#        'theoretical': 0,
#        'intrinsicValue': 0,
#        'timeValue': 0,
#        'updatedAt': '2022-02-17 19:08:35',
#        'daysBeforeExpiration': 0},
#       {'contractName': 'AAPL220218C00205000',
#        'contractSize': 'REGULAR',
#        'contractPeriod': 'MONTHLY',
#        'currency': 'USD',
#        'type': 'CALL',
#        'inTheMoney': 'FALSE',
#        'lastTradeDateTime': '2022-02-17 15:46:15',
#        'expirationDate': '2022-02-18',
#        'strike': 205,
#        'lastPrice': 0.01,
#        'bid': 0.01,
#        'ask': 0.01,
#        'change': 0,
#        'changePercent': 0,
#        'volume': 4,
#        'openInterest': 10246,
#        'impliedVolatility': 132.4592,
#        'delta': 0.0029,
#        'gamma': 0.0008,
#        'theta': -0.0518,
#        'vega': 0.0008,
#        'rho': 0,
#        'theoretical': 0.01,
#        'intrinsicValue': 0,
#        'timeValue': 0,
#        'updatedAt': '2022-02-17 19:08:35',
#        'daysBeforeExpiration': 0},
#       {'contractName': 'AAPL220218C00207500',
#        'contractSize': 'REGULAR',
#        'contractPeriod': 'MONTHLY',
#        'currency': 'USD',
#        'type': 'CALL',
#        'inTheMoney': 'FALSE',
#        'lastTradeDateTime': '2022-02-14 00:03:18',
#        'expirationDate': '2022-02-18',
#        'strike': 207.5,
#        'lastPrice': 0.01,
#        'bid': 0.01,
#        'ask': 0.01,
#        'change': 0.01,
#        'changePercent': None,
#        'volume': 15,
#        'openInterest': 13,
#        'impliedVolatility': 0,
#        'delta': 0,
#        'gamma': 0,
#        'theta': 0,
#        'vega': 0,
#        'rho': 0,
#        'theoretical': 0,
#        'intrinsicValue': 0,
#        'timeValue': 0,
#        'updatedAt': '2022-02-17 19:08:35',
#        'daysBeforeExpiration': 0},
#       {'contractName': 'AAPL220218C00210000',
#        'contractSize': 'REGULAR',
#        'contractPeriod': 'MONTHLY',
#        'currency': 'USD',
#        'type': 'CALL',
#        'inTheMoney': 'FALSE',
#        'lastTradeDateTime': '2022-02-17 12:28:27',
#        'expirationDate': '2022-02-18',
#        'strike': 210,
#        'lastPrice': 0.01,
#        'bid': 0.01,
#        'ask': 0.01,
#        'change': 0,
#        'changePercent': 0,
#        'volume': 4,
#        'openInterest': 15971,
#        'impliedVolatility': 147.0994,
#        'delta': 0.0026,
#        'gamma': 0.0006,
#        'theta': -0.0528,
#        'vega': 0.0007,
#        'rho': 0,
#        'theoretical': 0.01,
#        'intrinsicValue': 0,
#        'timeValue': 0,
#        'updatedAt': '2022-02-17 19:08:35',
#        'daysBeforeExpiration': 0},
#       {'contractName': 'AAPL220218C00215000',
#        'contractSize': 'REGULAR',
#        'contractPeriod': 'MONTHLY',
#        'currency': 'USD',
#        'type': 'CALL',
#        'inTheMoney': 'FALSE',
#        'lastTradeDateTime': '2022-02-16 11:18:00',
#        'expirationDate': '2022-02-18',
#        'strike': 215,
#        'lastPrice': 0.01,
#        'bid': 0.01,
#        'ask': 0.01,
#        'change': 0,
#        'changePercent': 0,
#        'volume': 4,
#        'openInterest': 3016,
#        'impliedVolatility': 0,
#        'delta': 0,
#        'gamma': 0,
#        'theta': 0,
#        'vega': 0,
#        'rho': 0,
#        'theoretical': 0,
#        'intrinsicValue': 0,
#        'timeValue': 0,
#        'updatedAt': '2022-02-17 19:08:35',
#        'daysBeforeExpiration': 0},
#       {'contractName': 'AAPL220218C00220000',
#        'contractSize': 'REGULAR',
#        'contractPeriod': 'MONTHLY',
#        'currency': 'USD',
#        'type': 'CALL',
#        'inTheMoney': 'FALSE',
#        'lastTradeDateTime': '2022-02-15 15:33:30',
#        'expirationDate': '2022-02-18',
#        'strike': 220,
#        'lastPrice': 0.01,
#        'bid': 0.01,
#        'ask': 0.01,
#        'change': 0,
#        'changePercent': 0,
#        'volume': 6,
#        'openInterest': 3703,
#        'impliedVolatility': 0,
#        'delta': 0,
#        'gamma': 0,
#        'theta': 0,
#        'vega': 0,
#        'rho': 0,
#        'theoretical': 0,
#        'intrinsicValue': 0,
#        'timeValue': 0,
#        'updatedAt': '2022-02-17 19:08:35',
#        'daysBeforeExpiration': 0},
#       {'contractName': 'AAPL220218C00225000',
#        'contractSize': 'REGULAR',
#        'contractPeriod': 'MONTHLY',
#        'currency': 'USD',
#        'type': 'CALL',
#        'inTheMoney': 'FALSE',
#        'lastTradeDateTime': '2022-02-15 09:36:33',
#        'expirationDate': '2022-02-18',
#        'strike': 225,
#        'lastPrice': 0.01,
#        'bid': 0.01,
#        'ask': 0.01,
#        'change': 0,
#        'changePercent': 0,
#        'volume': 3,
#        'openInterest': 3013,
#        'impliedVolatility': 0,
#        'delta': 0,
#        'gamma': 0,
#        'theta': 0,
#        'vega': 0,
#        'rho': 0,
#        'theoretical': 0,
#        'intrinsicValue': 0,
#        'timeValue': 0,
#        'updatedAt': '2022-02-17 19:08:35',
#        'daysBeforeExpiration': 0},
#       {'contractName': 'AAPL220218C00230000',
#        'contractSize': 'REGULAR',
#        'contractPeriod': 'MONTHLY',
#        'currency': 'USD',
#        'type': 'CALL',
#        'inTheMoney': 'FALSE',
#        'lastTradeDateTime': '2022-02-09 15:03:17',
#        'expirationDate': '2022-02-18',
#        'strike': 230,
#        'lastPrice': 0.01,
#        'bid': 0.01,
#        'ask': 0.01,
#        'change': 0,
#        'changePercent': 0,
#        'volume': 1,
#        'openInterest': 2809,
#        'impliedVolatility': 0,
#        'delta': 0,
#        'gamma': 0,
#        'theta': 0,
#        'vega': 0,
#        'rho': 0,
#        'theoretical': 0,
#        'intrinsicValue': 0,
#        'timeValue': 0,
#        'updatedAt': '2022-02-17 19:08:35',
#        'daysBeforeExpiration': 0},
#       {'contractName': 'AAPL220218C00235000',
#        'contractSize': 'REGULAR',
#        'contractPeriod': 'MONTHLY',
#        'currency': 'USD',
#        'type': 'CALL',
#        'inTheMoney': 'FALSE',
#        'lastTradeDateTime': '2022-02-10 09:54:18',
#        'expirationDate': '2022-02-18',
#        'strike': 235,
#        'lastPrice': 0.01,
#        'bid': 0.01,
#        'ask': 0.01,
#        'change': 0,
#        'changePercent': 0,
#        'volume': 1,
#        'openInterest': 1314,
#        'impliedVolatility': 0,
#        'delta': 0,
#        'gamma': 0,
#        'theta': 0,
#        'vega': 0,
#        'rho': 0,
#        'theoretical': 0,
#        'intrinsicValue': 0,
#        'timeValue': 0,
#        'updatedAt': '2022-02-17 19:08:35',
#        'daysBeforeExpiration': 0},
#       {'contractName': 'AAPL220218C00240000',
#        'contractSize': 'REGULAR',
#        'contractPeriod': 'MONTHLY',
#        'currency': 'USD',
#        'type': 'CALL',
#        'inTheMoney': 'FALSE',
#        'lastTradeDateTime': '2022-02-07 13:36:36',
#        'expirationDate': '2022-02-18',
#        'strike': 240,
#        'lastPrice': 0.01,
#        'bid': 0.01,
#        'ask': 0.01,
#        'change': 0,
#        'changePercent': 0,
#        'volume': 115,
#        'openInterest': 994,
#        'impliedVolatility': 0,
#        'delta': 0,
#        'gamma': 0,
#        'theta': 0,
#        'vega': 0,
#        'rho': 0,
#        'theoretical': 0,
#        'intrinsicValue': 0,
#        'timeValue': 0,
#        'updatedAt': '2022-02-17 19:08:35',
#        'daysBeforeExpiration': 0},
#       {'contractName': 'AAPL220218C00245000',
#        'contractSize': 'REGULAR',
#        'contractPeriod': 'MONTHLY',
#        'currency': 'USD',
#        'type': 'CALL',
#        'inTheMoney': 'FALSE',
#        'lastTradeDateTime': '2022-02-08 11:37:36',
#        'expirationDate': '2022-02-18',
#        'strike': 245,
#        'lastPrice': 0.01,
#        'bid': 0.01,
#        'ask': 0.01,
#        'change': 0,
#        'changePercent': 0,
#        'volume': 15,
#        'openInterest': 1792,
#        'impliedVolatility': 0,
#        'delta': 0,
#        'gamma': 0,
#        'theta': 0,
#        'vega': 0,
#        'rho': 0,
#        'theoretical': 0,
#        'intrinsicValue': 0,
#        'timeValue': 0,
#        'updatedAt': '2022-02-17 19:08:35',
#        'daysBeforeExpiration': 0},
#       {'contractName': 'AAPL220218C00250000',
#        'contractSize': 'REGULAR',
#        'contractPeriod': 'MONTHLY',
#        'currency': 'USD',
#        'type': 'CALL',
#        'inTheMoney': 'FALSE',
#        'lastTradeDateTime': '2022-02-09 15:54:03',
#        'expirationDate': '2022-02-18',
#        'strike': 250,
#        'lastPrice': 0.01,
#        'bid': 0.01,
#        'ask': 0.01,
#        'change': 0,
#        'changePercent': 0,
#        'volume': 1,
#        'openInterest': 2073,
#        'impliedVolatility': 0,
#        'delta': 0,
#        'gamma': 0,
#        'theta': 0,
#        'vega': 0,
#        'rho': 0,
#        'theoretical': 0,
#        'intrinsicValue': 0,
#        'timeValue': 0,
#        'updatedAt': '2022-02-17 19:08:35',
#        'daysBeforeExpiration': 0},
#       {'contractName': 'AAPL220218C00255000',
#        'contractSize': 'REGULAR',
#        'contractPeriod': 'MONTHLY',
#        'currency': 'USD',
#        'type': 'CALL',
#        'inTheMoney': 'FALSE',
#        'lastTradeDateTime': '2022-01-31 15:56:16',
#        'expirationDate': '2022-02-18',
#        'strike': 255,
#        'lastPrice': 0.01,
#        'bid': 0.01,
#        'ask': 0.01,
#        'change': -0.02,
#        'changePercent': -0.6667,
#        'volume': 234,
#        'openInterest': 1865,
#        'impliedVolatility': 0,
#        'delta': 0,
#        'gamma': 0,
#        'theta': 0,
#        'vega': 0,
#        'rho': 0,
#        'theoretical': 0,
#        'intrinsicValue': 0,
#        'timeValue': 0,
#        'updatedAt': '2022-02-17 19:08:35',
#        'daysBeforeExpiration': 0},
#       {'contractName': 'AAPL220218C00260000',
#        'contractSize': 'REGULAR',
#        'contractPeriod': 'MONTHLY',
#        'currency': 'USD',
#        'type': 'CALL',
#        'inTheMoney': 'FALSE',
#        'lastTradeDateTime': '2022-02-09 14:58:48',
#        'expirationDate': '2022-02-18',
#        'strike': 260,
#        'lastPrice': 0.01,
#        'bid': 0.01,
#        'ask': 0.01,
#        'change': 0,
#        'changePercent': 0,
#        'volume': 1,
#        'openInterest': 4924,
#        'impliedVolatility': 0,
#        'delta': 0,
#        'gamma': 0,
#        'theta': 0,
#        'vega': 0,
#        'rho': 0,
#        'theoretical': 0,
#        'intrinsicValue': 0,
#        'timeValue': 0,
#        'updatedAt': '2022-02-17 19:08:35',
#        'daysBeforeExpiration': 0},
#       {'contractName': 'AAPL220218C00265000',
#        'contractSize': 'REGULAR',
#        'contractPeriod': 'MONTHLY',
#        'currency': 'USD',
#        'type': 'CALL',
#        'inTheMoney': 'FALSE',
#        'lastTradeDateTime': '2022-01-31 15:54:13',
#        'expirationDate': '2022-02-18',
#        'strike': 265,
#        'lastPrice': 0.01,
#        'bid': 0.01,
#        'ask': 0.01,
#        'change': 0,
#        'changePercent': 0,
#        'volume': 503,
#        'openInterest': 1115,
#        'impliedVolatility': 0,
#        'delta': 0,
#        'gamma': 0,
#        'theta': 0,
#        'vega': 0,
#        'rho': 0,
#        'theoretical': 0,
#        'intrinsicValue': 0,
#        'timeValue': 0,
#        'updatedAt': '2022-02-17 19:08:35',
#        'daysBeforeExpiration': 0},
#       {'contractName': 'AAPL220218C00270000',
#        'contractSize': 'REGULAR',
#        'contractPeriod': 'MONTHLY',
#        'currency': 'USD',
#        'type': 'CALL',
#        'inTheMoney': 'FALSE',
#        'lastTradeDateTime': '2022-02-17 14:23:22',
#        'expirationDate': '2022-02-18',
#        'strike': 270,
#        'lastPrice': 0.01,
#        'bid': 0.01,
#        'ask': 0.01,
#        'change': 0,
#        'changePercent': 0,
#        'volume': 5,
#        'openInterest': 803,
#        'impliedVolatility': 292.6158,
#        'delta': 0.0014,
#        'gamma': 0.0002,
#        'theta': -0.0598,
#        'vega': 0.0004,
#        'rho': 0,
#        'theoretical': 0.01,
#        'intrinsicValue': 0,
#        'timeValue': 0,
#        'updatedAt': '2022-02-17 19:08:35',
#        'daysBeforeExpiration': 0},
#       {'contractName': 'AAPL220218C00275000',
#        'contractSize': 'REGULAR',
#        'contractPeriod': 'MONTHLY',
#        'currency': 'USD',
#        'type': 'CALL',
#        'inTheMoney': 'FALSE',
#        'lastTradeDateTime': '2022-02-15 09:30:05',
# ...
#    37  AAPL230616P00290000
#    38  AAPL230616P00300000  ,
#    '2023-09-15':      Theta   Gamma  Rho    Vega                cName  cDelta  cVolume  cBidP  \
#    0  -0.0059  0.0008    0  0.1504  AAPL230915C00070000  0.9404        1  99.70
#    1  -0.0066  0.0009    0  0.1743  AAPL230915C00075000  0.9419        2  95.85
#    2  -0.0074  0.0011    0  0.2017  AAPL230915C00080000  0.9298       20  91.35
#    3  -0.0082  0.0013    0  0.2321  AAPL230915C00085000  0.9203        1  86.85
#    4  -0.0091  0.0015    0  0.2639  AAPL230915C00090000  0.9079        3  81.65
#    5  -0.0102  0.0018    0  0.3020  AAPL230915C00095000  0.8968        2  78.10
#    6  -0.0111  0.0020    0  0.3395  AAPL230915C00100000  0.8818       10  73.85
#    7  -0.0118  0.0023    0  0.3731  AAPL230915C00105000  0.8654        1  69.65
#    8  -0.0133  0.0027    0  0.4227  AAPL230915C00110000  0.8535        1  65.60
#    9  -0.0142  0.0030    0  0.4640  AAPL230915C00115000  0.8373        1  61.60
#    10 -0.0153  0.0034    0  0.5080  AAPL230915C00120000  0.8176        1  57.95
#    11 -0.0163  0.0037    0  0.5517  AAPL230915C00125000  0.7989        2  53.95
#    12 -0.0173  0.0041    0  0.5950  AAPL230915C00130000  0.7772        1  50.30
#    13 -0.0181  0.0045    0  0.6366  AAPL230915C00135000  0.7542        1  46.80
#    14 -0.0189  0.0048    0  0.6763  AAPL230915C00140000  0.7306        1  43.45
#    15 -0.0196  0.0052    0  0.7130  AAPL230915C00145000  0.7051        1  40.20
#    16 -0.0203  0.0055    0  0.7462  AAPL230915C00150000  0.6791        6  37.65
#    17 -0.0208  0.0059    0  0.7752  AAPL230915C00155000  0.6524       10  34.55
#    18 -0.0211  0.0061    0  0.7992  AAPL230915C00160000  0.6246        5  31.45
#    19 -0.0210  0.0065    0  0.8182  AAPL230915C00165000  0.5963        4  28.90
#    20 -0.0210  0.0067    0  0.8310  AAPL230915C00170000  0.5674       79  26.50
#    21 -0.0213  0.0067    0  0.8371  AAPL230915C00175000  0.5389       44  24.20
#    22 -0.0211  0.0069    0  0.8375  AAPL230915C00180000  0.5096       68  22.05
#    23 -0.0207  0.0069    0  0.8315  AAPL230915C00185000  0.4819       30  20.10
#    24 -0.0202  0.0069    0  0.8191  AAPL230915C00190000  0.4544       15  18.50
#    25 -0.0196  0.0069    0  0.8006  AAPL230915C00195000  0.4261        1  16.55
#    26 -0.0188  0.0068    0  0.7763  AAPL230915C00200000  0.3999       18  15.00
#    27 -0.0178  0.0066    0  0.7444  AAPL230915C00205000  0.3731        6  13.55
#    28 -0.0168  0.0064    0  0.7084  AAPL230915C00210000  0.3481        5  12.25
#    29 -0.0148  0.0059    0  0.6262  AAPL230915C00220000  0.2991       31   9.90
#    30 -0.0123  0.0051    0  0.5244  AAPL230915C00230000  0.2574        7   8.00
#    31 -0.0097  0.0042    0  0.4072  AAPL230915C00240000  0.2194       11   6.50
#    32 -0.0071  0.0032    0  0.2826  AAPL230915C00250000  0.1902        1   5.30
#    33 -0.0049  0.0020    0  0.1663  AAPL230915C00260000  0.1566        1   4.15
#    34 -0.0056  0.0021    0  0.1904  AAPL230915C00270000  0.1309        7   3.30
#    35 -0.0035  0.0010    0  0.0788  AAPL230915C00280000  0.1098        2   2.61
#    36 -0.0030  0.0006    0  0.0437  AAPL230915C00290000  0.0928      100   2.13
#    37  0.0000  0.0000    0  0.0000  AAPL230915C00300000  0.0784        7   1.73
#
#        cTheo   cAskP  Strike   pBidP  pTheo   pAskP  pVolume  pDelta  \
#    0     NaN  103.45      70    1.31    NaN    1.55        7 -0.0316
#    1     NaN   97.80      75    1.54    NaN    1.84        1 -0.0379
#    2     NaN   93.25      80    1.86    NaN    2.16       20 -0.0453
#    3     NaN   88.75      85    2.24    NaN    2.54        1 -0.0541
#    4     NaN   85.25      90    2.67    NaN    3.00        1 -0.0637
#    5     NaN   79.90      95    3.20    NaN    3.55        1 -0.0759
#    6     NaN   75.55     100    3.80    NaN    4.10        1 -0.0887
#    7     NaN   71.40     105    4.40    NaN    4.85        2 -0.1008
#    8     NaN   67.25     110    5.20    NaN    5.65        2 -0.1200
#    9     NaN   62.90     115    6.05    NaN    6.45        1 -0.1373
#    10    NaN   59.15     120    7.00    NaN    7.50        5 -0.1572
#    11    NaN   55.05     125    8.10    NaN    8.60        1 -0.1788
#    12    NaN   51.50     130    9.30    NaN    9.90        2 -0.2023
#    13    NaN   48.15     135   10.65    NaN   11.25        1 -0.2273
#    14    NaN   44.80     140   12.15    NaN   12.80        4 -0.2542
#    15    NaN   41.55     145   13.80    NaN   14.45        2 -0.2826
#    16    NaN   38.40     150   15.60    NaN   16.30        1 -0.3124
#    17    NaN   35.50     155   17.65    NaN   18.20       10 -0.3436
#    18    NaN   32.60     160   19.70    NaN   20.45       27 -0.3759
#    19    NaN   29.95     165   21.95    NaN   22.80        2 -0.4099
#    20    NaN   27.50     170   24.45    NaN   25.30        1 -0.4443
#    21    NaN   25.15     175   27.05    NaN   28.00        1 -0.4770
#    22    NaN   23.00     180   29.85    NaN   30.80      192 -0.5115
#    23    NaN   21.00     185   32.80    NaN   33.80        2 -0.5459
#    24    NaN   19.05     190   35.85    NaN   36.95        1 -0.5803
#    25    NaN   17.35     195   39.10    NaN   40.25        1 -0.6140
#    26    NaN   15.70     200   42.50    NaN   43.70        2 -0.6471
#    27    NaN   14.30     205   45.65    NaN   47.40        1 -0.6814
#    28    NaN   12.95     210   48.15    NaN   52.25      100 -0.7133
#    29    NaN   10.55     220   57.50    NaN   58.60       12 -0.7712
#    30    NaN    8.55     230   65.40    NaN   67.00        1 -0.8270
#    31    NaN    6.95     240   73.90    NaN   75.55       22 -0.8782
#    32    NaN    5.65     250   82.75    NaN   84.55        6 -0.9224
#    33    NaN    4.60     260   92.25    NaN   93.70        6 -0.9563
#    34    NaN    3.70     270  101.15    NaN  103.15        2 -0.9498
#    35    NaN    3.05     280  109.50    NaN  112.65        1 -0.9773
#    36    NaN    2.51     290  120.35    NaN  122.55      120 -0.9846
#    37    NaN    2.08     300  129.20    NaN  132.10        1  0.0000
#
#                      pName
#    0   AAPL230915P00070000
#    1   AAPL230915P00075000
#    2   AAPL230915P00080000
#    3   AAPL230915P00085000
#    4   AAPL230915P00090000
#    5   AAPL230915P00095000
#    6   AAPL230915P00100000
#    7   AAPL230915P00105000
#    8   AAPL230915P00110000
#    9   AAPL230915P00115000
#    10  AAPL230915P00120000
#    11  AAPL230915P00125000
#    12  AAPL230915P00130000
#    13  AAPL230915P00135000
#    14  AAPL230915P00140000
#    15  AAPL230915P00145000
#    16  AAPL230915P00150000
#    17  AAPL230915P00155000
#    18  AAPL230915P00160000
#    19  AAPL230915P00165000
#    20  AAPL230915P00170000
#    21  AAPL230915P00175000
#    22  AAPL230915P00180000
#    23  AAPL230915P00185000
#    24  AAPL230915P00190000
#    25  AAPL230915P00195000
#    26  AAPL230915P00200000
#    27  AAPL230915P00205000
#    28  AAPL230915P00210000
#    29  AAPL230915P00220000
#    30  AAPL230915P00230000
#    31  AAPL230915P00240000
#    32  AAPL230915P00250000
#    33  AAPL230915P00260000
#    34  AAPL230915P00270000
#    35  AAPL230915P00280000
#    36  AAPL230915P00290000
#    37  AAPL230915P00300000  ,
#    '2024-01-19':      Theta   Gamma  Rho    Vega                cName  cDelta  cVolume   cBidP  \
#    0  -0.0033  0.0004    0  0.0953  AAPL240119C00050000  0.9629        1  119.85
#    1  -0.0037  0.0004    0  0.1116  AAPL240119C00055000  0.9597        1  115.25
#    2  -0.0042  0.0005    0  0.1320  AAPL240119C00060000  0.9573       13  108.60
#    3  -0.0050  0.0007    0  0.1604  AAPL240119C00065000  0.9492       15  104.00
#    4  -0.0055  0.0008    0  0.1827  AAPL240119C00070000  0.9400       11   99.50
#    5  -0.0063  0.0010    0  0.2143  AAPL240119C00075000  0.9293        3   97.00
#    6  -0.0071  0.0011    0  0.2473  AAPL240119C00080000  0.9099        1   91.10
#    7  -0.0078  0.0013    0  0.2812  AAPL240119C00085000  0.9154        3   87.00
#    8  -0.0086  0.0016    0  0.3184  AAPL240119C00090000  0.8964        1   82.00
#    9  -0.0095  0.0018    0  0.3585  AAPL240119C00095000  0.8863        1   79.70
#    10 -0.0102  0.0021    0  0.3970  AAPL240119C00100000  0.8712       13   75.55
#    11 -0.0113  0.0023    0  0.4451  AAPL240119C00105000  0.8585       14   70.40
#    12 -0.0122  0.0026    0  0.4904  AAPL240119C00110000  0.8370        3   66.35
#    13 -0.0130  0.0029    0  0.5358  AAPL240119C00115000  0.8249        1   63.70
#    14 -0.0140  0.0033    0  0.5829  AAPL240119C00120000  0.8075       19   60.15
#    15 -0.0148  0.0036    0  0.6291  AAPL240119C00125000  0.7888        2   56.35
#    16 -0.0154  0.0039    0  0.6718  AAPL240119C00130000  0.7666       27   52.85
#    17 -0.0162  0.0043    0  0.7156  AAPL240119C00135000  0.7458        7   49.45
#    18 -0.0170  0.0046    0  0.7566  AAPL240119C00140000  0.7248       16   46.25
#    19 -0.0175  0.0049    0  0.7939  AAPL240119C00145000  0.7010        7   43.10
#    20 -0.0182  0.0051    0  0.8278  AAPL240119C00150000  0.6771       82   40.20
#    21 -0.0183  0.0055    0  0.8569  AAPL240119C00155000  0.6527        8   36.60
#    22 -0.0186  0.0057    0  0.8816  AAPL240119C00160000  0.6276       32   34.65
#    23 -0.0188  0.0059    0  0.9009  AAPL240119C00165000  0.6028       34   32.45
#    24 -0.0191  0.0060    0  0.9143  AAPL240119C00170000  0.5775      108   29.75
#    25 -0.0191  0.0062    0  0.9223  AAPL240119C00175000  0.5516      119   27.50
#    26 -0.0187  0.0064    0  0.9244  AAPL240119C00180000  0.5271      135   25.60
#    27 -0.0186  0.0064    0  0.9206  AAPL240119C00185000  0.5010       85   23.45
#    28 -0.0182  0.0064    0  0.9108  AAPL240119C00190000  0.4763      292   21.60
#    29 -0.0178  0.0064    0  0.8950  AAPL240119C00195000  0.4513        6   19.80
#    30 -0.0174  0.0063    0  0.8752  AAPL240119C00200000  0.4262       94   18.25
#    31 -0.0165  0.0062    0  0.8467  AAPL240119C00205000  0.4047       20   16.70
#    32 -0.0156  0.0061    0  0.8105  AAPL240119C00210000  0.3812       10   15.50
#    33 -0.0150  0.0059    0  0.7774  AAPL240119C00215000  0.3577       22   14.05
#    34 -0.0137  0.0057    0  0.7244  AAPL240119C00220000  0.3366        6   12.95
#    35 -0.0132  0.0054    0  0.6899  AAPL240119C00225000  0.3162        2   11.90
#    36 -0.0122  0.0052    0  0.6394  AAPL240119C00230000  0.2981        9   10.70
#    37 -0.0113  0.0048    0  0.5894  AAPL240119C00235000  0.2771        2    9.80
#    38 -0.0102  0.0045    0  0.5301  AAPL240119C00240000  0.2593       12    9.00
#    39 -0.0091  0.0041    0  0.4696  AAPL240119C00245000  0.2433        4    8.10
#    40 -0.0080  0.0036    0  0.4080  AAPL240119C00250000  0.2273       28    7.60
#    41 -0.0057  0.0026    0  0.2663  AAPL240119C00260000  0.1982       23    6.30
#    42 -0.0066  0.0026    0  0.2947  AAPL240119C00270000  0.1733        6    5.25
#    43 -0.0031  0.0008    0  0.0712  AAPL240119C00280000  0.1471        1    4.30
#    44 -0.0075  0.0024    0  0.3119  AAPL240119C00290000  0.1310        2    3.60
#    45 -0.0069  0.0020    0  0.2692  AAPL240119C00300000  0.1093      184    3.00
#
#        cTheo   cAskP  Strike   pBidP  pTheo   pAskP  pVolume  pDelta  \
#    0     NaN  121.40      50    0.74    NaN    0.86       43 -0.0163
#    1     NaN  116.75      55    0.90    NaN    1.08        5 -0.0197
#    2     NaN  113.50      60    1.07    NaN    1.30        1 -0.0240
#    3     NaN  108.90      65    1.32    NaN    1.58       28 -0.0303
#    4     NaN  104.40      70    1.60    NaN    1.84        1 -0.0355
#    5     NaN   98.55      75    1.95    NaN    2.22       10 -0.0432
#    6     NaN   95.50      80    2.38    NaN    2.60       30 -0.0517
#    7     NaN   89.35      85    2.78    NaN    3.10        1 -0.0608
#    8     NaN   86.00      90    3.25    NaN    3.60       13 -0.0714
#    9     NaN   80.80      95    3.90    NaN    4.20       10 -0.0835
#    10    NaN   76.95     100    4.55    NaN    4.90       26 -0.0958
#    11    NaN   73.65     105    5.35    NaN    5.70        1 -0.1122
#    12    NaN   69.75     110    6.20    NaN    6.60        1 -0.1288
#    13    NaN   65.00     115    7.20    NaN    7.50        8 -0.1467
#    14    NaN   61.10     120    8.30    NaN    8.70       10 -0.1668
#    15    NaN   57.55     125    9.50    NaN    9.80       14 -0.1882
#    16    NaN   54.00     130   10.80    NaN   11.30        5 -0.2100
#    17    NaN   50.60     135   12.25    NaN   12.75      121 -0.2347
#    18    NaN   47.15     140   13.90    NaN   14.40       13 -0.2607
#    19    NaN   44.15     145   15.65    NaN   16.15        8 -0.2876
#    20    NaN   42.00     150   17.55    NaN   18.10      243 -0.3160
#    21    NaN   38.85     155   19.60    NaN   20.15      126 -0.3449
#    22    NaN   35.55     160   21.75    NaN   22.40        3 -0.3751
#    23    NaN   33.45     165   24.10    NaN   24.75      758 -0.4059
#    24    NaN   30.60     170   26.65    NaN   27.30        6 -0.4363
#    25    NaN   28.30     175   29.30    NaN   30.00        3 -0.4676
#    26    NaN   26.15     180   32.10    NaN   32.70        3 -0.5016
#    27    NaN   24.15     185   35.00    NaN   35.80        1 -0.5318
#    28    NaN   22.25     190   38.10    NaN   38.95        2 -0.5632
#    29    NaN   20.50     195   41.30    NaN   42.15        1 -0.5948
#    30    NaN   18.85     200   44.65    NaN   45.55        3 -0.6236
#    31    NaN   17.35     205   48.10    NaN   49.05        3 -0.6561
#    32    NaN   15.90     210   51.70    NaN   52.70        1 -0.6893
#    33    NaN   14.60     215   55.40    NaN   56.40      113 -0.7150
#    34    NaN   13.40     220   58.40    NaN   60.30      388 -0.7503
#    35    NaN   12.30     225   63.10    NaN   64.25        4 -0.7704
#    36    NaN   11.25     230   67.10    NaN   68.30        1 -0.7970
#    37    NaN   10.30     235   71.40    NaN   72.40      234 -0.8206
#    38    NaN    9.40     240   75.55    NaN   76.60        2 -0.8460
#    39    NaN    8.60     245   79.85    NaN   80.90       10 -0.8693
#    40    NaN    7.90     250   84.25    NaN   85.30       10 -0.8909
#    41    NaN    6.65     260   93.15    NaN   94.30       10 -0.9335
#    42    NaN    5.55     270  100.50    NaN  104.00      108 -0.9257
#    43    NaN    4.65     280  111.65    NaN  112.90        1 -0.9786
#    44    NaN    3.95     290  119.60    NaN  124.30        1 -0.9208
#    45    NaN    3.30     300  129.10    NaN  134.00        3 -0.9328
#
#                      pName
#    0   AAPL240119P00050000
#    1   AAPL240119P00055000
#    2   AAPL240119P00060000
#    3   AAPL240119P00065000
#    4   AAPL240119P00070000
#    5   AAPL240119P00075000
#    6   AAPL240119P00080000
#    7   AAPL240119P00085000
#    8   AAPL240119P00090000
#    9   AAPL240119P00095000
#    10  AAPL240119P00100000
#    11  AAPL240119P00105000
#    12  AAPL240119P00110000
#    13  AAPL240119P00115000
#    14  AAPL240119P00120000
#    15  AAPL240119P00125000
#    16  AAPL240119P00130000
#    17  AAPL240119P00135000
#    18  AAPL240119P00140000
#    19  AAPL240119P00145000
#    20  AAPL240119P00150000
#    21  AAPL240119P00155000
#    22  AAPL240119P00160000
#    23  AAPL240119P00165000
#    24  AAPL240119P00170000
#    25  AAPL240119P00175000
#    26  AAPL240119P00180000
#    27  AAPL240119P00185000
#    28  AAPL240119P00190000
#    29  AAPL240119P00195000
#    30  AAPL240119P00200000
#    31  AAPL240119P00205000
#    32  AAPL240119P00210000
#    33  AAPL240119P00215000
#    34  AAPL240119P00220000
#    35  AAPL240119P00225000
#    36  AAPL240119P00230000
#    37  AAPL240119P00235000
#    38  AAPL240119P00240000
#    39  AAPL240119P00245000
#    40  AAPL240119P00250000
#    41  AAPL240119P00260000
#    42  AAPL240119P00270000
#    43  AAPL240119P00280000
#    44  AAPL240119P00290000
#    45  AAPL240119P00300000  }}}

# %%
# Annualised Log Return (of Underlying)
import math
url = f"https://eodhistoricaldata.com/api/eod/AAPL.US?api_token=OeAFFmMliFG5orCUuwAKQ8l4WWFQ67YX"
response = requests.request("GET", url)
with open('data/AAPL_historical_data.csv', 'w') as f:
    f.write(response.text)
df = pd.read_csv('data/AAPL_historical_data.csv')
dfa = df.dropna().iloc[len(df)-252:len(df)]
sum([math.log(row['Close']/dfa.loc[i-1]['Close']) for i, row, in dfa.iterrows() if i != dfa.iloc[0].name])
# Out:
# 0.2940182254412781
