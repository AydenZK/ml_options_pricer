# %%
import requests
import pandas as pd

pd.set_option('display.max_rows', None)

# %% [markdown]
# Given a ticker, we will query the
# - stock price
# - available exercise prices
# - available times to expiration
# - risk-free interest rate
# - volatility
#
# and use black scholes formula to return the option price

# %% [markdown]
# Choosing Options:
#
# - Choose Ticker
# > see all expiries
# - Choose Expiry
# > See options chain for that Expiry
# - Choose option by code
# - Plug it into formula
#
# or
#
# - Choose Ticker, OptType, Expiry and Strike
# - Plug into formula

# %%
API_KEY = "OeAFFmMliFG5orCUuwAKQ8l4WWFQ67YX"

MEMORY = {}

OPTIONS = {}

RENAME_MAP = {
    'CALL': {
        'strike': 'Strike', 
        'contractName': 'cName',
        'lastPrice': 'lastPrice', 
        'bid': 'cBidP', 
        'ask': 'cAskP',
        'volume': 'cVolume', 
        'impliedVolatility': 'impliedVolatility', 
        'delta': 'cDelta', 
        'gamma': 'Gamma', 
        'theta': 'Theta', 
        'vega': 'Vega', 
        'rho': 'Rho'
    },
    'PUT': {
        'strike': 'Strike', 
        'contractName': 'pName',
        'lastPrice': 'lastPrice', 
        'bid': 'pBidP', 
        'ask': 'pAskP',
        'volume': 'pVolume', 
        'impliedVolatility': 'impliedVolatility', 
        'delta': 'pDelta', 
        'gamma': 'Gamma', 
        'theta': 'Theta', 
        'vega': 'Vega', 
        'rho': 'Rho'
    }
}

# %%
def query_data(ticker):
    global OPTIONS
    global MEMORY
    global API_KEY
    global RENAME_MAP

    if ticker not in OPTIONS:
        url = f"https://eodhistoricaldata.com/api/options/{ticker}.US?api_token={API_KEY}"

        response = requests.request("GET", url)

        OPTIONS[ticker] = response.json()
        OPTIONS[ticker]['expiries'] = [i['expirationDate'] for i in OPTIONS[ticker]['data']]
        OPTIONS[ticker]['options_chain'] = {}

        for sample in OPTIONS[ticker]['data']:
            opt_chain = {opt['strike']:{} for opt in sample['options']["CALL"]} if len(sample['options']["CALL"]) > len(sample['options']["PUT"]) else {opt['strike']:{} for opt in sample['options']["PUT"]}
            opt_types = ['CALL', 'PUT']
            for opt_type in opt_types:
                for opt in sample['options'][opt_type]: 
                    opt_chain[opt['strike']].update({RENAME_MAP[opt_type][k]:v for k, v in opt.items() if k in ['strike', 'bid', 'ask', 'volume', 'delta', 'gamma', 'theta', 'vega', 'rho', 'contractName']})
                    MEMORY[opt['contractName']] = opt
            
            OPTIONS[ticker]['options_chain'][sample['expirationDate']] = pd.DataFrame(list(opt_chain.values()), columns = ["Theta", "Gamma", "Rho", "Vega", "cName", "cDelta", "cVolume", "cBidP", "cTheo", "cAskP", "Strike", "pBidP", "pTheo", "pAskP", "pVolume", "pDelta", 'pName'])
    
    return OPTIONS[ticker]['data']

class OptionFromId:
    def __init__(self, contract_name, memory={}):
        self.contract_name = contract_name
        self.ticker = ""
        self.generate_ticker()

        query_data(self.ticker)

        if memory:
            self.memory = {contract_name: memory}
        else:
            self.memory = MEMORY
        
        self.stock_price = OPTIONS[self.ticker]['lastTradePrice']

        self.opt_type = self.memory[contract_name]['type']
        self.exercise_price =  self.memory[contract_name]['strike']
        self.time_to_expiration =  self.memory[contract_name]['daysBeforeExpiration']

        self.volatility = 0
        self.interest_rate = 0

    def generate_ticker(self):
        for i in self.contract_name:
            if i.isalpha():
                self.ticker += i
            else: break

class OptionByChoice:
    def __init__(self, ticker, opt_type, strike, expiration):
        self.data = query_data(ticker)
        self.strike = strike
        self.expiration = expiration

        opts_date = self.find_opt_date()
        self.opt_data = self.find_opt(opts_date['options'][opt_type])
        self.option = OptionFromId(self.opt_data['contractName'], memory=self.opt_data)

    def find_opt_date(self):
        for opt in self.data:
            if opt["expirationDate"] == self.expiration:
                return opt
        raise KeyError(f"No option with date: {self.expiration}")

    def find_opt(self, opts_datetype):
        for opt in opts_datetype:
            if opt['strike'] == self.strike:
                return opt
        raise KeyError(f"No option with date: {self.expiration}, strike: {self.strike}")

# %%
config = {
    'ticker': "AAPL"
}

# or 

config = {
    'ticker': "AAPL",
    'opt_type': 'CALL',
    'strike': 170,
    'expiration': '2022-02-25'
}

# or

config = {
    'id': "AAPL220218C00070000"
}

class OptionsPricer:
    def __init__(self, config):
        self.config = config
        if {'opt_type', 'strike', 'expiration'}.issubset(set(config.keys())):
            self.option = OptionByChoice(**config).option
        elif 'id' in config.keys():
            self.option = OptionFromId(config['id'])
        else:
            query_data(config['ticker'])
            print("See below expiries, and then `OPTIONS[option_chain][<expiry>]` to see options chains")
            print(OPTIONS['expiries'])

aapl = OptionsPricer(config)
aapl.option

# %%
MEMORY
# Out:
# {'AAPL220218C00070000': {'contractName': 'AAPL220218C00070000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'TRUE',
#   'lastTradeDateTime': '2022-02-14 15:55:06',
#   'expirationDate': '2022-02-18',
#   'strike': 70,
#   'lastPrice': 98.2,
#   'bid': 102.3,
#   'ask': 102.75,
#   'change': -4.23,
#   'changePercent': -0.0413,
#   'volume': 1,
#   'openInterest': 16,
#   'impliedVolatility': 549.0118,
#   'delta': 0.9923,
#   'gamma': 0.0003,
#   'theta': -0.3696,
#   'vega': 0.0027,
#   'rho': 0,
#   'theoretical': 102.75,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00075000': {'contractName': 'AAPL220218C00075000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'TRUE',
#   'lastTradeDateTime': '2022-02-09 14:51:22',
#   'expirationDate': '2022-02-18',
#   'strike': 75,
#   'lastPrice': 100.85,
#   'bid': 97.3,
#   'ask': 97.75,
#   'change': 4.77,
#   'changePercent': 0.0496,
#   'volume': 12,
#   'openInterest': 11,
#   'impliedVolatility': 510.0037,
#   'delta': 0.9917,
#   'gamma': 0.0003,
#   'theta': -0.3668,
#   'vega': 0.0029,
#   'rho': 0,
#   'theoretical': 97.75,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00080000': {'contractName': 'AAPL220218C00080000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'TRUE',
#   'lastTradeDateTime': '2022-02-16 14:44:13',
#   'expirationDate': '2022-02-18',
#   'strike': 80,
#   'lastPrice': 92.1,
#   'bid': 92.3,
#   'ask': 92.75,
#   'change': 0.49,
#   'changePercent': 0.0053,
#   'volume': 1,
#   'openInterest': 4,
#   'impliedVolatility': 473.5204,
#   'delta': 0.9911,
#   'gamma': 0.0004,
#   'theta': -0.3636,
#   'vega': 0.0031,
#   'rho': 0,
#   'theoretical': 92.75,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00085000': {'contractName': 'AAPL220218C00085000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'TRUE',
#   'lastTradeDateTime': '2022-02-15 12:03:51',
#   'expirationDate': '2022-02-18',
#   'strike': 85,
#   'lastPrice': 86.52,
#   'bid': 87.25,
#   'ask': 87.75,
#   'change': -0.49,
#   'changePercent': -0.0056,
#   'volume': 3,
#   'openInterest': 741,
#   'impliedVolatility': 439.23,
#   'delta': 0.9904,
#   'gamma': 0.0005,
#   'theta': -0.3602,
#   'vega': 0.0033,
#   'rho': 0,
#   'theoretical': 87.75,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00090000': {'contractName': 'AAPL220218C00090000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'TRUE',
#   'lastTradeDateTime': '2022-02-16 14:13:44',
#   'expirationDate': '2022-02-18',
#   'strike': 90,
#   'lastPrice': 81.45,
#   'bid': 82.3,
#   'ask': 82.75,
#   'change': -0.79,
#   'changePercent': -0.0096,
#   'volume': 1,
#   'openInterest': 37,
#   'impliedVolatility': 406.8576,
#   'delta': 0.9896,
#   'gamma': 0.0005,
#   'theta': -0.3565,
#   'vega': 0.0035,
#   'rho': 0,
#   'theoretical': 82.75,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00095000': {'contractName': 'AAPL220218C00095000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'TRUE',
#   'lastTradeDateTime': '2022-02-15 12:01:03',
#   'expirationDate': '2022-02-18',
#   'strike': 95,
#   'lastPrice': 76.55,
#   'bid': 77.3,
#   'ask': 77.75,
#   'change': -0.48,
#   'changePercent': -0.0062,
#   'volume': 5,
#   'openInterest': 18,
#   'impliedVolatility': 376.173,
#   'delta': 0.9888,
#   'gamma': 0.0006,
#   'theta': -0.3525,
#   'vega': 0.0038,
#   'rho': 0,
#   'theoretical': 77.75,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00100000': {'contractName': 'AAPL220218C00100000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'TRUE',
#   'lastTradeDateTime': '2022-02-15 15:08:20',
#   'expirationDate': '2022-02-18',
#   'strike': 100,
#   'lastPrice': 71.15,
#   'bid': 72.25,
#   'ask': 72.75,
#   'change': -1.08,
#   'changePercent': -0.015,
#   'volume': 1,
#   'openInterest': 580,
#   'impliedVolatility': 346.9811,
#   'delta': 0.9878,
#   'gamma': 0.0007,
#   'theta': -0.3481,
#   'vega': 0.004,
#   'rho': 0,
#   'theoretical': 72.75,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00105000': {'contractName': 'AAPL220218C00105000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'TRUE',
#   'lastTradeDateTime': '2022-02-15 12:07:58',
#   'expirationDate': '2022-02-18',
#   'strike': 105,
#   'lastPrice': 66.35,
#   'bid': 67.3,
#   'ask': 67.75,
#   'change': -1.07,
#   'changePercent': -0.0159,
#   'volume': 23,
#   'openInterest': 47,
#   'impliedVolatility': 319.1133,
#   'delta': 0.9868,
#   'gamma': 0.0008,
#   'theta': -0.3434,
#   'vega': 0.0043,
#   'rho': 0,
#   'theoretical': 67.75,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00110000': {'contractName': 'AAPL220218C00110000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'TRUE',
#   'lastTradeDateTime': '2022-02-16 14:56:55',
#   'expirationDate': '2022-02-18',
#   'strike': 110,
#   'lastPrice': 62.58,
#   'bid': 62.3,
#   'ask': 62.75,
#   'change': 1.66,
#   'changePercent': 0.0272,
#   'volume': 6,
#   'openInterest': 96,
#   'impliedVolatility': 232.2514,
#   'delta': 0.9966,
#   'gamma': 0.0003,
#   'theta': -0.0744,
#   'vega': 0.0013,
#   'rho': 0,
#   'theoretical': 62.58,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00115000': {'contractName': 'AAPL220218C00115000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'TRUE',
#   'lastTradeDateTime': '2022-02-16 12:35:39',
#   'expirationDate': '2022-02-18',
#   'strike': 115,
#   'lastPrice': 55.29,
#   'bid': 57.3,
#   'ask': 57.75,
#   'change': -1.19,
#   'changePercent': -0.0211,
#   'volume': 2,
#   'openInterest': 225,
#   'impliedVolatility': 266.7818,
#   'delta': 0.9844,
#   'gamma': 0.0012,
#   'theta': -0.3327,
#   'vega': 0.005,
#   'rho': 0,
#   'theoretical': 57.75,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00120000': {'contractName': 'AAPL220218C00120000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'TRUE',
#   'lastTradeDateTime': '2022-02-16 12:01:14',
#   'expirationDate': '2022-02-18',
#   'strike': 120,
#   'lastPrice': 51.2,
#   'bid': 52.3,
#   'ask': 52.75,
#   'change': -0.02,
#   'changePercent': -0.0004,
#   'volume': 7,
#   'openInterest': 598,
#   'impliedVolatility': 242.0721,
#   'delta': 0.9828,
#   'gamma': 0.0014,
#   'theta': -0.3266,
#   'vega': 0.0054,
#   'rho': 0,
#   'theoretical': 52.75,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00125000': {'contractName': 'AAPL220218C00125000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'TRUE',
#   'lastTradeDateTime': '2022-02-16 10:06:48',
#   'expirationDate': '2022-02-18',
#   'strike': 125,
#   'lastPrice': 46.89,
#   'bid': 47.3,
#   'ask': 47.75,
#   'change': 2.56,
#   'changePercent': 0.0577,
#   'volume': 2,
#   'openInterest': 269,
#   'impliedVolatility': 218.1875,
#   'delta': 0.9811,
#   'gamma': 0.0017,
#   'theta': -0.3199,
#   'vega': 0.0059,
#   'rho': 0,
#   'theoretical': 47.75,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00130000': {'contractName': 'AAPL220218C00130000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'TRUE',
#   'lastTradeDateTime': '2022-02-16 11:55:30',
#   'expirationDate': '2022-02-18',
#   'strike': 130,
#   'lastPrice': 40.97,
#   'bid': 42.3,
#   'ask': 42.75,
#   'change': -1.31,
#   'changePercent': -0.031,
#   'volume': 2,
#   'openInterest': 631,
#   'impliedVolatility': 195.028,
#   'delta': 0.979,
#   'gamma': 0.0021,
#   'theta': -0.3125,
#   'vega': 0.0064,
#   'rho': 0,
#   'theoretical': 42.75,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00135000': {'contractName': 'AAPL220218C00135000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'TRUE',
#   'lastTradeDateTime': '2022-02-16 14:11:38',
#   'expirationDate': '2022-02-18',
#   'strike': 135,
#   'lastPrice': 36.7,
#   'bid': 37.3,
#   'ask': 37.75,
#   'change': -0.51,
#   'changePercent': -0.0137,
#   'volume': 8,
#   'openInterest': 208,
#   'impliedVolatility': 172.4961,
#   'delta': 0.9765,
#   'gamma': 0.0025,
#   'theta': -0.3041,
#   'vega': 0.0071,
#   'rho': 0,
#   'theoretical': 37.75,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00140000': {'contractName': 'AAPL220218C00140000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'TRUE',
#   'lastTradeDateTime': '2022-02-16 12:20:44',
#   'expirationDate': '2022-02-18',
#   'strike': 140,
#   'lastPrice': 32.45,
#   'bid': 32.3,
#   'ask': 32.8,
#   'change': -0.05,
#   'changePercent': -0.0015,
#   'volume': 10,
#   'openInterest': 898,
#   'impliedVolatility': 156.4286,
#   'delta': 0.9688,
#   'gamma': 0.0035,
#   'theta': -0.3494,
#   'vega': 0.009,
#   'rho': 0,
#   'theoretical': 32.8,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00141000': {'contractName': 'AAPL220218C00141000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'TRUE',
#   'lastTradeDateTime': '0000-00-00 00:00:00',
#   'expirationDate': '2022-02-18',
#   'strike': 141,
#   'lastPrice': 0,
#   'bid': 31.3,
#   'ask': 31.7,
#   'change': 0,
#   'changePercent': None,
#   'volume': None,
#   'openInterest': None,
#   'impliedVolatility': 139.3986,
#   'delta': 0.9777,
#   'gamma': 0.003,
#   'theta': -0.2344,
#   'vega': 0.0068,
#   'rho': 0,
#   'theoretical': 31.7,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:18:45',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00142000': {'contractName': 'AAPL220218C00142000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'TRUE',
#   'lastTradeDateTime': '0000-00-00 00:00:00',
#   'expirationDate': '2022-02-18',
#   'strike': 142,
#   'lastPrice': 0,
#   'bid': 30.3,
#   'ask': 30.65,
#   'change': 0,
#   'changePercent': None,
#   'volume': None,
#   'openInterest': None,
#   'impliedVolatility': 127.1012,
#   'delta': 0.9829,
#   'gamma': 0.0026,
#   'theta': -0.17,
#   'vega': 0.0054,
#   'rho': 0,
#   'theoretical': 30.65,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:18:45',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00143000': {'contractName': 'AAPL220218C00143000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'TRUE',
#   'lastTradeDateTime': '0000-00-00 00:00:00',
#   'expirationDate': '2022-02-18',
#   'strike': 143,
#   'lastPrice': 0,
#   'bid': 29.3,
#   'ask': 29.65,
#   'change': 0,
#   'changePercent': None,
#   'volume': None,
#   'openInterest': None,
#   'impliedVolatility': 123.1371,
#   'delta': 0.9824,
#   'gamma': 0.0028,
#   'theta': -0.1688,
#   'vega': 0.0055,
#   'rho': 0,
#   'theoretical': 29.65,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:18:45',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00144000': {'contractName': 'AAPL220218C00144000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'TRUE',
#   'lastTradeDateTime': '2022-02-14 00:03:15',
#   'expirationDate': '2022-02-18',
#   'strike': 144,
#   'lastPrice': 30.4,
#   'bid': 28.3,
#   'ask': 28.65,
#   'change': 30.4,
#   'changePercent': None,
#   'volume': 1,
#   'openInterest': 1,
#   'impliedVolatility': 119.1874,
#   'delta': 0.9819,
#   'gamma': 0.0029,
#   'theta': -0.1676,
#   'vega': 0.0057,
#   'rho': 0,
#   'theoretical': 28.65,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00145000': {'contractName': 'AAPL220218C00145000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'TRUE',
#   'lastTradeDateTime': '2022-02-16 15:57:40',
#   'expirationDate': '2022-02-18',
#   'strike': 145,
#   'lastPrice': 27.62,
#   'bid': 27.3,
#   'ask': 27.75,
#   'change': 0.57,
#   'changePercent': 0.0211,
#   'volume': 49,
#   'openInterest': 4077,
#   'impliedVolatility': 109.519,
#   'delta': 0.9857,
#   'gamma': 0.0026,
#   'theta': -0.1259,
#   'vega': 0.0046,
#   'rho': 0,
#   'theoretical': 27.62,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00146000': {'contractName': 'AAPL220218C00146000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'TRUE',
#   'lastTradeDateTime': '2022-02-14 00:03:15',
#   'expirationDate': '2022-02-18',
#   'strike': 146,
#   'lastPrice': 26.8,
#   'bid': 26.3,
#   'ask': 26.75,
#   'change': 26.8,
#   'changePercent': None,
#   'volume': 3,
#   'openInterest': 5,
#   'impliedVolatility': 124.6387,
#   'delta': 0.9684,
#   'gamma': 0.0045,
#   'theta': -0.2813,
#   'vega': 0.0091,
#   'rho': 0,
#   'theoretical': 26.75,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00147000': {'contractName': 'AAPL220218C00147000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'TRUE',
#   'lastTradeDateTime': '2022-02-15 13:18:31',
#   'expirationDate': '2022-02-18',
#   'strike': 147,
#   'lastPrice': 24.18,
#   'bid': 25.3,
#   'ask': 25.75,
#   'change': -0.32,
#   'changePercent': -0.0131,
#   'volume': 7,
#   'openInterest': 5,
#   'impliedVolatility': 120.3744,
#   'delta': 0.9673,
#   'gamma': 0.0047,
#   'theta': -0.2788,
#   'vega': 0.0093,
#   'rho': 0,
#   'theoretical': 25.75,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00148000': {'contractName': 'AAPL220218C00148000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'TRUE',
#   'lastTradeDateTime': '2022-02-16 11:29:27',
#   'expirationDate': '2022-02-18',
#   'strike': 148,
#   'lastPrice': 22.7,
#   'bid': 24.3,
#   'ask': 24.75,
#   'change': -0.68,
#   'changePercent': -0.0291,
#   'volume': 4,
#   'openInterest': 8,
#   'impliedVolatility': 116.1198,
#   'delta': 0.9663,
#   'gamma': 0.0051,
#   'theta': -0.2762,
#   'vega': 0.0096,
#   'rho': 0,
#   'theoretical': 24.75,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00149000': {'contractName': 'AAPL220218C00149000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'TRUE',
#   'lastTradeDateTime': '2022-02-16 09:36:56',
#   'expirationDate': '2022-02-18',
#   'strike': 149,
#   'lastPrice': 22.25,
#   'bid': 23.3,
#   'ask': 23.75,
#   'change': -0.29,
#   'changePercent': -0.0129,
#   'volume': 1,
#   'openInterest': 22,
#   'impliedVolatility': 111.8737,
#   'delta': 0.9651,
#   'gamma': 0.0054,
#   'theta': -0.2735,
#   'vega': 0.0098,
#   'rho': 0,
#   'theoretical': 23.75,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00150000': {'contractName': 'AAPL220218C00150000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'TRUE',
#   'lastTradeDateTime': '2022-02-16 15:52:00',
#   'expirationDate': '2022-02-18',
#   'strike': 150,
#   'lastPrice': 22.8,
#   'bid': 22.35,
#   'ask': 22.7,
#   'change': 0.03,
#   'changePercent': 0.0013,
#   'volume': 218,
#   'openInterest': 14165,
#   'impliedVolatility': 102.2843,
#   'delta': 0.9705,
#   'gamma': 0.0052,
#   'theta': -0.2176,
#   'vega': 0.0086,
#   'rho': 0,
#   'theoretical': 22.7,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00152500': {'contractName': 'AAPL220218C00152500',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'TRUE',
#   'lastTradeDateTime': '2022-02-16 10:02:16',
#   'expirationDate': '2022-02-18',
#   'strike': 152.5,
#   'lastPrice': 19.11,
#   'bid': 19.85,
#   'ask': 20.25,
#   'change': 4.37,
#   'changePercent': 0.2965,
#   'volume': 25,
#   'openInterest': 378,
#   'impliedVolatility': 97.0606,
#   'delta': 0.9604,
#   'gamma': 0.0069,
#   'theta': -0.2632,
#   'vega': 0.0109,
#   'rho': 0,
#   'theoretical': 20.25,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00155000': {'contractName': 'AAPL220218C00155000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'TRUE',
#   'lastTradeDateTime': '2022-02-16 15:59:33',
#   'expirationDate': '2022-02-18',
#   'strike': 155,
#   'lastPrice': 17.8,
#   'bid': 17.35,
#   'ask': 17.75,
#   'change': 0.05,
#   'changePercent': 0.0028,
#   'volume': 280,
#   'openInterest': 8211,
#   'impliedVolatility': 86.4969,
#   'delta': 0.9561,
#   'gamma': 0.0084,
#   'theta': -0.2548,
#   'vega': 0.0119,
#   'rho': 0,
#   'theoretical': 17.75,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00157500': {'contractName': 'AAPL220218C00157500',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'TRUE',
#   'lastTradeDateTime': '2022-02-16 15:50:32',
#   'expirationDate': '2022-02-18',
#   'strike': 157.5,
#   'lastPrice': 15.42,
#   'bid': 14.85,
#   'ask': 15.25,
#   'change': 0.4,
#   'changePercent': 0.0266,
#   'volume': 16,
#   'openInterest': 1459,
#   'impliedVolatility': 75.9111,
#   'delta': 0.9508,
#   'gamma': 0.0105,
#   'theta': -0.2452,
#   'vega': 0.013,
#   'rho': 0,
#   'theoretical': 15.25,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00160000': {'contractName': 'AAPL220218C00160000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'TRUE',
#   'lastTradeDateTime': '2022-02-16 15:57:34',
#   'expirationDate': '2022-02-18',
#   'strike': 160,
#   'lastPrice': 12.51,
#   'bid': 12.35,
#   'ask': 12.7,
#   'change': -0.34,
#   'changePercent': -0.0265,
#   'volume': 690,
#   'openInterest': 28133,
#   'impliedVolatility': 61.5371,
#   'delta': 0.9536,
#   'gamma': 0.0124,
#   'theta': -0.1892,
#   'vega': 0.0124,
#   'rho': 0,
#   'theoretical': 12.7,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00162500': {'contractName': 'AAPL220218C00162500',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'TRUE',
#   'lastTradeDateTime': '2022-02-16 15:55:57',
#   'expirationDate': '2022-02-18',
#   'strike': 162.5,
#   'lastPrice': 10.1,
#   'bid': 9.9,
#   'ask': 10.3,
#   'change': 0.09,
#   'changePercent': 0.009,
#   'volume': 450,
#   'openInterest': 5195,
#   'impliedVolatility': 41.9874,
#   'delta': 0.9743,
#   'gamma': 0.0114,
#   'theta': -0.0786,
#   'vega': 0.0076,
#   'rho': 0,
#   'theoretical': 10.1,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00165000': {'contractName': 'AAPL220218C00165000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'TRUE',
#   'lastTradeDateTime': '2022-02-16 15:59:31',
#   'expirationDate': '2022-02-18',
#   'strike': 165,
#   'lastPrice': 7.6,
#   'bid': 7.45,
#   'ask': 7.8,
#   'change': -0.15,
#   'changePercent': -0.0194,
#   'volume': 3293,
#   'openInterest': 39377,
#   'impliedVolatility': 32.8717,
#   'delta': 0.9681,
#   'gamma': 0.0171,
#   'theta': -0.0736,
#   'vega': 0.0091,
#   'rho': 0,
#   'theoretical': 7.6,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00167500': {'contractName': 'AAPL220218C00167500',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'TRUE',
#   'lastTradeDateTime': '2022-02-16 15:59:33',
#   'expirationDate': '2022-02-18',
#   'strike': 167.5,
#   'lastPrice': 5.4,
#   'bid': 5.15,
#   'ask': 5.45,
#   'change': -0.43,
#   'changePercent': -0.0738,
#   'volume': 2497,
#   'openInterest': 7460,
#   'impliedVolatility': 37.8476,
#   'delta': 0.8586,
#   'gamma': 0.0464,
#   'theta': -0.2692,
#   'vega': 0.0286,
#   'rho': 0,
#   'theoretical': 5.4,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00170000': {'contractName': 'AAPL220218C00170000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'TRUE',
#   'lastTradeDateTime': '2022-02-16 15:59:38',
#   'expirationDate': '2022-02-18',
#   'strike': 170,
#   'lastPrice': 3.15,
#   'bid': 3,
#   'ask': 3.25,
#   'change': -0.5,
#   'changePercent': -0.137,
#   'volume': 34092,
#   'openInterest': 48235,
#   'impliedVolatility': 30.7864,
#   'delta': 0.7466,
#   'gamma': 0.0814,
#   'theta': -0.3131,
#   'vega': 0.0409,
#   'rho': 0,
#   'theoretical': 3.15,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00172500': {'contractName': 'AAPL220218C00172500',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'TRUE',
#   'lastTradeDateTime': '2022-02-16 15:59:59',
#   'expirationDate': '2022-02-18',
#   'strike': 172.5,
#   'lastPrice': 1.38,
#   'bid': 1.33,
#   'ask': 1.38,
#   'change': -0.44,
#   'changePercent': -0.2418,
#   'volume': 89659,
#   'openInterest': 36180,
#   'impliedVolatility': 26.637,
#   'delta': 0.5093,
#   'gamma': 0.1173,
#   'theta': -0.3381,
#   'vega': 0.0509,
#   'rho': 0,
#   'theoretical': 1.38,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00175000': {'contractName': 'AAPL220218C00175000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'FALSE',
#   'lastTradeDateTime': '2022-02-16 15:59:58',
#   'expirationDate': '2022-02-18',
#   'strike': 175,
#   'lastPrice': 0.34,
#   'bid': 0.34,
#   'ask': 0.35,
#   'change': -0.32,
#   'changePercent': -0.4848,
#   'volume': 79843,
#   'openInterest': 87684,
#   'impliedVolatility': 23.0707,
#   'delta': 0.2065,
#   'gamma': 0.0968,
#   'theta': -0.2098,
#   'vega': 0.0364,
#   'rho': 0,
#   'theoretical': 0.34,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00177500': {'contractName': 'AAPL220218C00177500',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'FALSE',
#   'lastTradeDateTime': '2022-02-16 15:59:59',
#   'expirationDate': '2022-02-18',
#   'strike': 177.5,
#   'lastPrice': 0.07,
#   'bid': 0.06,
#   'ask': 0.07,
#   'change': -0.09,
#   'changePercent': -0.5625,
#   'volume': 26249,
#   'openInterest': 43273,
#   'impliedVolatility': 23.7621,
#   'delta': 0.0547,
#   'gamma': 0.0365,
#   'theta': -0.084,
#   'vega': 0.0142,
#   'rho': 0,
#   'theoretical': 0.07,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00180000': {'contractName': 'AAPL220218C00180000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'FALSE',
#   'lastTradeDateTime': '2022-02-16 15:59:35',
#   'expirationDate': '2022-02-18',
#   'strike': 180,
#   'lastPrice': 0.02,
#   'bid': 0.01,
#   'ask': 0.02,
#   'change': -0.03,
#   'changePercent': -0.6,
#   'volume': 16098,
#   'openInterest': 78248,
#   'impliedVolatility': 26.6638,
#   'delta': 0.0165,
#   'gamma': 0.012,
#   'theta': -0.0349,
#   'vega': 0.0052,
#   'rho': 0,
#   'theoretical': 0.02,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00182500': {'contractName': 'AAPL220218C00182500',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'FALSE',
#   'lastTradeDateTime': '2022-02-16 15:57:52',
#   'expirationDate': '2022-02-18',
#   'strike': 182.5,
#   'lastPrice': 0.01,
#   'bid': 0.01,
#   'ask': 0.01,
#   'change': -0.02,
#   'changePercent': -0.6667,
#   'volume': 2469,
#   'openInterest': 13351,
#   'impliedVolatility': 31.1078,
#   'delta': 0.0077,
#   'gamma': 0.0053,
#   'theta': -0.021,
#   'vega': 0.0027,
#   'rho': 0,
#   'theoretical': 0.01,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00185000': {'contractName': 'AAPL220218C00185000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'FALSE',
#   'lastTradeDateTime': '2022-02-16 15:59:55',
#   'expirationDate': '2022-02-18',
#   'strike': 185,
#   'lastPrice': 0.01,
#   'bid': 0.01,
#   'ask': 0.01,
#   'change': -0.02,
#   'changePercent': -0.6667,
#   'volume': 2575,
#   'openInterest': 61758,
#   'impliedVolatility': 37.6564,
#   'delta': 0.0065,
#   'gamma': 0.0038,
#   'theta': -0.0218,
#   'vega': 0.0023,
#   'rho': 0,
#   'theoretical': 0.01,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00187500': {'contractName': 'AAPL220218C00187500',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'FALSE',
#   'lastTradeDateTime': '2022-02-16 15:57:52',
#   'expirationDate': '2022-02-18',
#   'strike': 187.5,
#   'lastPrice': 0.01,
#   'bid': 0.01,
#   'ask': 0.01,
#   'change': 0,
#   'changePercent': 0,
#   'volume': 117,
#   'openInterest': 8817,
#   'impliedVolatility': 43.993,
#   'delta': 0.0056,
#   'gamma': 0.0028,
#   'theta': -0.0225,
#   'vega': 0.002,
#   'rho': 0,
#   'theoretical': 0.01,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00190000': {'contractName': 'AAPL220218C00190000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'FALSE',
#   'lastTradeDateTime': '2022-02-16 15:54:34',
#   'expirationDate': '2022-02-18',
#   'strike': 190,
#   'lastPrice': 0.01,
#   'bid': 0.01,
#   'ask': 0.01,
#   'change': 0,
#   'changePercent': 0,
#   'volume': 350,
#   'openInterest': 33846,
#   'impliedVolatility': 50.1476,
#   'delta': 0.005,
#   'gamma': 0.0022,
#   'theta': -0.0231,
#   'vega': 0.0018,
#   'rho': 0,
#   'theoretical': 0.01,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00192500': {'contractName': 'AAPL220218C00192500',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'FALSE',
#   'lastTradeDateTime': '2022-02-15 15:54:21',
#   'expirationDate': '2022-02-18',
#   'strike': 192.5,
#   'lastPrice': 0.01,
#   'bid': 0.01,
#   'ask': 0.01,
#   'change': 0,
#   'changePercent': 0,
#   'volume': 19,
#   'openInterest': 1158,
#   'impliedVolatility': 0,
#   'delta': 0,
#   'gamma': 0,
#   'theta': 0,
#   'vega': 0,
#   'rho': 0,
#   'theoretical': 0,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00195000': {'contractName': 'AAPL220218C00195000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'FALSE',
#   'lastTradeDateTime': '2022-02-16 15:50:01',
#   'expirationDate': '2022-02-18',
#   'strike': 195,
#   'lastPrice': 0.01,
#   'bid': 0.01,
#   'ask': 0.01,
#   'change': 0,
#   'changePercent': 0,
#   'volume': 6,
#   'openInterest': 13667,
#   'impliedVolatility': 61.9899,
#   'delta': 0.0041,
#   'gamma': 0.0015,
#   'theta': -0.0241,
#   'vega': 0.0016,
#   'rho': 0,
#   'theoretical': 0.01,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00197500': {'contractName': 'AAPL220218C00197500',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'FALSE',
#   'lastTradeDateTime': '2022-02-14 12:04:25',
#   'expirationDate': '2022-02-18',
#   'strike': 197.5,
#   'lastPrice': 0.01,
#   'bid': 0.01,
#   'ask': 0.01,
#   'change': 0,
#   'changePercent': 0,
#   'volume': 1,
#   'openInterest': 762,
#   'impliedVolatility': 0,
#   'delta': 0,
#   'gamma': 0,
#   'theta': 0,
#   'vega': 0,
#   'rho': 0,
#   'theoretical': 0,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00200000': {'contractName': 'AAPL220218C00200000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'FALSE',
#   'lastTradeDateTime': '2022-02-16 15:50:01',
#   'expirationDate': '2022-02-18',
#   'strike': 200,
#   'lastPrice': 0.01,
#   'bid': 0.01,
#   'ask': 0.01,
#   'change': 0,
#   'changePercent': 0,
#   'volume': 126,
#   'openInterest': 24784,
#   'impliedVolatility': 73.299,
#   'delta': 0.0035,
#   'gamma': 0.0011,
#   'theta': -0.0248,
#   'vega': 0.0014,
#   'rho': 0,
#   'theoretical': 0.01,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00202500': {'contractName': 'AAPL220218C00202500',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'FALSE',
#   'lastTradeDateTime': '2022-02-14 09:44:48',
#   'expirationDate': '2022-02-18',
#   'strike': 202.5,
#   'lastPrice': 0.01,
#   'bid': 0.01,
#   'ask': 0.01,
#   'change': 0,
#   'changePercent': 0,
#   'volume': 6,
#   'openInterest': 73,
#   'impliedVolatility': 0,
#   'delta': 0,
#   'gamma': 0,
#   'theta': 0,
#   'vega': 0,
#   'rho': 0,
#   'theoretical': 0,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00205000': {'contractName': 'AAPL220218C00205000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'FALSE',
#   'lastTradeDateTime': '2022-02-16 09:40:48',
#   'expirationDate': '2022-02-18',
#   'strike': 205,
#   'lastPrice': 0.01,
#   'bid': 0.01,
#   'ask': 0.01,
#   'change': 0,
#   'changePercent': 0,
#   'volume': 4,
#   'openInterest': 10247,
#   'impliedVolatility': 84.1497,
#   'delta': 0.0031,
#   'gamma': 0.0009,
#   'theta': -0.0255,
#   'vega': 0.0012,
#   'rho': 0,
#   'theoretical': 0.01,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00207500': {'contractName': 'AAPL220218C00207500',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'FALSE',
#   'lastTradeDateTime': '2022-02-14 00:03:18',
#   'expirationDate': '2022-02-18',
#   'strike': 207.5,
#   'lastPrice': 0.01,
#   'bid': 0.01,
#   'ask': 0.01,
#   'change': 0.01,
#   'changePercent': None,
#   'volume': 15,
#   'openInterest': 13,
#   'impliedVolatility': 0,
#   'delta': 0,
#   'gamma': 0,
#   'theta': 0,
#   'vega': 0,
#   'rho': 0,
#   'theoretical': 0,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00210000': {'contractName': 'AAPL220218C00210000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'FALSE',
#   'lastTradeDateTime': '2022-02-16 10:37:59',
#   'expirationDate': '2022-02-18',
#   'strike': 210,
#   'lastPrice': 0.01,
#   'bid': 0.01,
#   'ask': 0.01,
#   'change': 0,
#   'changePercent': 0,
#   'volume': 10,
#   'openInterest': 15961,
#   'impliedVolatility': 94.5951,
#   'delta': 0.0028,
#   'gamma': 0.0007,
#   'theta': -0.026,
#   'vega': 0.0011,
#   'rho': 0,
#   'theoretical': 0.01,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00215000': {'contractName': 'AAPL220218C00215000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'FALSE',
#   'lastTradeDateTime': '2022-02-16 11:18:00',
#   'expirationDate': '2022-02-18',
#   'strike': 215,
#   'lastPrice': 0.01,
#   'bid': 0.01,
#   'ask': 0.01,
#   'change': 0,
#   'changePercent': 0,
#   'volume': 4,
#   'openInterest': 3017,
#   'impliedVolatility': 104.6758,
#   'delta': 0.0026,
#   'gamma': 0.0006,
#   'theta': -0.0265,
#   'vega': 0.001,
#   'rho': 0,
#   'theoretical': 0.01,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00220000': {'contractName': 'AAPL220218C00220000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'FALSE',
#   'lastTradeDateTime': '2022-02-15 15:33:30',
#   'expirationDate': '2022-02-18',
#   'strike': 220,
#   'lastPrice': 0.01,
#   'bid': 0.01,
#   'ask': 0.01,
#   'change': 0,
#   'changePercent': 0,
#   'volume': 6,
#   'openInterest': 3707,
#   'impliedVolatility': 0,
#   'delta': 0,
#   'gamma': 0,
#   'theta': 0,
#   'vega': 0,
#   'rho': 0,
#   'theoretical': 0,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00225000': {'contractName': 'AAPL220218C00225000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'FALSE',
#   'lastTradeDateTime': '2022-02-11 09:55:33',
#   'expirationDate': '2022-02-18',
#   'strike': 225,
#   'lastPrice': 0.01,
#   'bid': 0.01,
#   'ask': 0.01,
#   'change': 0,
#   'changePercent': 0,
#   'volume': 3,
#   'openInterest': 3013,
#   'impliedVolatility': 0,
#   'delta': 0,
#   'gamma': 0,
#   'theta': 0,
#   'vega': 0,
#   'rho': 0,
#   'theoretical': 0,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00230000': {'contractName': 'AAPL220218C00230000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'FALSE',
#   'lastTradeDateTime': '2022-02-09 15:03:17',
#   'expirationDate': '2022-02-18',
#   'strike': 230,
#   'lastPrice': 0.01,
#   'bid': 0.01,
#   'ask': 0.01,
#   'change': 0,
#   'changePercent': 0,
#   'volume': 1,
#   'openInterest': 2809,
#   'impliedVolatility': 0,
#   'delta': 0,
#   'gamma': 0,
#   'theta': 0,
#   'vega': 0,
#   'rho': 0,
#   'theoretical': 0,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00235000': {'contractName': 'AAPL220218C00235000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'FALSE',
#   'lastTradeDateTime': '2022-02-10 09:54:18',
#   'expirationDate': '2022-02-18',
#   'strike': 235,
#   'lastPrice': 0.01,
#   'bid': 0.01,
#   'ask': 0.01,
#   'change': 0,
#   'changePercent': 0,
#   'volume': 1,
#   'openInterest': 1314,
#   'impliedVolatility': 0,
#   'delta': 0,
#   'gamma': 0,
#   'theta': 0,
#   'vega': 0,
#   'rho': 0,
#   'theoretical': 0,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00240000': {'contractName': 'AAPL220218C00240000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'FALSE',
#   'lastTradeDateTime': '2022-02-07 13:36:36',
#   'expirationDate': '2022-02-18',
#   'strike': 240,
#   'lastPrice': 0.01,
#   'bid': 0.01,
#   'ask': 0.01,
#   'change': 0,
#   'changePercent': 0,
#   'volume': 115,
#   'openInterest': 994,
#   'impliedVolatility': 0,
#   'delta': 0,
#   'gamma': 0,
#   'theta': 0,
#   'vega': 0,
#   'rho': 0,
#   'theoretical': 0,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00245000': {'contractName': 'AAPL220218C00245000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'FALSE',
#   'lastTradeDateTime': '2022-02-08 11:37:36',
#   'expirationDate': '2022-02-18',
#   'strike': 245,
#   'lastPrice': 0.01,
#   'bid': 0.01,
#   'ask': 0.01,
#   'change': 0,
#   'changePercent': 0,
#   'volume': 15,
#   'openInterest': 1792,
#   'impliedVolatility': 0,
#   'delta': 0,
#   'gamma': 0,
#   'theta': 0,
#   'vega': 0,
#   'rho': 0,
#   'theoretical': 0,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00250000': {'contractName': 'AAPL220218C00250000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'FALSE',
#   'lastTradeDateTime': '2022-02-09 15:54:03',
#   'expirationDate': '2022-02-18',
#   'strike': 250,
#   'lastPrice': 0.01,
#   'bid': 0.01,
#   'ask': 0.01,
#   'change': 0,
#   'changePercent': 0,
#   'volume': 1,
#   'openInterest': 2073,
#   'impliedVolatility': 0,
#   'delta': 0,
#   'gamma': 0,
#   'theta': 0,
#   'vega': 0,
#   'rho': 0,
#   'theoretical': 0,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00255000': {'contractName': 'AAPL220218C00255000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'FALSE',
#   'lastTradeDateTime': '2022-01-31 15:56:16',
#   'expirationDate': '2022-02-18',
#   'strike': 255,
#   'lastPrice': 0.01,
#   'bid': 0.01,
#   'ask': 0.01,
#   'change': -0.02,
#   'changePercent': -0.6667,
#   'volume': 234,
#   'openInterest': 1865,
#   'impliedVolatility': 0,
#   'delta': 0,
#   'gamma': 0,
#   'theta': 0,
#   'vega': 0,
#   'rho': 0,
#   'theoretical': 0,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00260000': {'contractName': 'AAPL220218C00260000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'FALSE',
#   'lastTradeDateTime': '2022-02-09 14:58:48',
#   'expirationDate': '2022-02-18',
#   'strike': 260,
#   'lastPrice': 0.01,
#   'bid': 0.01,
#   'ask': 0.01,
#   'change': 0,
#   'changePercent': 0,
#   'volume': 1,
#   'openInterest': 4924,
#   'impliedVolatility': 0,
#   'delta': 0,
#   'gamma': 0,
#   'theta': 0,
#   'vega': 0,
#   'rho': 0,
#   'theoretical': 0,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00265000': {'contractName': 'AAPL220218C00265000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'FALSE',
#   'lastTradeDateTime': '2022-01-31 15:54:13',
#   'expirationDate': '2022-02-18',
#   'strike': 265,
#   'lastPrice': 0.01,
#   'bid': 0.01,
#   'ask': 0.01,
#   'change': 0,
#   'changePercent': 0,
#   'volume': 503,
#   'openInterest': 1115,
#   'impliedVolatility': 0,
#   'delta': 0,
#   'gamma': 0,
#   'theta': 0,
#   'vega': 0,
#   'rho': 0,
#   'theoretical': 0,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00270000': {'contractName': 'AAPL220218C00270000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'FALSE',
#   'lastTradeDateTime': '2022-02-14 09:32:06',
#   'expirationDate': '2022-02-18',
#   'strike': 270,
#   'lastPrice': 0.01,
#   'bid': 0.01,
#   'ask': 0.01,
#   'change': 0,
#   'changePercent': 0,
#   'volume': 5,
#   'openInterest': 803,
#   'impliedVolatility': 0,
#   'delta': 0,
#   'gamma': 0,
#   'theta': 0,
#   'vega': 0,
#   'rho': 0,
#   'theoretical': 0,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218C00275000': {'contractName': 'AAPL220218C00275000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'FALSE',
#   'lastTradeDateTime': '2022-02-15 09:30:05',
#   'expirationDate': '2022-02-18',
#   'strike': 275,
#   'lastPrice': 0.01,
#   'bid': 0.01,
#   'ask': 0.01,
#   'change': 0,
#   'changePercent': 0,
#   'volume': 1,
#   'openInterest': 4106,
#   'impliedVolatility': 0,
#   'delta': 0,
#   'gamma': 0,
#   'theta': 0,
#   'vega': 0,
#   'rho': 0,
#   'theoretical': 0,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218P00070000': {'contractName': 'AAPL220218P00070000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'PUT',
#   'inTheMoney': 'FALSE',
#   'lastTradeDateTime': '2022-02-14 14:48:34',
#   'expirationDate': '2022-02-18',
#   'strike': 70,
#   'lastPrice': 0.01,
#   'bid': 0.01,
#   'ask': 0.01,
#   'change': 0,
#   'changePercent': 0,
#   'volume': 17,
#   'openInterest': 1430,
#   'impliedVolatility': 0,
#   'delta': 0,
#   'gamma': 0,
#   'theta': 0,
#   'vega': 0,
#   'rho': 0,
#   'theoretical': 0,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218P00075000': {'contractName': 'AAPL220218P00075000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'PUT',
#   'inTheMoney': 'FALSE',
#   'lastTradeDateTime': '2022-01-31 10:03:01',
#   'expirationDate': '2022-02-18',
#   'strike': 75,
#   'lastPrice': 0.01,
#   'bid': 0.01,
#   'ask': 0.01,
#   'change': 0,
#   'changePercent': 0,
#   'volume': 722,
#   'openInterest': 5662,
#   'impliedVolatility': 0,
#   'delta': 0,
#   'gamma': 0,
#   'theta': 0,
#   'vega': 0,
#   'rho': 0,
#   'theoretical': 0,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218P00080000': {'contractName': 'AAPL220218P00080000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'PUT',
#   'inTheMoney': 'FALSE',
#   'lastTradeDateTime': '2022-02-09 12:02:11',
#   'expirationDate': '2022-02-18',
#   'strike': 80,
#   'lastPrice': 0.01,
#   'bid': 0.01,
#   'ask': 0.01,
#   'change': 0,
#   'changePercent': 0,
#   'volume': 1,
#   'openInterest': 1946,
#   'impliedVolatility': 0,
#   'delta': 0,
#   'gamma': 0,
#   'theta': 0,
#   'vega': 0,
#   'rho': 0,
#   'theoretical': 0,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218P00085000': {'contractName': 'AAPL220218P00085000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'PUT',
#   'inTheMoney': 'FALSE',
#   'lastTradeDateTime': '2022-02-14 09:56:15',
#   'expirationDate': '2022-02-18',
#   'strike': 85,
#   'lastPrice': 0.01,
#   'bid': 0.01,
#   'ask': 0.01,
#   'change': 0,
#   'changePercent': 0,
#   'volume': 1,
#   'openInterest': 1204,
#   'impliedVolatility': 0,
#   'delta': 0,
#   'gamma': 0,
#   'theta': 0,
#   'vega': 0,
#   'rho': 0,
#   'theoretical': 0,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218P00090000': {'contractName': 'AAPL220218P00090000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'PUT',
#   'inTheMoney': 'FALSE',
#   'lastTradeDateTime': '2022-02-11 14:36:29',
#   'expirationDate': '2022-02-18',
#   'strike': 90,
#   'lastPrice': 0.01,
#   'bid': 0.01,
#   'ask': 0.01,
#   'change': 0,
#   'changePercent': 0,
#   'volume': 1,
#   'openInterest': 2286,
#   'impliedVolatility': 0,
#   'delta': 0,
#   'gamma': 0,
#   'theta': 0,
#   'vega': 0,
#   'rho': 0,
#   'theoretical': 0,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218P00095000': {'contractName': 'AAPL220218P00095000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'PUT',
#   'inTheMoney': 'FALSE',
#   'lastTradeDateTime': '2022-02-04 13:51:27',
#   'expirationDate': '2022-02-18',
#   'strike': 95,
#   'lastPrice': 0.01,
#   'bid': 0.01,
#   'ask': 0.01,
#   'change': 0,
#   'changePercent': 0,
#   'volume': 45,
#   'openInterest': 996,
#   'impliedVolatility': 0,
#   'delta': 0,
#   'gamma': 0,
#   'theta': 0,
#   'vega': 0,
#   'rho': 0,
#   'theoretical': 0,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218P00100000': {'contractName': 'AAPL220218P00100000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'PUT',
#   'inTheMoney': 'FALSE',
#   'lastTradeDateTime': '2022-02-15 11:05:51',
#   'expirationDate': '2022-02-18',
#   'strike': 100,
#   'lastPrice': 0.01,
#   'bid': 0.01,
#   'ask': 0.01,
#   'change': 0,
#   'changePercent': 0,
#   'volume': 100,
#   'openInterest': 4305,
#   'impliedVolatility': 0,
#   'delta': 0,
#   'gamma': 0,
#   'theta': 0,
#   'vega': 0,
#   'rho': 0,
#   'theoretical': 0,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218P00105000': {'contractName': 'AAPL220218P00105000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'PUT',
#   'inTheMoney': 'FALSE',
#   'lastTradeDateTime': '2022-02-15 10:14:34',
#   'expirationDate': '2022-02-18',
#   'strike': 105,
#   'lastPrice': 0.01,
#   'bid': 0.01,
#   'ask': 0.01,
#   'change': 0,
#   'changePercent': 0,
#   'volume': 1,
#   'openInterest': 4975,
#   'impliedVolatility': 0,
#   'delta': 0,
#   'gamma': 0,
#   'theta': 0,
#   'vega': 0,
#   'rho': 0,
#   'theoretical': 0,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218P00110000': {'contractName': 'AAPL220218P00110000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'PUT',
#   'inTheMoney': 'FALSE',
#   'lastTradeDateTime': '2022-02-14 11:10:33',
#   'expirationDate': '2022-02-18',
#   'strike': 110,
#   'lastPrice': 0.01,
#   'bid': 0.01,
#   'ask': 0.01,
#   'change': 0,
#   'changePercent': 0,
#   'volume': 12,
#   'openInterest': 6376,
#   'impliedVolatility': 0,
#   'delta': 0,
#   'gamma': 0,
#   'theta': 0,
#   'vega': 0,
#   'rho': 0,
#   'theoretical': 0,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218P00115000': {'contractName': 'AAPL220218P00115000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'PUT',
#   'inTheMoney': 'FALSE',
#   'lastTradeDateTime': '2022-02-15 11:23:47',
#   'expirationDate': '2022-02-18',
#   'strike': 115,
#   'lastPrice': 0.01,
#   'bid': 0.01,
#   'ask': 0.01,
#   'change': 0,
#   'changePercent': 0,
#   'volume': 2,
#   'openInterest': 9435,
#   'impliedVolatility': 0,
#   'delta': 0,
#   'gamma': 0,
#   'theta': 0,
#   'vega': 0,
#   'rho': 0,
#   'theoretical': 0,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:05',
#   'daysBeforeExpiration': 1},
#  'AAPL220218P00120000': {'contractName': 'AAPL220218P00120000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'PUT',
#   'inTheMoney': 'FALSE',
#   'lastTradeDateTime': '2022-02-16 15:25:27',
#   'expirationDate': '2022-02-18',
#   'strike': 120,
#   'lastPrice': 0.01,
#   'bid': 0.01,
#   'ask': 0.01,
#   'change': 0,
#   'changePercent': 0,
#   'volume': 3,
#   'openInterest': 12590,
#   'impliedVolatility': 169.4963,
#   'delta': -0.0016,
#   'gamma': 0.0002,
#   'theta': -0.0273,
#   'vega': 0.0006,
#   'rho': 0,
# ...
#   'lastTradeDateTime': '2022-01-11 11:35:00',
#   'expirationDate': '2022-07-15',
#   'strike': 70,
#   'lastPrice': 104.1,
#   'bid': 102.4,
#   'ask': 103.05,
#   'change': 4.45,
#   'changePercent': 0.0447,
#   'volume': 3,
#   'openInterest': 135,
#   'impliedVolatility': 68.5658,
#   'delta': 0.9898,
#   'gamma': 0.0004,
#   'theta': -0.0056,
#   'vega': 0.0278,
#   'rho': 0,
#   'theoretical': 102.725,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:19',
#   'daysBeforeExpiration': 148},
#  'AAPL220715C00075000': {'contractName': 'AAPL220715C00075000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'TRUE',
#   'lastTradeDateTime': '2022-02-03 12:10:49',
#   'expirationDate': '2022-07-15',
#   'strike': 75,
#   'lastPrice': 99.75,
#   'bid': 97.55,
#   'ask': 98.1,
#   'change': 0.8,
#   'changePercent': 0.0081,
#   'volume': 200,
#   'openInterest': 81,
#   'impliedVolatility': 66.7579,
#   'delta': 0.9859,
#   'gamma': 0.0005,
#   'theta': -0.0075,
#   'vega': 0.0373,
#   'rho': 0,
#   'theoretical': 97.825,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:19',
#   'daysBeforeExpiration': 148},
#  'AAPL220715C00080000': {'contractName': 'AAPL220715C00080000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'TRUE',
#   'lastTradeDateTime': '2022-02-02 15:26:42',
#   'expirationDate': '2022-07-15',
#   'strike': 80,
#   'lastPrice': 95.6,
#   'bid': 92.6,
#   'ask': 93.2,
#   'change': 5.4,
#   'changePercent': 0.0599,
#   'volume': 276,
#   'openInterest': 282,
#   'impliedVolatility': 63.8418,
#   'delta': 0.9824,
#   'gamma': 0.0006,
#   'theta': -0.0088,
#   'vega': 0.0455,
#   'rho': 0,
#   'theoretical': 92.9,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:19',
#   'daysBeforeExpiration': 148},
#  'AAPL220715C00085000': {'contractName': 'AAPL220715C00085000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'TRUE',
#   'lastTradeDateTime': '2022-02-03 15:17:23',
#   'expirationDate': '2022-07-15',
#   'strike': 85,
#   'lastPrice': 90.1,
#   'bid': 87.7,
#   'ask': 88.45,
#   'change': 0.1,
#   'changePercent': 0.0011,
#   'volume': 27,
#   'openInterest': 62,
#   'impliedVolatility': 62.5903,
#   'delta': 0.9764,
#   'gamma': 0.0008,
#   'theta': -0.0113,
#   'vega': 0.059,
#   'rho': 0,
#   'theoretical': 88.075,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:19',
#   'daysBeforeExpiration': 148},
#  'AAPL220715C00090000': {'contractName': 'AAPL220715C00090000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'TRUE',
#   'lastTradeDateTime': '2022-01-31 11:02:59',
#   'expirationDate': '2022-07-15',
#   'strike': 90,
#   'lastPrice': 83.59,
#   'bid': 82.45,
#   'ask': 83.55,
#   'change': 16.68,
#   'changePercent': 0.2493,
#   'volume': 2,
#   'openInterest': 14,
#   'impliedVolatility': 56.8894,
#   'delta': 0.9767,
#   'gamma': 0.0009,
#   'theta': -0.0101,
#   'vega': 0.0582,
#   'rho': 0,
#   'theoretical': 83,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:19',
#   'daysBeforeExpiration': 148},
#  'AAPL220715C00095000': {'contractName': 'AAPL220715C00095000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'TRUE',
#   'lastTradeDateTime': '2022-02-16 10:13:15',
#   'expirationDate': '2022-07-15',
#   'strike': 95,
#   'lastPrice': 76.34,
#   'bid': 77.85,
#   'ask': 78.5,
#   'change': 1.83,
#   'changePercent': 0.0246,
#   'volume': 8,
#   'openInterest': 210,
#   'impliedVolatility': 55.324,
#   'delta': 0.9698,
#   'gamma': 0.0011,
#   'theta': -0.0125,
#   'vega': 0.073,
#   'rho': 0,
#   'theoretical': 78.175,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:19',
#   'daysBeforeExpiration': 148},
#  'AAPL220715C00100000': {'contractName': 'AAPL220715C00100000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'TRUE',
#   'lastTradeDateTime': '2022-02-10 13:19:06',
#   'expirationDate': '2022-07-15',
#   'strike': 100,
#   'lastPrice': 74.15,
#   'bid': 73,
#   'ask': 73.6,
#   'change': -2.26,
#   'changePercent': -0.0296,
#   'volume': 1,
#   'openInterest': 151,
#   'impliedVolatility': 52.7415,
#   'delta': 0.9638,
#   'gamma': 0.0014,
#   'theta': -0.0139,
#   'vega': 0.0849,
#   'rho': 0,
#   'theoretical': 73.3,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:19',
#   'daysBeforeExpiration': 148},
#  'AAPL220715C00105000': {'contractName': 'AAPL220715C00105000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'TRUE',
#   'lastTradeDateTime': '2022-02-11 15:53:11',
#   'expirationDate': '2022-07-15',
#   'strike': 105,
#   'lastPrice': 69.78,
#   'bid': 68.05,
#   'ask': 68.7,
#   'change': 2.62,
#   'changePercent': 0.039,
#   'volume': 3,
#   'openInterest': 64,
#   'impliedVolatility': 49.5259,
#   'delta': 0.9589,
#   'gamma': 0.0016,
#   'theta': -0.0146,
#   'vega': 0.0944,
#   'rho': 0,
#   'theoretical': 68.375,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:19',
#   'daysBeforeExpiration': 148},
#  'AAPL220715C00110000': {'contractName': 'AAPL220715C00110000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'TRUE',
#   'lastTradeDateTime': '2022-02-14 15:46:24',
#   'expirationDate': '2022-07-15',
#   'strike': 110,
#   'lastPrice': 60,
#   'bid': 63.05,
#   'ask': 64.25,
#   'change': -6.26,
#   'changePercent': -0.0945,
#   'volume': 2,
#   'openInterest': 158,
#   'impliedVolatility': 48.1637,
#   'delta': 0.9474,
#   'gamma': 0.002,
#   'theta': -0.0175,
#   'vega': 0.1158,
#   'rho': 0,
#   'theoretical': 63.65,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:19',
#   'daysBeforeExpiration': 148},
#  'AAPL220715C00115000': {'contractName': 'AAPL220715C00115000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'TRUE',
#   'lastTradeDateTime': '2022-02-15 15:30:28',
#   'expirationDate': '2022-07-15',
#   'strike': 115,
#   'lastPrice': 58.5,
#   'bid': 58.2,
#   'ask': 59.15,
#   'change': 0.3,
#   'changePercent': 0.0052,
#   'volume': 4,
#   'openInterest': 67,
#   'impliedVolatility': 44.4419,
#   'delta': 0.9423,
#   'gamma': 0.0024,
#   'theta': -0.0173,
#   'vega': 0.1247,
#   'rho': 0,
#   'theoretical': 58.675,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:19',
#   'daysBeforeExpiration': 148},
#  'AAPL220715C00120000': {'contractName': 'AAPL220715C00120000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'TRUE',
#   'lastTradeDateTime': '2022-02-15 14:41:54',
#   'expirationDate': '2022-07-15',
#   'strike': 120,
#   'lastPrice': 53.65,
#   'bid': 53.9,
#   'ask': 54.4,
#   'change': 2.95,
#   'changePercent': 0.0582,
#   'volume': 18,
#   'openInterest': 93,
#   'impliedVolatility': 43.939,
#   'delta': 0.9244,
#   'gamma': 0.003,
#   'theta': -0.0215,
#   'vega': 0.1543,
#   'rho': 0,
#   'theoretical': 54.15,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:19',
#   'daysBeforeExpiration': 148},
#  'AAPL220715C00125000': {'contractName': 'AAPL220715C00125000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'TRUE',
#   'lastTradeDateTime': '2022-02-11 13:41:22',
#   'expirationDate': '2022-07-15',
#   'strike': 125,
#   'lastPrice': 47.3,
#   'bid': 49.25,
#   'ask': 49.7,
#   'change': -3.99,
#   'changePercent': -0.0778,
#   'volume': 1,
#   'openInterest': 170,
#   'impliedVolatility': 41.9443,
#   'delta': 0.9095,
#   'gamma': 0.0035,
#   'theta': -0.0236,
#   'vega': 0.177,
#   'rho': 0,
#   'theoretical': 49.475,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:19',
#   'daysBeforeExpiration': 148},
#  'AAPL220715C00130000': {'contractName': 'AAPL220715C00130000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'TRUE',
#   'lastTradeDateTime': '2022-02-16 11:19:07',
#   'expirationDate': '2022-07-15',
#   'strike': 130,
#   'lastPrice': 43.24,
#   'bid': 44.7,
#   'ask': 45.15,
#   'change': -1.06,
#   'changePercent': -0.0239,
#   'volume': 2,
#   'openInterest': 193,
#   'impliedVolatility': 40.3138,
#   'delta': 0.8899,
#   'gamma': 0.0043,
#   'theta': -0.0264,
#   'vega': 0.2047,
#   'rho': 0,
#   'theoretical': 44.925,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:19',
#   'daysBeforeExpiration': 148},
#  'AAPL220715C00135000': {'contractName': 'AAPL220715C00135000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'TRUE',
#   'lastTradeDateTime': '2022-02-15 14:58:04',
#   'expirationDate': '2022-07-15',
#   'strike': 135,
#   'lastPrice': 40,
#   'bid': 40.25,
#   'ask': 40.65,
#   'change': 3.97,
#   'changePercent': 0.1102,
#   'volume': 1,
#   'openInterest': 358,
#   'impliedVolatility': 38.6588,
#   'delta': 0.8672,
#   'gamma': 0.0051,
#   'theta': -0.029,
#   'vega': 0.2339,
#   'rho': 0,
#   'theoretical': 40.45,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:19',
#   'daysBeforeExpiration': 148},
#  'AAPL220715C00140000': {'contractName': 'AAPL220715C00140000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'TRUE',
#   'lastTradeDateTime': '2022-02-15 14:48:39',
#   'expirationDate': '2022-07-15',
#   'strike': 140,
#   'lastPrice': 35.75,
#   'bid': 35.9,
#   'ask': 36.3,
#   'change': 2.3,
#   'changePercent': 0.0688,
#   'volume': 1,
#   'openInterest': 1185,
#   'impliedVolatility': 37.1275,
#   'delta': 0.8402,
#   'gamma': 0.006,
#   'theta': -0.0318,
#   'vega': 0.2652,
#   'rho': 0,
#   'theoretical': 36.1,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:19',
#   'daysBeforeExpiration': 148},
#  'AAPL220715C00145000': {'contractName': 'AAPL220715C00145000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'TRUE',
#   'lastTradeDateTime': '2022-02-16 15:14:37',
#   'expirationDate': '2022-07-15',
#   'strike': 145,
#   'lastPrice': 32.39,
#   'bid': 31.75,
#   'ask': 32.05,
#   'change': 0.54,
#   'changePercent': 0.017,
#   'volume': 24,
#   'openInterest': 787,
#   'impliedVolatility': 35.7075,
#   'delta': 0.8081,
#   'gamma': 0.007,
#   'theta': -0.0345,
#   'vega': 0.2983,
#   'rho': 0,
#   'theoretical': 31.9,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:19',
#   'daysBeforeExpiration': 148},
#  'AAPL220715C00150000': {'contractName': 'AAPL220715C00150000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'TRUE',
#   'lastTradeDateTime': '2022-02-16 15:04:32',
#   'expirationDate': '2022-07-15',
#   'strike': 150,
#   'lastPrice': 26.22,
#   'bid': 27.7,
#   'ask': 28.05,
#   'change': -1.33,
#   'changePercent': -0.0483,
#   'volume': 2,
#   'openInterest': 3354,
#   'impliedVolatility': 34.3811,
#   'delta': 0.7706,
#   'gamma': 0.008,
#   'theta': -0.0371,
#   'vega': 0.3315,
#   'rho': 0,
#   'theoretical': 27.875,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:19',
#   'daysBeforeExpiration': 148},
#  'AAPL220715C00155000': {'contractName': 'AAPL220715C00155000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'TRUE',
#   'lastTradeDateTime': '2022-02-16 10:09:46',
#   'expirationDate': '2022-07-15',
#   'strike': 155,
#   'lastPrice': 22.72,
#   'bid': 23.9,
#   'ask': 24.2,
#   'change': -0.93,
#   'changePercent': -0.0393,
#   'volume': 2,
#   'openInterest': 1066,
#   'impliedVolatility': 33.1287,
#   'delta': 0.7273,
#   'gamma': 0.0091,
#   'theta': -0.0393,
#   'vega': 0.3637,
#   'rho': 0,
#   'theoretical': 24.05,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:19',
#   'daysBeforeExpiration': 148},
#  'AAPL220715C00160000': {'contractName': 'AAPL220715C00160000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'TRUE',
#   'lastTradeDateTime': '2022-02-16 15:50:07',
#   'expirationDate': '2022-07-15',
#   'strike': 160,
#   'lastPrice': 20.84,
#   'bid': 20.3,
#   'ask': 20.6,
#   'change': 0.74,
#   'changePercent': 0.0368,
#   'volume': 26,
#   'openInterest': 2181,
#   'impliedVolatility': 31.9325,
#   'delta': 0.6784,
#   'gamma': 0.0102,
#   'theta': -0.041,
#   'vega': 0.3925,
#   'rho': 0,
#   'theoretical': 20.45,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:19',
#   'daysBeforeExpiration': 148},
#  'AAPL220715C00165000': {'contractName': 'AAPL220715C00165000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'TRUE',
#   'lastTradeDateTime': '2022-02-16 15:43:30',
#   'expirationDate': '2022-07-15',
#   'strike': 165,
#   'lastPrice': 17.45,
#   'bid': 17,
#   'ask': 17.3,
#   'change': 0.45,
#   'changePercent': 0.0265,
#   'volume': 20,
#   'openInterest': 2122,
#   'impliedVolatility': 30.8993,
#   'delta': 0.6238,
#   'gamma': 0.0112,
#   'theta': -0.0422,
#   'vega': 0.4159,
#   'rho': 0,
#   'theoretical': 17.15,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:19',
#   'daysBeforeExpiration': 148},
#  'AAPL220715C00170000': {'contractName': 'AAPL220715C00170000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'TRUE',
#   'lastTradeDateTime': '2022-02-16 15:03:29',
#   'expirationDate': '2022-07-15',
#   'strike': 170,
#   'lastPrice': 14.53,
#   'bid': 14,
#   'ask': 14.25,
#   'change': 0.23,
#   'changePercent': 0.0161,
#   'volume': 45,
#   'openInterest': 2606,
#   'impliedVolatility': 29.891,
#   'delta': 0.5646,
#   'gamma': 0.012,
#   'theta': -0.0424,
#   'vega': 0.4316,
#   'rho': 0,
#   'theoretical': 14.125,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:19',
#   'daysBeforeExpiration': 148},
#  'AAPL220715C00175000': {'contractName': 'AAPL220715C00175000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'FALSE',
#   'lastTradeDateTime': '2022-02-16 15:42:36',
#   'expirationDate': '2022-07-15',
#   'strike': 175,
#   'lastPrice': 11.75,
#   'bid': 11.35,
#   'ask': 11.6,
#   'change': 0.95,
#   'changePercent': 0.088,
#   'volume': 45,
#   'openInterest': 3731,
#   'impliedVolatility': 29.0849,
#   'delta': 0.5021,
#   'gamma': 0.0125,
#   'theta': -0.0419,
#   'vega': 0.4375,
#   'rho': 0,
#   'theoretical': 11.475,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:19',
#   'daysBeforeExpiration': 148},
#  'AAPL220715C00180000': {'contractName': 'AAPL220715C00180000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'FALSE',
#   'lastTradeDateTime': '2022-02-16 15:54:44',
#   'expirationDate': '2022-07-15',
#   'strike': 180,
#   'lastPrice': 9.1,
#   'bid': 8.95,
#   'ask': 9.2,
#   'change': -0.1,
#   'changePercent': -0.0109,
#   'volume': 13,
#   'openInterest': 3837,
#   'impliedVolatility': 28.2154,
#   'delta': 0.4376,
#   'gamma': 0.0127,
#   'theta': -0.0403,
#   'vega': 0.4323,
#   'rho': 0,
#   'theoretical': 9.1,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:19',
#   'daysBeforeExpiration': 148},
#  'AAPL220715C00185000': {'contractName': 'AAPL220715C00185000',
#   'contractSize': 'REGULAR',
#   'contractPeriod': 'MONTHLY',
#   'currency': 'USD',
#   'type': 'CALL',
#   'inTheMoney': 'FALSE',
#   'lastTradeDateTime': '2022-02-16 14:30:01',
#   'expirationDate': '2022-07-15',
#   'strike': 185,
#   'lastPrice': 7.2,
#   'bid': 7,
#   'ask': 7.2,
#   'change': 0.13,
#   'changePercent': 0.0184,
#   'volume': 88,
#   'openInterest': 2880,
#   'impliedVolatility': 27.7421,
#   'delta': 0.3753,
#   'gamma': 0.0124,
#   'theta': -0.0382,
#   'vega': 0.4162,
#   'rho': 0,
#   'theoretical': 7.2,
#   'intrinsicValue': 0,
#   'timeValue': 0,
#   'updatedAt': '2022-02-16 19:20:19',
#   'daysBeforeExpiration': 148},
#  ...}

# %%
aapl.option.exercise_price
# Out:
# 70

# %%
OPTIONS["AAPL"]["options_chain"]['2022-02-18']
# Out:
#      Theta   Gamma  Rho    Vega                cName  cDelta  cVolume   cBidP  \
# 0   0.0000  0.0000    0  0.0000  AAPL220218C00070000  0.9923      1.0  102.30
# 1   0.0000  0.0000    0  0.0000  AAPL220218C00075000  0.9917     12.0   97.30
# 2   0.0000  0.0000    0  0.0000  AAPL220218C00080000  0.9911      1.0   92.30
# 3   0.0000  0.0000    0  0.0000  AAPL220218C00085000  0.9904      3.0   87.25
# 4   0.0000  0.0000    0  0.0000  AAPL220218C00090000  0.9896      1.0   82.30
# 5   0.0000  0.0000    0  0.0000  AAPL220218C00095000  0.9888      5.0   77.30
# 6   0.0000  0.0000    0  0.0000  AAPL220218C00100000  0.9878      1.0   72.25
# 7   0.0000  0.0000    0  0.0000  AAPL220218C00105000  0.9868     23.0   67.30
# 8   0.0000  0.0000    0  0.0000  AAPL220218C00110000  0.9966      6.0   62.30
# 9   0.0000  0.0000    0  0.0000  AAPL220218C00115000  0.9844      2.0   57.30
# 10 -0.0273  0.0002    0  0.0006  AAPL220218C00120000  0.9828      7.0   52.30
# 11 -0.0270  0.0003    0  0.0007  AAPL220218C00125000  0.9811      2.0   47.30
# 12 -0.0265  0.0004    0  0.0008  AAPL220218C00130000  0.9790      2.0   42.30
# 13 -0.0260  0.0005    0  0.0009  AAPL220218C00135000  0.9765      8.0   37.30
# 14 -0.0255  0.0006    0  0.0010  AAPL220218C00140000  0.9688     10.0   32.30
# 15 -0.0254  0.0006    0  0.0010  AAPL220218C00141000  0.9777      NaN   31.30
# 16 -0.0252  0.0007    0  0.0011  AAPL220218C00142000  0.9829      NaN   30.30
# 17 -0.0251  0.0007    0  0.0011  AAPL220218C00143000  0.9824      NaN   29.30
# 18 -0.0447  0.0012    0  0.0019  AAPL220218C00144000  0.9819      1.0   28.30
# 19 -0.0444  0.0013    0  0.0019  AAPL220218C00145000  0.9857     49.0   27.30
# 20 -0.0442  0.0013    0  0.0020  AAPL220218C00146000  0.9684      3.0   26.30
# 21 -0.0439  0.0014    0  0.0020  AAPL220218C00147000  0.9673      7.0   25.30
# 22 -0.0436  0.0015    0  0.0021  AAPL220218C00148000  0.9663      4.0   24.30
# 23 -0.0433  0.0017    0  0.0022  AAPL220218C00149000  0.9651      1.0   23.30
# 24 -0.0241  0.0012    0  0.0014  AAPL220218C00150000  0.9705    218.0   22.35
# 25 -0.0421  0.0022    0  0.0025  AAPL220218C00152500  0.9604     25.0   19.85
# 26 -0.0411  0.0028    0  0.0027  AAPL220218C00155000  0.9561    280.0   17.35
# 27 -0.0629  0.0048    0  0.0045  AAPL220218C00157500  0.9508     16.0   14.85
# 28 -0.0675  0.0069    0  0.0055  AAPL220218C00160000  0.9536    690.0   12.35
# 29 -0.0885  0.0118    0  0.0083  AAPL220218C00162500  0.9743    450.0    9.90
# 30 -0.1222  0.0218    0  0.0132  AAPL220218C00165000  0.9681   3293.0    7.45
# 31 -0.2247  0.0455    0  0.0258  AAPL220218C00167500  0.8586   2497.0    5.15
# 32 -0.3138  0.0816    0  0.0408  AAPL220218C00170000  0.7466  34092.0    3.00
# 33 -0.3218  0.1241    0  0.0509  AAPL220218C00172500  0.5093  89659.0    1.33
# 34 -0.1884  0.0986    0  0.0346  AAPL220218C00175000  0.2065  79843.0    0.34
# 35 -0.1078  0.0401    0  0.0166  AAPL220218C00177500  0.0547  26249.0    0.06
# 36 -0.1102  0.0229    0  0.0127  AAPL220218C00180000  0.0165  16098.0    0.01
# 37 -0.2932  0.0229    0  0.0209  AAPL220218C00182500  0.0077   2469.0    0.01
# 38 -0.1350  0.0120    0  0.0102  AAPL220218C00185000  0.0065   2575.0    0.01
# 39 -0.0794  0.0066    0  0.0058  AAPL220218C00187500  0.0056    117.0    0.01
# 40 -0.2507  0.0102    0  0.0129  AAPL220218C00190000  0.0050    350.0    0.01
# 41 -0.0840  0.0044    0  0.0048  AAPL220218C00192500  0.0000     19.0    0.01
# 42 -0.0456  0.0024    0  0.0026  AAPL220218C00195000  0.0041      6.0    0.01
# 43 -0.3242  0.0071    0  0.0122  AAPL220218C00197500  0.0000      1.0    0.01
# 44 -0.0891  0.0028    0  0.0040  AAPL220218C00200000  0.0035    126.0    0.01
# 45 -0.5297  0.0070    0  0.0155  AAPL220218C00202500  0.0000      6.0    0.01
# 46 -0.5850  0.0066    0  0.0158  AAPL220218C00205000  0.0031      4.0    0.01
# 47  0.0000  0.0000    0  0.0000  AAPL220218C00207500  0.0000     15.0    0.01
# 48 -0.2047  0.0031    0  0.0064  AAPL220218C00210000  0.0028     10.0    0.01
# 49 -0.0505  0.0009    0  0.0017  AAPL220218C00215000  0.0026      4.0    0.01
# 50 -0.0513  0.0008    0  0.0016  AAPL220218C00220000  0.0000      6.0    0.01
# 51 -0.0521  0.0007    0  0.0015  AAPL220218C00225000  0.0000      3.0    0.01
# 52 -0.0528  0.0006    0  0.0014  AAPL220218C00230000  0.0000      1.0    0.01
# 53 -0.0534  0.0005    0  0.0013  AAPL220218C00235000  0.0000      1.0    0.01
# 54 -0.0540  0.0005    0  0.0013  AAPL220218C00240000  0.0000    115.0    0.01
# 55 -0.0546  0.0004    0  0.0012  AAPL220218C00245000  0.0000     15.0    0.01
# 56 -0.0551  0.0004    0  0.0012  AAPL220218C00250000  0.0000      1.0    0.01
# 57 -0.0556  0.0004    0  0.0011  AAPL220218C00255000  0.0000    234.0    0.01
# 58 -0.0560  0.0003    0  0.0011  AAPL220218C00260000  0.0000      1.0    0.01
# 59 -0.0565  0.0003    0  0.0011  AAPL220218C00265000  0.0000    503.0    0.01
# 60 -0.0569  0.0003    0  0.0010  AAPL220218C00270000  0.0000      5.0    0.01
# 61 -0.0573  0.0003    0  0.0010  AAPL220218C00275000  0.0000      1.0    0.01
#
#     cTheo   cAskP  Strike   pBidP  pTheo   pAskP  pVolume  pDelta  \
# 0     NaN  102.75    70.0    0.01    NaN    0.01     17.0  0.0000
# 1     NaN   97.75    75.0    0.01    NaN    0.01    722.0  0.0000
# 2     NaN   92.75    80.0    0.01    NaN    0.01      1.0  0.0000
# 3     NaN   87.75    85.0    0.01    NaN    0.01      1.0  0.0000
# 4     NaN   82.75    90.0    0.01    NaN    0.01      1.0  0.0000
# 5     NaN   77.75    95.0    0.01    NaN    0.01     45.0  0.0000
# 6     NaN   72.75   100.0    0.01    NaN    0.01    100.0  0.0000
# 7     NaN   67.75   105.0    0.01    NaN    0.01      1.0  0.0000
# 8     NaN   62.75   110.0    0.01    NaN    0.01     12.0  0.0000
# 9     NaN   57.75   115.0    0.01    NaN    0.01      2.0  0.0000
# 10    NaN   52.75   120.0    0.01    NaN    0.01      3.0 -0.0016
# 11    NaN   47.75   125.0    0.01    NaN    0.01     60.0 -0.0017
# 12    NaN   42.75   130.0    0.01    NaN    0.01     14.0 -0.0019
# 13    NaN   37.75   135.0    0.01    NaN    0.01   1012.0 -0.0022
# 14    NaN   32.80   140.0    0.01    NaN    0.01    400.0 -0.0025
# 15    NaN   31.70   141.0    0.01    NaN    0.04    203.0 -0.0026
# 16    NaN   30.65   142.0    0.01    NaN    0.04     28.0 -0.0027
# 17    NaN   29.65   143.0    0.01    NaN    0.02     12.0 -0.0028
# 18    NaN   28.65   144.0    0.01    NaN    0.04    218.0 -0.0050
# 19    NaN   27.75   145.0    0.01    NaN    0.05    826.0 -0.0052
# 20    NaN   26.75   146.0    0.01    NaN    0.05     79.0 -0.0054
# 21    NaN   25.75   147.0    0.01    NaN    0.02    302.0 -0.0056
# 22    NaN   24.75   148.0    0.01    NaN    0.03    216.0 -0.0058
# 23    NaN   23.75   149.0    0.01    NaN    0.03    123.0 -0.0060
# 24    NaN   22.70   150.0    0.01    NaN    0.02    860.0 -0.0035
# 25    NaN   20.25   152.5    0.02    NaN    0.03    483.0 -0.0069
# 26    NaN   17.75   155.0    0.02    NaN    0.04   2525.0 -0.0077
# 27    NaN   15.25   157.5    0.03    NaN    0.04   1760.0 -0.0137
# 28    NaN   12.70   160.0    0.03    NaN    0.04   6742.0 -0.0175
# 29    NaN   10.30   162.5    0.05    NaN    0.07   8327.0 -0.0282
# 30    NaN    7.80   165.0    0.10    NaN    0.12  18409.0 -0.0500
# 31    NaN    5.45   167.5    0.24    NaN    0.30  22809.0 -0.1218
# 32    NaN    3.25   170.0    0.56    NaN    0.62  53018.0 -0.2528
# 33    NaN    1.38   172.5    1.26    NaN    1.34  21739.0 -0.4907
# 34    NaN    0.35   175.0    2.58    NaN    2.90   3886.0 -0.8101
# 35    NaN    0.07   177.5    4.85    NaN    5.25    375.0 -0.9327
# 36    NaN    0.02   180.0    7.20    NaN    7.70    479.0 -0.9523
# 37    NaN    0.01   182.5    9.75    NaN   10.25     66.0 -0.9093
# 38    NaN    0.01   185.0   12.35    NaN   12.75      6.0 -0.9635
# 39    NaN    0.01   187.5   14.85    NaN   15.15     20.0 -0.9815
# 40    NaN    0.01   190.0   17.20    NaN   17.65     12.0 -0.9514
# 41    NaN    0.01   192.5   19.80    NaN   20.20      1.0 -0.9849
# 42    NaN    0.01   195.0   22.25    NaN   22.70      1.0 -0.9927
# 43    NaN    0.01   197.5   24.65    NaN   25.20      NaN -0.9545
# 44    NaN    0.01   200.0   27.20    NaN   27.75    151.0 -0.9880
# 45    NaN    0.01   202.5   29.00    NaN   30.40      1.0 -0.9384
# 46    NaN    0.01   205.0   31.15    NaN   32.95      5.0 -0.9368
# 47    NaN    0.01   207.5     NaN    NaN     NaN      NaN     NaN
# 48    NaN    0.01   210.0   37.15    NaN   38.00      6.0 -0.9793
# 49    NaN    0.01   215.0   42.25    NaN   42.70      7.0 -0.9954
# 50    NaN    0.01   220.0   47.25    NaN   47.70     40.0 -0.9957
# 51    NaN    0.01   225.0   52.25    NaN   52.70      5.0 -0.9960
# 52    NaN    0.01   230.0   57.25    NaN   57.70      2.0 -0.9963
# 53    NaN    0.01   235.0   62.25    NaN   62.70      7.0 -0.9965
# 54    NaN    0.01   240.0   67.25    NaN   67.70      6.0 -0.9966
# 55    NaN    0.01   245.0   72.25    NaN   72.70      NaN -0.9968
# 56    NaN    0.01   250.0   77.25    NaN   77.70      2.0 -0.9969
# 57    NaN    0.01   255.0   82.25    NaN   82.70      NaN -0.9971
# 58    NaN    0.01   260.0   87.25    NaN   87.70      1.0 -0.9972
# 59    NaN    0.01   265.0   92.25    NaN   92.70      3.0 -0.9973
# 60    NaN    0.01   270.0   97.25    NaN   97.70      1.0 -0.9974
# 61    NaN    0.01   275.0  102.25    NaN  102.70      1.0 -0.9974
#
#                   pName
# 0   AAPL220218P00070000
# 1   AAPL220218P00075000
# 2   AAPL220218P00080000
# 3   AAPL220218P00085000
# 4   AAPL220218P00090000
# 5   AAPL220218P00095000
# 6   AAPL220218P00100000
# 7   AAPL220218P00105000
# 8   AAPL220218P00110000
# 9   AAPL220218P00115000
# 10  AAPL220218P00120000
# 11  AAPL220218P00125000
# 12  AAPL220218P00130000
# 13  AAPL220218P00135000
# 14  AAPL220218P00140000
# 15  AAPL220218P00141000
# 16  AAPL220218P00142000
# 17  AAPL220218P00143000
# 18  AAPL220218P00144000
# 19  AAPL220218P00145000
# 20  AAPL220218P00146000
# 21  AAPL220218P00147000
# 22  AAPL220218P00148000
# 23  AAPL220218P00149000
# 24  AAPL220218P00150000
# 25  AAPL220218P00152500
# 26  AAPL220218P00155000
# 27  AAPL220218P00157500
# 28  AAPL220218P00160000
# 29  AAPL220218P00162500
# 30  AAPL220218P00165000
# 31  AAPL220218P00167500
# 32  AAPL220218P00170000
# 33  AAPL220218P00172500
# 34  AAPL220218P00175000
# 35  AAPL220218P00177500
# 36  AAPL220218P00180000
# 37  AAPL220218P00182500
# 38  AAPL220218P00185000
# 39  AAPL220218P00187500
# 40  AAPL220218P00190000
# 41  AAPL220218P00192500
# 42  AAPL220218P00195000
# 43  AAPL220218P00197500
# 44  AAPL220218P00200000
# 45  AAPL220218P00202500
# 46  AAPL220218P00205000
# 47                  NaN
# 48  AAPL220218P00210000
# 49  AAPL220218P00215000
# 50  AAPL220218P00220000
# 51  AAPL220218P00225000
# 52  AAPL220218P00230000
# 53  AAPL220218P00235000
# 54  AAPL220218P00240000
# 55  AAPL220218P00245000
# 56  AAPL220218P00250000
# 57  AAPL220218P00255000
# 58  AAPL220218P00260000
# 59  AAPL220218P00265000
# 60  AAPL220218P00270000
# 61  AAPL220218P00275000
